# %% [markdown]
# ##Import dependencies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Cleaning school names from the dataset

# %%
df = pd.read_parquet('/content/ct_job_app_education.parquet')

# %%
df1=df['school_name'].fillna('').str.upper().sort_values()

# %%
new_list = []
for x in df1:
      new_list.append(x.strip())

df1= new_list

# %%
import re
def remove_punct(text):
    new_words = []
    for word in text:
        w = re.sub(r'[^\w\s]','',word) #remove everything except words and space
        w = re.sub(r'_','',w) #how to remove underscore as well
        new_words.append(w)
    return new_words

# %%
school_namedf = pd.DataFrame(remove_punct(df1))
#school_namedf['school_name'] = pd.DataFrame(remove_punct(df1))

# %%
school_namedf.replace([""," ","OTHER", "OTHERS"], np.nan, inplace=True)

# %%
school_namedf_na=school_namedf.dropna()

# %%
school_namedf_na=school_namedf_na.replace("ACCA", "ASSOCIATION OF CHARTERED CERTIFIED ACCOUNTANTS")
school_namedf_na=school_namedf_na.replace("APU", "ASIA PACIFIC UNIVERSITY OF TECHNOLOGY AND INNOVATION")
school_namedf_na=school_namedf_na.replace("AMIK", "AMIK BINA SARANA INFORMATIKAAPU")
school_namedf_na=school_namedf_na.replace("BSI", "UNIVERSITAS BINA SARANA INFORMATIKA")
school_namedf_na=school_namedf_na.replace("FKIP", "FKIP BAHASA INGGRIS")
school_namedf_na=school_namedf_na.replace("FPT", "FPT UNIVERSITY")
school_namedf_na=school_namedf_na.replace("GCUF", "GOVERNMENT COLLEGE UNIVERSITY FAISALABAD")
school_namedf_na=school_namedf_na.replace("GIKI", "GHULAM ISHAQ KHAN INSTITUTE")
school_namedf_na=school_namedf_na.replace("I3L", "INDONESIA INTERNATIONAL INSTITUTE FOR LIFE SCIENCES")
school_namedf_na=school_namedf_na.replace("IAIN", "INSTITUT AGAMA ISLAM NEGERI")
school_namedf_na=school_namedf_na.replace("IBA", "UNIVERSITY IBA")
school_namedf_na=school_namedf_na.replace("IBBI", "SEKOLAH TINGGI ILMU EKONOMI")
school_namedf_na=school_namedf_na.replace("IBM", "IBM ASMI")
school_namedf_na=school_namedf_na.replace("ICBS", "IMPERIAL COLLEGE OF BUSINESS STUDIES")
school_namedf_na=school_namedf_na.replace("IIEE", "IIEE NED UNIVERSITY OF ENGINEERING AND TECHNOLOGY")
school_namedf_na=school_namedf_na.replace("IIUM", "INTERNATIONAL ISLAMIC UNIVERSITY MALAYSIA")
school_namedf_na=school_namedf_na.replace("INTI", "INTI INTERNATIONAL COLLEGE")
school_namedf_na=school_namedf_na.replace("IPA", "INSTITUTE OF PUBLIC ADMINISTRATION")
school_namedf_na=school_namedf_na.replace("IPB", "INSTITUT PERTANIAN BOGOR")
school_namedf_na=school_namedf_na.replace("ITB", "BANDUNG INSTITUTE OF TECHNOLOGHY")
school_namedf_na=school_namedf_na.replace("ITNY", "INSTITUT TEKNOLOGI NASIONAL YOGYAKARTA")
school_namedf_na=school_namedf_na.replace("ITS", "INSTITUT SEPULUH NOPEMBER")
school_namedf_na=school_namedf_na.replace("IUMW", "INTERNATIONAL UNIVERSITY OF MALAYAWALES")
school_namedf_na=school_namedf_na.replace("KPTM", "KOLEJ POLYTECH MARA")
school_namedf_na=school_namedf_na.replace("LP31", "LP3I COLLEGE")
school_namedf_na=school_namedf_na.replace("LSC", "LONDON SCHOOL OF COMMERCE")
school_namedf_na=school_namedf_na.replace("LSPR", "LONDON SCHOOL OF PUBLIC RELATIONS")
school_namedf_na=school_namedf_na.replace("MCHM", "MALAYSIAN COLLEGE OF HOSPITALITY AND MANAGEMENT")
school_namedf_na=school_namedf_na.replace("MMU", "MULTIMEDIA UNIVERSITY")
school_namedf_na=school_namedf_na.replace("MSU", "MANAGEMENT SCIENCE UNIVERSITY")
school_namedf_na=school_namedf_na.replace("NED", "NED UNIVERSITY OF ENGINEERING AND TECHNOLOGY")
school_namedf_na=school_namedf_na.replace("NTU", "NANYANG TECHNOLOGICAL UNIVERSITY")
school_namedf_na=school_namedf_na.replace("NUS", "NATIONAL UNIVERSITY OF SINGAPORE")
school_namedf_na=school_namedf_na.replace("NUST", "NATIONAL UNIVERSITY OF SCIENCE AND TECHNOLOGY NUST")
school_namedf_na=school_namedf_na.replace("PENS", "ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA")
school_namedf_na=school_namedf_na.replace("PVU", "TRƯỜNG ĐẠI HỌC")
school_namedf_na=school_namedf_na.replace("RMIT", "ROYAL MELBOURNE INSTITUTE OF TECHNOLOGY")
school_namedf_na=school_namedf_na.replace("SEGI", "SEGI COLLEGE")
school_namedf_na=school_namedf_na.replace("STIA", "SEKOLAH TINGGI ILMU ADMINISTRASI")
school_namedf_na=school_namedf_na.replace("STIE", "SEKOLAH TINGGI ILMU EKONOMI")
school_namedf_na=school_namedf_na.replace("SWUC", "SOUTHWESTERN CHRISTIAN UNIVERSITY")
school_namedf_na=school_namedf_na.replace("UBSI", "UNIVERSITAS BINA SARANA INFORMATIKA")
school_namedf_na=school_namedf_na.replace("UCSI", "UCSI UNIVERISTY")
school_namedf_na=school_namedf_na.replace("UEF", "ĐẠI HỌC KINH TẾ QUỐC DÂN")
school_namedf_na=school_namedf_na.replace("UEH", "UNIVERSITY OF ECONOMICS HCMC")
school_namedf_na=school_namedf_na.replace("UEL", "UNIVERSITY OF EAST LONDON")
school_namedf_na=school_namedf_na.replace("UGM", "GADJAH MADA UNIVERSITY")
school_namedf_na=school_namedf_na.replace("UIAM", "UNIVERSITI ISLAM ANTARABANGSA MALAYSIA")
school_namedf_na=school_namedf_na.replace("UII", "UNIVERSITY ISLAM INDONESIA")
school_namedf_na=school_namedf_na.replace("UITM", "MARA UNIVERSITY OF TECHNOLOGY MALAYSIA")
school_namedf_na=school_namedf_na.replace("UKI", "UNIVERSITY KRISTEN INDONESIA")
school_namedf_na=school_namedf_na.replace("UKM", "NATIONAL UNIVERSITY OF MALAYSIA")
school_namedf_na=school_namedf_na.replace("UM", "UNIVERSITY OF MALAYA")
school_namedf_na=school_namedf_na.replace("UMJ", "UNIVERSITAS MUHAMMADIYAH JAKARTA")
school_namedf_na=school_namedf_na.replace("UMM", "UNIVERSITY OF MALAYA")
school_namedf_na=school_namedf_na.replace("UMP", "UNIVERSITY MALAYSIA PAHANG")
school_namedf_na=school_namedf_na.replace("UMSU", "UNIVERSITY MUHAMMADIYAH SUMATERA UTARA")
school_namedf_na=school_namedf_na.replace("UMT", "UNIVERSITI MALAYSIA TERENGGANU")
school_namedf_na=school_namedf_na.replace("UMY", "UNIVERSITY MUHAMMADIYAH YOGYAKARTA")
school_namedf_na=school_namedf_na.replace("UNS", "SEBELAS MARET UNIVERSITY")
school_namedf_na=school_namedf_na.replace("UNSW", "UNIVERSITY OF NEW SOUTH WALES")
school_namedf_na=school_namedf_na.replace("UNY", "UNIVERSITAS NEGERI YOGYAKARTA")
school_namedf_na=school_namedf_na.replace("UOL", "UNIVERSITY OF LONDON")
school_namedf_na=school_namedf_na.replace("UPH", "PELITA HARAPAN UNIVERSITY")
school_namedf_na=school_namedf_na.replace("UPI", "UNIVERSITY PENDIDIKAN INDONESIA")
school_namedf_na=school_namedf_na.replace("UPM", "UNIVERSITY PUTRA MALAYSIA")
school_namedf_na=school_namedf_na.replace("UPNM", "UNIVERSITI PERTAHANAN NASIONAL MALAYSIA")
school_namedf_na=school_namedf_na.replace("USIM", "UNIVERSITI SAINS ISLAM MALAYSIA")
school_namedf_na=school_namedf_na.replace("USM", "UNIVERSITI SAINS MALAYSIA")
school_namedf_na=school_namedf_na.replace("USU", "UNIVERSITY SUMATERA UTARA")
school_namedf_na=school_namedf_na.replace("UTAR", "UNIVERSITY TUNKU ABDUL RAHMAN")
school_namedf_na=school_namedf_na.replace("UTEM", "UNIVERSITI TEKNIKAL MALAYSIA MELAKA")
school_namedf_na=school_namedf_na.replace("UTHM", "UNIVERSITY TUN HUSSEIN ONN MALAYSIA")
school_namedf_na=school_namedf_na.replace("UTM", "UNIVERSITY TEKNOLOGI MALAYSIA")
school_namedf_na=school_namedf_na.replace("UTP", "UNIVERSITI TEKNOLOGI PETRONAS")
school_namedf_na=school_namedf_na.replace("UUM", "UNIVERSITY UTARA MALAYSIA")
school_namedf_na=school_namedf_na.replace("YAI", "AKADEMI AKUNTANSI YAI")

# %%
transform_list=['BINA NUNSATARA UNIVERSITY', 
                'BINA NUSANTARA', 
                'BINA NUSANTARA BINUS', 
                'BINA NUSANTARA BINUS UNIVERSITY', 
                'BINA NUSANTARA BUSINESS SCHOOL',
                'BINA NUSANTARA INTERNATIONAL UNIVERSITY',
                'BINA NUSANTARA INTERNATIONAL UNIVERSITY CBS INTERNATIONAL BUSINESS SCHOOL',
                'BINA NUSANTARA UNIVERCITY',
                'BINA NUSANTARA UNIVERISTY',
                'BINA NUSANTARA UNIVERSIRY',
                'BINA NUSANTARA UNIVERSITY',
                'BINA NUSANTARA UNIVERSITY BINUS UNIVERSITY',
                'BINA NUSANTARA UNIVERSITY BINUS']

for i in school_namedf_na:
  for i in transform_list:
    school_namedf_na=school_namedf_na.replace(i, 'BINUS UNIVERSITY')

# %%
#Remove string length < 5
school_namedf_na = school_namedf_na[school_namedf_na[0].str.len() > 5]
school_namedf_na
# Out:
#                                                        0
# 57                                    ANDALAS UNIVERSITY
# 58            ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA
# 59     BANDUNG POLYTECHNIC FOR MANUFACTURING  POLMAN ...
# 60     HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND ...
# 61                         JENDERAL SOEDIRMAN UNIVERSITY
# ...                                                  ...
# 59886                                  ĐẠI HỌC CÔNG ĐOÀN
# 59887                          ĐẠI HỌC KINH TẾ  QUỐC DÂN
# 59888                        ĐẠI HỌC TÀI CHÍNH MARKETING
# 59889                       \tIMG SRCJAVASCRIPTALERTTEST
# 59890                               東洋大学 TOYO UNIVERSITY
#
# [59630 rows x 1 columns]

# %%
unique_school_name=pd.DataFrame(school_namedf_na[0].unique())

# %%
unique_list = unique_school_name.iloc[:,0].values.tolist()
#unique_list = ['UNIVERSITY OF' if i.startswith('UNIVER')]

unique_list
# Out:
# ['ANDALAS UNIVERSITY',
#  'ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA',
#  'BANDUNG POLYTECHNIC FOR MANUFACTURING  POLMAN BANDUNG ',
#  'HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND EDUCATION',
#  'JENDERAL SOEDIRMAN UNIVERSITY',
#  'LEGAL PROFESSION QUALIFYING BOARD',
#  'MEDAN STATE UNIVERSITY',
#  'NATIONAL INSTITUTE OF TECHNOLOGY BANDUNG',
#  'PADJAJARAN UNIVERSITY',
#  'SOLBRIDGE INTERNATIONAL SCHOOL OF BUSINESS',
#  'STATE POLYTECHNIC OF JEMBER',
#  'STATE POLYTECHNIC OF MALANG',
#  'SURABAYA STATE OF UNIVERSITY',
#  'TRILOGI UNIVERSITY',
#  'UNIVERSITAS GADJAH MADA',
#  'UNIVERSITAS NUSA MANDIRI',
#  'UNIVERSITAS PEMBANGUNAN NASIONAL VETERAN YOGYAKARTA',
#  'UNIVERSITY OF INDONESIA',
#  'UNIVERSITY OF NORTH SUMATRA',
#  'YOGYAKARTA VETERAN NATIONAL DEVELOPMENT UNIVERSITY',
#  'ANGEL KANČEV UNIVERSITY OF RUSE',
#  'BALTAZAR ADAM KRČELIĆ COLLEGE OF BUSINESS ADMINISTRATION',
#  'CHERNORIZETS HRABAR  FREE UNIVERSITY OF VARNA',
#  'DA TSENOV ACADEMY OF ECONOMICS  SVISHTOV',
#  'GEORGE BARIȚIU UNIVERSITY',
#  'KONSTANTIN PRESLAVSKI SHUMEN UNIVERSITY',
#  'KRUSTYO SARAFOV NATIONAL ACADEMY FOR THEATRE AND FILM ARTS',
#  'LA GRACE UNIVERSITY ADVANCED TECHNICIANS SCHOOL OF BENIN',
#  '17 AGUSTUS 1945 JAKARTA UNIVERSITY',
#  '17 AGUSTUS 1945 UNIVERSITY',
#  '2 DEPOK SENIOR HIGH SCHOOL',
#  '23RQEWDWQ',
#  '57 SHS',
#  'A2L  STIE PRASETIYA MANDIRI LAMPUNG',
#  'AACHEN  UNIVERSITY OF APPLIED SCIENCE',
#  'ABBOTTABAD UNIVERSITY OF SCIENCE AND TECHNOLOGY',
#  'ABC UNI',
#  'ABDUL WALI KHAN UNIVERSITY MARDAN',
#  'ABE INTERNATIONAL BUSINESS COLLEGE',
#  'ABERYSTWYTH UNIVERSITY',
#  'ABFI INSTITUTE PERBANAS',
#  'ABFI PERBANAS',
#  'ABFII PERBANAS',
#  'ABIA STATE UNIVERSITY',
#  'ACADEMIES AUSTRALASIA INSTITUTE',
#  'ACADEMY AVIATION TRAINING CENTER',
#  'ACADEMY MARITIME CIREBON',
#  'ACADEMY METROLOGY AND INSTRUMENTATION',
#  'ACADEMY OF FINANCE VIETNAM',
#  'ACADEMY OF FOOD AND PHARMACY ANALYST PUTRA INDONESIA MALANG',
#  'ACADEMY OF HUMANITIES AND TECHNOLOGY',
#  'ACADEMY OF JOURNALISM AND COMMUNICATION',
#  'ACADEMY OF JOURNALISM AND COMMUNICATIONS',
#  'ACADEMY OF METROLOGY AND INSTRUMENTATION ITB',
#  'ACADEMY OF POLICY AND DEVELOPMENT',
#  'ACADEMY OF TOURISM NHI BANDUNG',
#  'ACADEMY OIL AND GAS BALONGAN INDRAMAYU',
#  'ASSOCIATION OF CHARTERED CERTIFIED ACCOUNTANTS',
#  'ACCOUNTING',
#  'ACCRA TECHNICAL UNIVERSITY',
#  'ADAMJEE GOVERNMENT SCIENCE COLLEGE',
#  'ADELEKE UNIVERSITY EDE OSUN STATE',
#  'ADHI TAMA INSTITUTE OF TECHNOLOGY',
#  'ADHI TAMA INSTITUTE OF TECHNOLOGY SURABAYA',
#  'ADHI TAMA SURABAYA INSTITUT OF TECHNOLOGY',
#  'ADHI TAMAINSTITUTE OF TECHNOLOGY',
#  'ADHYAKSA UNIVERSITAS ISLAM NEGERI JAMBI',
#  'ADI BUANA SURABAYA UNIVERSITY',
#  'ADI BUANA UNIVERSITY',
#  'ADISUTJIPTO COLLEGE OF TECHNOLOGY',
#  'ADISUTJIPTO COLLEGE OF TECHNOLOGY STTA',
#  'ADISUTJIPTOAEROSPACE INSTITUTE OF TECHNOLOGY',
#  'ADMINISTRASI',
#  'ADMINISTRASI PERKANTORAN',
#  'ADVANCE TERTIARY COLLEGE',
#  'ADVANCED TECHNOLOGY CENTRE ADTEC TAIPING',
#  'ADVENTIST UNIVERSITY OF INDONESIA',
#  'ADVENTIST UNIVERSITY OF THE PHILIPPINES',
#  'ADVOKAT',
#  'AFRICA INTERNATIONAL UNIVERSITY',
#  'AGRICULTURAL DEVELOPMENT POLYTECHNIC MALANG',
#  'AGRICULTURE',
#  'AGROCAMPUS WEST',
#  'AHMAD DAHLAN UNIVERSITY',
#  'AHMAD DAHLAN UNIVERSITY OF YOGYAKARTA',
#  'AHMAD DAHLAN UNIVERSITY YOGYAKARTA',
#  'AHMAD DAHLAN UNIVESITY',
#  'AIMST UNIVERSITY',
#  'AIR MARSHAL SURYADARMA UNIVERSITY',
#  'AIR UNIVERSITY',
#  'AIR UNIVERSITY ISLAMABAD',
#  'AIRALANGGA UNIVERSITY',
#  'AIRLANGGA',
#  'AIRLANGGA  UNIVERSITY',
#  'AIRLANGGA BROADCAST EDUCATION',
#  'AIRLANGGA UNIVERISTY',
#  'AIRLANGGA UNIVERSITY',
#  'AIRLANGGA UNIVERSITY UNAIR',
#  'AIRLANGGA UNIVERSITY UNIVERSITAS AIRLANGGA',
#  'AIRLANGGA UNIVERSITY INDONESIA',
#  'AIRLANGGA UNIVERSITY SURABAYA',
#  'AIRLANGGA UNVERSITY',
#  'AISYIYAH YOGYAKARTA UNIVERSITY',
#  'AKADEMI  PARIWISATA NHI BANDUNG',
#  'AKADEMI AKUNTANSI BUKITTINGGI',
#  'AKADEMI AKUNTANSI KEUANGAN DAN PERBANKAN INDONESIA',
#  'AKADEMI AKUNTANSI YAI',
#  'AKADEMI AKUNTANSI YAI JAKARTA',
#  'AKADEMI AKUNTANSI YAYASAN KELUARGA PAHLAWAN NEGARA',
#  'AKADEMI AKUNTANSI YKPN',
#  'AKADEMI AKUNTANSI YKPN YOGYAKARTA',
#  'AKADEMI ANALIS KESEHATAN DELIMA HUSADA GRESIK',
#  'AKADEMI BINA INSANI',
#  'AKADEMI BINA SARANA INFORMATIKA',
#  'AKADEMI BINASARANA INFORMATIKA',
#  'AKADEMI FARMASI SURABAYA',
#  'AKADEMI GIZI KARYA HUSADA KEDIRI',
#  'AKADEMI KEBIDANAN TUNAS HARAPAN BANGSA',
#  'AKADEMI KEBIDANAN WIJAYA KUSUMA MALANG',
#  'AKADEMI KEPERAWATAN HANG TUAH JAKARTA',
#  'AKADEMI KEPERAWATAN MUHAMMADIYAH MAKASSAR',
#  'AKADEMI KEPERAWATAN PEMKAB LABUHANBATU',
#  'AKADEMI KEUANGAN DAN PERBANKAN PONTIANAK',
#  'AKADEMI KIMIA ANALISIS CARAKA NUSANTARA DEPOK',
#  'AKADEMI KOMUNIKASI',
#  'AKADEMI KOMUNITAS INDUSTRI MANUFAKTUR BANTAENG',
#  'AKADEMI MANAJEMEN INFORMATIKA DAN KOMPUTER KOSGORO',
#  'AKADEMI MANAJEMEN INFORMATIKA KOMPUTERISASI BINA SARANA INFORMATIKA',
#  'AKADEMI METROLOGI DAN INSTRUMENTASI',
#  'AKADEMI MINYAK DAN GAS BALONGAN',
#  'AKADEMI MINYAK DAN GAS BALONGAN INDRAMAYU',
#  'AKADEMI PARIWISATA BUNDA PADANG',
#  'AKADEMI PARIWISATA INDONESIA',
#  'AKADEMI PARIWISATA JAKARTA',
#  'AKADEMI PARIWISATA JAKARTA INTERNATIONAL HOTELS',
#  'AKADEMI PARIWISATA MAJAPAHIT',
#  'AKADEMI PARIWISATA MAKASSAR',
#  'AKADEMI PARIWISATA MEDAN',
#  'AKADEMI PARIWISATA NASIONAL INDONESIA',
#  'AKADEMI PARIWISATA NHI BANDUNG',
#  'AKADEMI PARIWISATA NUSANTARA',
#  'AKADEMI PARIWISATA PERHOTELAN DARMA AGUNG MEDAN',
#  'AKADEMI PELAYARAN NASIONAL SURAKARTA',
#  'AKADEMI PIMPINAN PERUSAHAAN',
#  'AKADEMI REFRAKSI OPTISI',
#  'AKADEMI REFRAKSI OPTISION',
#  'AKADEMI SEKRETARI BUDI LUHUR',
#  'AKADEMI SEKRETARI DAN MANAJEMEN ARIYANTI',
#  'AKADEMI TEHNIK WARGA',
#  'AKADEMI TEKNIK RADIODIAGNOSTIK DAN RADIOTERAPI YAYASAN SIHAT BEURATA BANDA ACEH',
#  'AKADEMI TEKNIK TELEKOMUNIKASI SANDHY PUTRA JAKARTA',
#  'AKADEMI TEKNOLOGI AUB SURAKARTA',
#  'AKADEMI TEKNOLOGI WARGA SURAKARTA',
#  'AKADEMI TELEKOMUNIKASI BOGOR',
#  'AKADEMI TELEVISI INDONESIA',
#  'AKADEMI TELKOM JAKARTA',
#  'AKADEMI UNIVERSITAS BINA SARANA INFORMATIKA',
#  'AKADEMIA FINANSÓW I BIZNESU VISTULA',
#  'AKAMIGAS BALONGAN',
#  'AKAMIGAS BALONGAN INDRAMAYU',
#  'AKAMIGAS CEPU',
#  'AKANU IBIAM FEDERAL POLYTECHNIC UNWANA AFIKPO EBONYI STATE NIGERIA',
#  'AKBID PRIMA HUSADA BOGOR',
#  'AKEDEMI PARIWISATA PARAMITHA',
#  'AKPAR NHI',
#  'AKPAR NHI BANDUNG',
#  'AKPAR TRISAKTI',
#  'AKPINDO',
#  'AKPRIND INSTITUTE OF SCIENCE  TECHNOLOGY',
#  'AKPRIND INSTITUTE OF SCIENCE  TECHNOLOGY YOGYAKARTA',
#  'AKPRIND INSTITUTE OF SCIENCE AND TECHNOLOGY',
#  'AKPRIND INSTITUTE OF SCIENCE AND TECHNOLOGY YOGYAKARTA',
#  'AKPRIND YOGYAKARTA INSTITUTE OF SCIENCE  TECHNOLOGY',
#  'AKRB AKADEMI KOMUNIKASI RADYA BINATAMA YOGYAKARTA',
#  'AKUNTANSI',
#  'AL  AZHAR INDONESIA UNIVERSITY',
#  'AL ALBAYT UNIVERSITY',
#  'AL ALBAYT UNIVERSITY JORDAN',
#  'AL AZHAR INDONESIA UNIVERSITY',
#  'AL AZHAR UNIVERSITY',
#  'AL AZHAR UNIVERSITY OF INDONESIA',
#  'AL AZHAR UNIVERSITY CAIRO',
#  'AL GHIFARI UNIVERSITY',
#  'ALAZHAR',
#  'ALAZHAR INDONESIA',
#  'ALAZHAR INDONESIA UNIVERSITY',
#  'ALAZHAR UNIVERSITY',
#  'ALAZHAR UNIVERSITY  FACULTY OF SCIENCE',
#  'ALAZHAR UNIVERSITY OF INDONESIA',
#  'ALMAWADDAH',
#  'ALAUDDIN ISLAMIC STATE UNIVERSITY',
#  'ALAUDDIN ISLAMIC STATE UNIVERSITY OF MAKASSAR',
#  'ALAUDDIN STATE ISLAMIC UNIVERSITY',
#  'ALAUDDIN STATE ISLAMIC UNIVERSITY OF MAKASSAR',
#  'ALAUDDIN STATE ISLAMIC UNVIRSITY OF MAKASSAR',
#  'ALETHEIA UNIVERSITY CHINA',
#  'ALIGARH MUSLIM UNIVERSITY',
#  'ALPENADRIAUNIVERSITÄT KLAGENFURT',
#  'AMA COMPUTER COLLEGE',
#  'AMBARRUKMO TOURISM INSTITUTE',
#  'AMBARRUKMO TOURISM INSTITUTE OF YOGYAKARTA',
#  'AMIK BINA SARANA INFORMATIKAAPU',
#  'AMIK BINA SARANA INFORMATIKA',
#  'AMIK BSI BANDUNG',
#  'AMIK BSI SUKABUMI',
#  'AMIK BSI TANGERANG',
#  'AMIK CITRA BUANA INDONESIA',
#  'AMIK DIAN CIPTA CENDIKIA',
#  'AMIK GARUT',
#  'AMIK MASTER LAMPUNG',
#  'AMIK MEDICOM',
#  'AMIK MEDICOM MEDAN',
#  'AMIK PN INDRAMAYU',
#  'AMIK PURNAMA NIAGA INDRAMAYU',
#  'AMIK SOLOK',
#  'AMIK TEKNOKRAT',
#  'AMIK TUNAS BANGSA',
#  'AMIK TUNAS BANGSA PEMATANGSIANTAR',
#  'AMIKOM PURWOKERTO UNIVERSITY',
#  'AMIKOM UNIVERSITY PURWOKERTO',
#  'AMIKOM UNIVERSITY YOGYAKARTA',
#  'AMIKOM YOGYAKARTA',
#  'AMIKOM YOGYAKARTA UNIVERSITY',
#  'AMITY BUSINESS SCHOOL',
#  'AMPTA TOURISM INSTITUTE STP AMPTA YOGYAKARTA',
#  'ANDALAS',
#  'ANDALAS UIVERSITY',
#  'ANDALAS UNIVERSITAS',
#  'ANDALAS UNIVERSITYI',
#  'ANDALAS UNIVERSIY',
#  'ANDALAS UNIVESITY',
#  'ANGLIA RUSKIN UNIVERSITY',
#  'ANGLIA RUSKIN UNIVERSITY  FTMS COLLEGE',
#  'ANGLO CHINESE JUNIOR COLLEGE',
#  'ANTARTIKA SENIOR HIGH SCHOOL',
#  'APCOMS',
#  'APIKES BANDUNG',
#  'APU AND STAFFORSHIRE UK  DOUBLE DEGREE',
#  'ARRANIRY ISLAMIC STATE UNIVERSITY BANDA ACEH INDONESIA',
#  'ARRANIRY STATE ISLAMIC UNIVERSITY',
#  'ARID AGRICULTURE UNIVERSITY RAWALPINDI',
#  'ARID INSTITUTE OF MANAGEMENT SCIENCES LAHORE',
#  'ARMY PUBLIC COLLEGE OF MANAGEMENT AND SCIENCES AFFILIATED WITH UET TAXILA',
#  'ARMY PUBLIC COLLEGE OF MANAGEMENT AND SCIENCES AFFILIATED WITH UNIVERSITY OF ENGINEERING AND TECHNOLOGY TAXILA',
#  'ARMY PUBLIC COLLEGE OF MANAGEMENT SCIENCES',
#  'ARS INTERNASIONAL UNIVERSITY',
#  'ARS UNIVERSITY',
#  'ARSHAD AYUB BUSINESS SCHOOL',
#  'ART AND DESIGN',
#  'ASIA E UNIVERSITY',
#  'ASIA METROPOLITAN UNIVERSITY',
#  'ASIA PACIFIC INSTITUTE OF INFORMATION TECHNOLOGY',
#  'ASIA PACIFIC INSTITUTE OF INFORMATION TECHNOLOGY KUALA LUMPUR',
#  'ASIA PACIFIC INTERNATIONAL UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY  STAFFORDSHIRE UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY STAFFORDSHIRE UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY MALAYSIA',
#  'ASIA PACIFIC UNIVERSITY OF TECHNOLOGY  INNOVATION',
#  'ASIA PACIFIC UNIVERSITY OF TECHNOLOGY  INNOVATION APU',
#  'ASIA PACIFIC UNIVERSITY OF TECHNOLOGY AND INNOVATION',
#  'ASIA PACIFIC UNIVERSITY TECHNOLOGY AND INNOVATION',
#  'ASIA PACIFIC UNIVERSITY TECHNOLOGY AND INNOVATION APU',
#  'ASIA PACIFIC UNIVERSITY KUALA LUMPUR MALAYSIA',
#  'ASIA UNIVERSITY',
#  'ASIA UNIVERSITY TAIWAN',
#  'ASIAPACIFIC INTERNATIONAL UNIVERSITY',
#  'ASIAPACIFIC INTERNATIONAL UNIVERSITY THAILAND',
#  'ASIAN BANKING FINANCE AND INFORMATICS INSTITUTE PERBANAS',
#  'ASIAN BANKING FINANCE AND INFORMATICS PERBANAS INSTITUTE',
#  'ASIAN BANKING FINANCE INFORMATICS INSTITUTE PERBANAS',
#  'ASMI SANTA MARIA YOGYAKARTA',
#  'ASSOCIATION OF CERTIFIED CHARTERED ACCOUNTANTS',
#  'ASSOCIATION OF CERTIFIED CHARTERED ACCOUNTANTS UK',
#  'ASSOCIATION OF CHARTERED CERTIFIED ACCOUNTANT ACCA',
#  'ASSOCIATION OF CHARTERED CERTIFIED ACCOUNTANTS ACCA',
#  'ASTON UNIVERSITY',
#  'ASTRAKHAN STATE TECHNICAL UNIVERSITY',
#  'ATI POLYTECHNIC PADANG',
#  'ATMA JAY CATHOLIC UNIVERSITY OF INDONESIA',
#  'ATMA JAYA',
#  'ATMA JAYA CATHOLIC INDONESIA UNIVERSITY',
#  'ATMA JAYA CATHOLIC INDONESIA UNIVERSITY JAKARTA',
#  'ATMA JAYA CATHOLIC UNIVERSITY',
#  'ATMA JAYA CATHOLIC UNIVERSITY JAKARTA',
#  'ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA JAKARTA',
#  'ATMA JAYA CATHOLIC UNVERSITY OF INDONESIA',
#  'ATMA JAYA CHATOLIC UNIVERSITY',
#  'ATMA JAYA CHATOLIC UNIVERSITY OF INDONESIA',
#  'ATMA JAYA CHATOLIC UNIVERSITY OF INDONESIA JAKARTA',
#  'ATMA JAYA JAKARTA',
#  'ATMA JAYA JAKARTA UNIVERSITY',
#  'ATMA JAYA MAKASSAR UNIVERSITY',
#  'ATMA JAYA UNIVERSITY',
#  'ATMA JAYA UNIVERSITY CATHOLIC OF INDONESIA',
#  'ATMA JAYA UNIVERSITY JAKARTA',
#  'ATMA JAYA UNIVERSITY MAKASSAR',
#  'ATMA JAYA UNIVERSITY OF YOGYAKARTA',
#  'ATMA JAYA UNIVERSITY OG JOGJAKARTA',
#  'ATMA JAYA UNIVERSITY YOGYAKARTA',
#  'ATMA JAYA UNIVESTITY',
#  'ATMA JAYA YOGYAJARTA UNIVERSITY',
#  'ATMA JAYA YOGYAKARTA',
#  'ATMA JAYA YOGYAKARTA UNIVERSITY',
#  'ATMA JAYA YOGYAKARTA UNVERSITY',
#  'ATMA JAYA YOYAKARTA UNIVERSITY',
#  'ATMAJAYA CATHOLIC UNIVERSITY',
#  'ATMAJAYA CATHOLIC UNIVERSITY OF INDONESIA',
#  'ATMAJAYA CATHOLIC UNIVERSITY YOGYAKARTA',
#  'ATMAJAYA CHATOLIC UNIVERSITY',
#  'ATMAJAYA JAKARTA',
#  'ATMAJAYA JAKARTA UNIVERSITY',
#  'ATMAJAYA UNIVERSITY',
#  'ATMAJAYA UNIVERSITY YOGYAKARTA',
#  'ATMAJAYA YOGYAKARTA',
#  'ATMI SURAKARTA',
#  'ATMJAYA CATHOLIC UNIVERSITY OF INDONESIA JAKARTA',
#  'AUCHI POLYTECHNIC AUCHI EDO STATE NIGERIA',
#  'AUCKLAND INSTITUTE OF STUDIES',
#  'AUCKLAND UNIVERSITY OF TECHNOLOGY',
#  'AVIATION POLYTECHNIC OF MAKASSAR',
#  'AVIATION POLYTECHNIC OF SURABAYA',
#  'AZZAHRA UNIVERSITY',
#  'BABSON COLLEGE',
#  'BACH KHOA UNIVERSITY',
#  'BACH KHOA UNVERSITY',
#  'BACHELOR IN BANKING',
#  'BACHELOR OF ACCOUNTING HONS',
#  'BACHELOR OF BUSINESS ADMINISTRATION HONS INTERNATIONAL BUSINESS',
#  'BADDI UNIVERSITY OF EMERGING SCIENCES AND TECHNOLOGY',
#  'BAHAUDDIN ZAKARIYA UNIVERSITY',
#  'BAHAUDDIN ZAKARIYA UNIVERSITY MULTAN',
#  'BAHAUDDIN ZAKARIYA UNIVERSITY MULTAN PAKISTAN',
#  'BAHAUDDIN ZAKRYA UNIVERSITY MULTAN',
#  'BAHAUDIN ZAKARIA UNIVERSITY MULTAN',
#  'BAHAUDIN ZAKARIYA UNIVERSITY MULTAN',
#  'BAHAUDIN ZAKRIYA UNIVERSITY MULTAN',
#  'BAHRIA UNIVERSITY',
#  'BAHRIA UNIVERSITY ISLAMABAD',
#  'BAHRIA UNIVERSITY ISLAMABAD CAMPUS',
#  'BAHRIA UNIVERSITY ISLAMABAD PAKISTAN',
#  'BAHRIA UNIVERSITY KARACHI',
#  'BAHRIA UNIVERSITY KARACHI CAMPUS',
#  'BAHUDDIN ZAKARIYA UNIVERSITY MULTAN',
#  'BAKRIE UNIVERISTY',
#  'BAKRIE UNIVERSITY',
#  'BALI STATE POLYTECHNIC',
#  'BALI TOURISM INSTITUTE',
#  'BALI TOURISM POLYTECHNIC',
#  'BALINDO PARADISO',
#  'BALOCHISTAN UNIVERSITY OF ENGINEERING AND TECHNOLOGY KHUZDAR',
#  'BALOCHISTAN UNIVERSITY OF INFORMATION TECHNOLOGY ENGINEERING AND MANAGEMENT SCIENCES',
#  'BALONGAN OIL AND GAS ACADEMY',
#  'BALUCHISTAN UNIVERSITY OF INFORMATION TECHNOLOGY ENGINEERING AND MANAGEMENT SCIENCES QUETTA',
#  'BANARAS HINDU UNIVERSITY',
#  'BANDAR LAMPUNG UNIVERSITY',
#  'BANDUNG COLLEGE OF SOCIAL WALFERE',
#  'BANDUNG COLLEGE OF SOCIAL WELFARE',
#  'BANDUNG INSITUTE OF TECHNOLOGY',
#  'BANDUNG INSTITUT OF TECHNOLOGY',
#  'BANDUNG INSTITUT OF TECHNOLOGY ITB',
#  'BANDUNG INSTITUT TECHNOLOGY',
#  'BANDUNG INSTITUTE OF SCIENCE TECHNOLOGY',
#  'BANDUNG INSTITUTE OF TACHNOLOGY',
#  'BANDUNG INSTITUTE OF TECHNOLOGHY',
#  'BANDUNG INSTITUTE OF TECHNOLOGI',
#  'BANDUNG INSTITUTE OF TECHNOLOGIES',
#  'BANDUNG INSTITUTE OF TECHNOLOGY',
#  'BANDUNG INSTITUTE OF TECHNOLOGY  ITB',
#  'BANDUNG INSTITUTE OF TECHNOLOGY ITB',
#  'BANDUNG INSTITUTE OF TECHNOLOGY BANDUNG',
#  'BANDUNG INSTITUTE OF TECHNOLOGYINSTITUT TEKNOLOGI BANDUNG',
#  'BANDUNG INSTITUTE OF TECHNOOGY',
#  'BANDUNG INSTITUTE OF TECHONOLOGY',
#  'BANDUNG INSTITUTE OF TECHONOLOGY ITB',
#  'BANDUNG INSTITUTE OF TECNOLOGY',
#  'BANDUNG INSTITUTE OF TEECHNOLOGY',
#  'BANDUNG INSTITUTE OF TOURISM',
#  'BANDUNG INSTITUTE OF TOURISM NHI',
#  'BANDUNG INSTITUTE TECHNOLOGY',
#  'BANDUNG INSTUTE OF TECHNOLOGY',
#  'BANDUNG INTITUTE OF TECHONOLOGY',
#  'BANDUNG ISLAM UNIVERSITY',
#  'BANDUNG ISLAMIC OF UNIVERSITY',
#  'BANDUNG ISLAMIC UNICERSITY',
#  'BANDUNG ISLAMIC UNIVERSITY',
#  'BANDUNG ISLAMIC UNIVERSITY UNISBA',
#  'BANDUNG ISLAMIC UNIVERSITY  UNIVERSITAS ISLAM BANDUNG',
#  'BANDUNG LAW SCHOOL',
#  'BANDUNG NATIONAL INSTITUE OF TECHNOLOGY',
#  'BANDUNG NATIONAL INSTITUTE OF TECHNOLOGY',
#  'BANDUNG OF INSTITUE TECHNOLOGY',
#  'BANDUNG OF INSTITUTE TECHNOLOGY',
#  'BANDUNG PILOT ACADEMY',
#  'BANDUNG POLYTECHNIC FOR MANUFACTURING',
#  'BANDUNG POLYTECHNIC OF MANUFACTURE',
#  'BANDUNG POLYTECHNIC OF MANUFACTURING',
#  'BANDUNG POLYTECHNIC OF SOCIAL WELFARE',
#  'BANDUNG POLYTHECHNIC OF TEXTILE TECHNOLOGY STTT',
#  'BANDUNG POLYTHECNIC SOCIAL WELFARE',
#  'BANDUNG RAYA OF UNIVERSITY',
#  'BANDUNG RAYA UNIVERSITY',
#  'BANDUNG STATE OF POLYTECHNIC',
#  'BANDUNG STATE POLYTECHNIC',
#  'BANDUNG STATE POLYTHECNIC',
#  'BANDUNG TECHNOLOGY INSTITUTE',
#  'BANDUNG TOURISM OF INSTITUTE',
#  'BANDUNG İSLAMIC UNIVERSITY',
#  'BANGALORE UNIVERSITY',
#  'BANGKA BELITUNG UNIVERSITY',
#  'BANGKOK SUVARNABHUMI COLLEGE',
#  'BANGKOK UNIVERSITY',
#  'BANGLADESH UNIVERSITY OF PROFESSIONALS',
#  'BANGOR UNIVERSITY',
#  'BANGOR UNIVERSITYMANAGEMENT DEVELOPMENT INSTITUTE OF SINGAPORE',
#  'BANKING ACADEMY OF VIETNAM',
#  'BANKING UNIVERSITY OF HO CHI MINH CITY',
#  'BANYUWANGI MARITIME ACADEMI',
#  'BATAM INTERNATIONAL UNIVERSITY',
#  'BATAM STATE POLYTECHNIC',
#  'BATAM STATE POLYTECHNICS',
#  'BATAM UNIVERSITY',
#  'BATANGHARI OF BATANGHARI',
#  'BATIK ISLAMIC UNIVERSITY OF SURAKARTA',
#  'BBPLKI SERANG',
#  'BEIHANG UNIVERSITY',
#  'BEIJING INSTITUTE OF TECHNOLOGY',
#  'BEIJING UNIVERSITY OF CHEMICAL TECHNOLOGY',
#  'BELARUSIANRUSSIAN UNIVERSITY',
#  'BENAZIR BHUTTO SHAHEED UNIVERSITY LYARI',
#  'BENGKULU UNIVERSITY',
#  'BERJAYA UNIVERSITY COLLEGE',
#  'BETHEL',
#  'BHAKTI ANINDYA',
#  'BHAKTI KENCANA UNIVERSITY',
#  'BHARATHIAR UNIVERSITY',
#  'BHARATI VIDYAPEETH DEEMED UNIVERSITY PUNE',
#  'BHAYANGKARA',
#  'BHAYANGKARA JAKARTA RAYA',
#  'BHAYANGKARA JAKARTA RAYA UNIVERSITY',
#  'BHAYANGKARA JAYA UNIVERSITY',
#  'BHAYANGKARA UNIVERSITY',
#  'BICOL UNIVERSITY',
#  'BILKENT UNIVERSITY',
#  'BIMBINGAN KONSELING',
#  'BINA BANGSA UNIVERCITY',
#  'BINA BANGSA UNIVERSITY',
#  'BINA BUSANTARA UNIVERSITY',
#  'BINA DARMA',
#  'BINA DARMA UNIVERSITY',
#  'BINA INSAN UNIVERSITY  OF LUBUKLINGGAU',
#  'BINA INSANI UNIVERSITY',
#  'BINUS UNIVERSITY',
#  'BINA NUSANTARA INTERNATIONAL UNIVERSITY  CBS INTERNATIONAL BUSINESS SCHOOL',
#  'BINA NUSANTARA UNIVERSITY  BINUS UNIVERSITY',
#  'BINA NUSANTARA UNIVERSITY  ONLINE PROGRAM',
#  'BINA NUSANTARA UNIVERSITY MALANG',
#  'BINA NUSANTARA UNIVERSITY ONLINE LEARNING',
#  'BINA NUSANTARA UNOVERSITY',
#  'BINA NUSNTARA',
#  'BINA SARANA INFOMATIKA',
#  'BINA SARANA INFORMATIKA',
#  'BINA SARANA INFORMATIKA BSI',
#  'BINA SARANA INFORMATIKA BSI BANDUNG',
#  'BINA SARANA INFORMATIKA UNIVERCITY',
#  'BINA SARANA INFORMATIKA UNIVERSITY',
#  'BINAS SARANA INFORMATIKA',
#  'BINAWAN',
#  'BINAWAN UNIVERSITY',
#  'BINUS BINA NUSANTARA UNIVERSITY',
#  'BINUS UNIVERSITAS BINA NUSANTARA',
#  'BINUS ASO SCHOOL OF ENGINEERING',
#  'BINUS BUSINESS SCHOOL',
#  'BINUS INTERNATIONAL',
#  'BINUS INTERNATIONAL UNIVERSITY',
#  'BINUS INTERNATIONAL UNIVERSITY  NINGBO UNIVERSITY',
#  'BINUS ONLINE LEARNING UNIVERSITY',
#  'BINUS SCHOOL BEKASI',
#  'BINUS SCHOOL OF BUSINESS MANAGEMENT',
#  'BINUS SCHOOL OF COMPUTER SCIENCE',
#  'BINUS UMIVERSITY',
#  'BINUS UNIVERISTY',
#  'BINUS UNIVERSITY  BUSINESS SCHOOL',
#  'BINUS UNIVERSITY ALAM SUTERA',
#  'BINUS UNIVERSITY GRADUATE PROGRAM',
#  'BINUS UNIVERSITY INTERNATIONAL',
#  'BINUS UNIVERSITY JAKARTA',
#  'BINUS UNIVERSTIY',
#  'BIOTECHNOLOGY RESEARCH INSTITUTE',
#  'BIRMINGHAM CITY UNIVERSITY',
#  'BIRMINGHAM CITY UNIVERSITY UNITED KINGDOM',
#  'BIRSA INSTITUTE OF TECHNOLOGY SINDRI',
#  'BLESSED TRINITY COLLEGE',
#  'BLK WONOGIRI',
#  'BLUE MOUNTAINS INTERNATIONAL HOTEL MANAGEMENT SCHOOL',
#  'BOGIR AGRICULTURAL UNIVERSITY',
#  'BOGOR AGRICULTULAR UNIVERSITY',
#  'BOGOR AGRICULTURAL  UNIVERSITY',
#  'BOGOR AGRICULTURAL IPB UNIVERSITY',
#  'BOGOR AGRICULTURAL INSTITUTE',
#  'BOGOR AGRICULTURAL OF UNIVERSITY',
#  'BOGOR AGRICULTURAL UNIVERCITY',
#  'BOGOR AGRICULTURAL UNIVERSIT',
#  'BOGOR AGRICULTURAL UNIVERSITY',
#  'BOGOR AGRICULTURAL UNIVERSITY IPB UNIVERSITY',
#  'BOGOR AGRICULTURAL UNIVERSITY IPB',
#  'BOGOR AGRICULTURAL UNIVERSITY  IPB',
#  'BOGOR AGRICULTURE INSTITUTE IPB',
#  'BOGOR AGRICULTURE UNIVERISTY',
#  'BOGOR AGRICULTURE UNIVERSITY',
#  'BOGOR AGRICULTURE UNIVERSITY IPB',
#  'BOGOR AGRICULURAL UNIVERSITY',
#  'BOGOR AGRICUTURAL UNIVERSITY',
#  'BOGOR INSTITUTE OF AGRICULTURE',
#  'BOGOR PAKUAN UNIVERSITY',
#  'BOGOR UNIVERSITY',
#  'BOND UNIVERISTY',
#  'BOND UNIVERSITY',
#  'BONNRHEINSIEG UNIVERSITY OF APPLIED SCIENCES',
#  'BORNEO UNIVERSITY OF TARAKAN',
#  'BOROBUDUR UNIVERSITY',
#  'BOSOWA UNIVERSITY',
#  'BOSOWA UNIVERSITY MAKASSAR',
#  'BOSTON UNIVERSITY',
#  'BOY AGRICULTURAL UNIVERSITY',
#  'BPP UNIVERSITY',
#  'BPP UNIVERSITY LONDON',
#  'BPP UNIVERSITY MANCHESTER UNITED KINGDOM',
#  'BRAC UNIVERSITY',
#  'BRAWIJAWA UNIVERSITY',
#  'BRAWIJAYA',
#  'BRAWIJAYA MALANG',
#  'BRAWIJAYA NATIONAL UNIVERSITY',
#  'BRAWIJAYA OF UNIVERSITY',
#  'BRAWIJAYA UNEVIRSITY',
#  'BRAWIJAYA UNIVERISTY',
#  'BRAWIJAYA UNIVERSITIES',
#  'BRAWIJAYA UNIVERSITU',
#  'BRAWIJAYA UNIVERSITY',
#  'BRAWIJAYA UNIVERSITY CIVIL ENGINEERING',
#  'BRAWIJAYA UNIVERSITY MALANG',
#  'BRAWIJAYA UNIVERSITY INDONESIAN',
#  'BRAWIJAYA UNIVERSITY MALANG INDONESIA',
#  'BRAWIJAYA UNIVERSTY',
#  'BRAWIJAYA UNIVESITY',
#  'BRAWIJAYA UNYVERSITY',
#  'BRAWIJAYAA UNIVERSITY',
#  'BRICKFIELDS ASIA COLLEGE',
#  'BRICKFIELDS ASIA COLLEGE UNIVERSITY OF LONDON EXTERNAL LAW PROGRAMME',
#  'BRITISH UNIVERSITY VIETNAM',
#  'BROADCASTING',
#  'BRUNEL UNIVERSITY LONDON',
#  'UNIVERSITAS BINA SARANA INFORMATIKA',
#  'BSI UNIVERSITY',
#  'BUANA PERJUANGAN KARAWANG UNIVERSITY',
#  'BUANA PERJUANGAN UNIVERSITY',
#  'BUDAPEST UNIVERSITY OF TECHNOLOGY AND ECONOMICS',
#  'BUDDHI DHARMA UNIVERSITY',
#  'BUDI LUHUR',
#  'BUDI LUHUR JAKARTA',
#  'BUDI LUHUR UNIVERCITY',
#  'BUDI LUHUR UNIVERSITY',
#  'BUDI LUHUR UNIVERSITY MAJOR COMMUNICATION SCIENCE',
#  'BUDI LUHUR UNOVERSITY',
#  'BUDI LUHUR UNVERSITY',
#  'BUDILUHUR',
#  'BUDILUHUR UNIVERSITY',
#  'BUITEMS',
#  'BUITEMS QUETTA PAKISTAN',
#  'BUNDA MULIA',
#  'BUNDA MULIA UNIVERSITT',
#  'BUNDA MULIA UNIVERSITY',
#  'BUNDA MULIIA UNIVERSITY',
#  'BUNDA MULLIA UNIVERSITY',
#  'BUNG HATTA',
#  'BUNG HATTA UNIVERSITY',
#  'BUNG HATTA UNIVESITY',
#  'BUNG KARNO UNIVERSITY',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS HOTEL MANAGEMENT SCHOOL',
#  'BUSINESS SCHOOL IPB UNIVERSITY',
#  'BZU MULTAN',
#  'CAIRO UNIVERSITY',
#  'CAIRO UNUVERSITY',
#  'CAL POLY POMONA',
#  'CALCUTTA UNIVERSITY',
#  'CALIFORNIA STATE POLYTECHNIC UNIVERSITY POMONA',
#  'CALIFORNIA STATE UNIVERSITY OF LONG BEACH',
#  'CALIFORNIA STATE UNIVERSITYFULLERTON',
#  'CAMPBELL UNIVERSITY',
#  'CAMPUS UNIVERSITAS PRAMITA',
#  'CAN THO UNIVERSITY',
#  'CANAKKALE ONSEKIZ MART UNIVERSITY',
#  'CANKAYA UNIVERSITY',
#  'CAPITAL UN IVERSITY OF SCIENCE AND TECHNOLOGY ISLAMABAD',
#  'CAPITAL UNIVERSITY OF SCIENCE  TECHNOLOGY',
#  'CAPITAL UNIVERSITY OF SCIENCE  TECHNOLOGY CUST',
#  'CAPITAL UNIVERSITY OF SCIENCE AND TECHNOLOGY',
#  'CAPITAL UNIVERSITY OF SCIENCE AND TECHNOLOGY ISLAMABAD',
#  'CARDIFF METROPOLITAN UNIVERSITY',
#  'CARDIFF UNIVERSITY',
#  'CARDIFF UNIVERSITY UK',
#  'CARDIFF UNIVESITY',
#  'CARNEGIE MELLON UNIVERSITY',
#  'CASS BUSINESS SCHOOL CITY UNIVERSITY OF LONDON',
#  'CATHOLIC PARAHYANGAN UNIVERSITY',
#  'CATHOLIC SANTO THOMAS UNIVERSITY',
#  'CATHOLIC SCHOOL OF PHILOSOPHY LEDALERO',
#  'CATHOLIC UNIVERSITY INDONESIA ATMA JAYA',
#  'CATHOLIC UNIVERSITY OF ATMA JAYA',
#  'CATHOLIC UNIVERSITY OF ATMA JAYA JAKARTA',
#  'CATHOLIC UNIVERSITY OF DE LA SALLE MANADO',
#  'CATHOLIC UNIVERSITY OF INDONESIA ATMA JAYA',
#  'CATHOLIC UNIVERSITY OF INDONESIA ATMA JAYA JAKARTA',
#  'CATHOLIC UNIVERSITY OF PARAHYANGAN',
#  'CATOLIC UNIVERSITY OF WIDYA MANDALA MADIUN',
#  'CATUR INSAN CENDEKIA UNIVERSITY',
#  'CECOS UNIVERSITY OF IT  EMERGING SCIENCES',
#  'CECOS UNIVERSITY PESHAWAR',
#  'CEME NUST',
#  'CENDERAWASIH UNIVERSITY',
#  'CENTRAL UNIVERSITY OF FINANCE AND ECONOMICS',
#  'CENTRAL WASHINGTON UNIVERSITY',
#  'CENTRO ESCOLAR UNIVERSITY',
#  'CEP CCIT FT UI',
#  'CEP CCIT FTUI',
#  'CHANDIGARH UNIVERSITY',
#  'CHANDRAGUPT INSTITUTE OF MANAGEMENT PATNA',
#  'CHANG JUNG CHRISTIAN UNIVERSITY',
#  'CHARTERED INSTITUTE OF MARKETING UNITED KINGDOM',
#  'CHATOLIC MUSI CHARITAS UNIVERSITY',
#  'CHENG SHIU UNIVERSITY',
#  'CHENG SHIU UNIVERSITY TAIWAN',
#  'CHIA NAN UNIVERSITY OF PHARMACY AND SCIENCE',
#  'CHIA NAN UNIVERSITY TAIWAN',
#  'CHICKEN',
#  'CHICKEN LITTLE',
#  'CHONGQING MEDICAL UNIVERSITY',
#  'CHONGQING UNIVERSITY OF ARTS AND SCIENCE',
#  'CHRISTIAN INDONESIA PAULUS UNIVERSITY MAKASSAR',
#  'CHRISTIAN MARANATHA UNIVERSITY',
#  'CHRISTIAN SATYA WACANA UNIVERSITY',
#  'CHRISTIAN UNIVERSITY DUTA WACANA',
#  'CHRISTIAN UNIVERSITY OF INDONESIA',
#  'CHRISTIAN UNIVERSITY OF INDONESIA TORAJA',
#  'CHRISTIAN UNIVERWSITY OF INDONESIA',
#  'CHULALONGKORN UNIVERSITY',
#  'CHULALONGKORN UNIVERSITY THAILAND',
#  'CIKRA 1',
#  'CIPUTRA',
#  'CIPUTRA UNIVERSITY',
#  'CIPUTRA UNIVERSITY SURABAYA',
#  'CITAMA MIDWIFERY ACADEMY',
#  'CITY LAW SCHOOL',
#  'CITY UNIVERSITY LONDON',
#  'CITY UNIVERSITY MALAYSIA',
#  'CITY UNIVERSITY OF MALAYSIA',
#  'CITY UNIVERSITY OF LONDON',
#  'CITY UNIVERSITY OF LONDONS BUSINESS SCHOOL',
#  'CIVIC EDUCATION',
#  'CIVIL AVIATION SAFETY AND ENGINEERING ACADEMY',
#  'COLGATE UNIVERSITY',
#  'COLLEGE OF FOREIGN ECONOMIC RELATION',
#  'COLLEGE OF FOREIGN LANGUAGE STIBA MALANG',
#  'COLLEGE OF NURSING SUBANG JAYA MEDICAL CENTRE',
#  'COLLEGE UNIVERSITY POLYTECH MARA KUALA LUMPUR',
#  'COLORADO SCHOOL OF MINES',
#  'COLORADO SCHOOL OF MINES USA',
#  'COMMERCIAL ADMINISTRATION',
#  'COMMUNCATION AND BUSINESS OF LSPR JAKARTA',
#  'COMMUNICATION',
#  'COMMUNICATION  BUSINESS INSTITUTE OF LONDON SCHOOL OF PUBLIC RELATION',
#  'COMMUNICATION  BUSINESS INSTITUTE OF LONDON SCHOOL OF PUBLIC RELATIONS',
#  'COMMUNICATION AND BUSINESS INSTITUTE LSPR JAKARTA',
#  'COMMUNICATION AND BUSINESS INSTITUTE OF LSPR JAKARTA',
#  'COMMUNICATION STUDIES',
#  'COMMUNICATION VISUAL DESIGN',
#  'COMMUNITY HEALTH NURSES TRAINING COLLEGE TAMALE',
#  'COMPUTER SCIENCE',
#  'COMPUTER UNIVERSITY',
#  'COMPUTER UNIVERSITY OF INDONESIA',
#  'COMSAT5 UNIVERSITY ISLAMABAD LAHORE CAMPUS',
#  'COMSATS INSTITUTION OF INFORMATION TECHNOLOGY',
#  'COMSATS UNIVERSITY',
#  'COMSATS UNIVERSITY ISLAMABAD',
#  'COMSATS UNIVERSITY ISLAMABAD SAHIWAL CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD  LAHORE CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD ABBOTTABAD CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD ABBOTTABAD',
#  'COMSATS UNIVERSITY ISLAMABAD ATTOCK CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD LAHORE CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD WAH CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABADLAHORE CAMPUS',
#  'COMSATS UNIVERSITY LAHORE CAMPUS',
#  'COMSATS UNIVERSITY WAH CAMPUS',
#  'COMSATS UNIVERSTY ISLAMABAD',
#  'COOPERATIVE INSTITUTE OF INDONESIA',
#  'CORNELL UNIVERSITY',
#  'COSMOPOINT COLLEGE',
#  'COTTON UNIVERSITY',
#  'COVENTRY UNIVERSITY',
#  'COVENTRY UNIVERSITY LONDON CAMPUS',
#  'COVENTRY UNIVERSITY UNITED KINGDOM',
#  'CPA AUSTRALIA',
#  'CRAWFORD UNIVERSITY',
#  'CRISTIAN UNIVERSITY OF INDONESIA',
#  'CUNY HUNTER COLLEGE',
#  'CURTIN SINGAPORE',
#  'CURTIN UNIVERSITY',
#  'CURTIN UNIVERSITY MALAYSIA',
#  'CURTIN UNIVERSITY OF TECHNOLOGY',
#  'CURTIN UNIVERSITY SINGAPORE',
#  'CURTIN UNIVERSITY SARAWAK',
#  'CYBERJAYA UNIVERSITY',
#  'CYBERNETICS INTERNATIONAL COLLEGE OF TECHNOLOGY',
#  'CYCU TAIWAN',
#  'CẦN THƠ UNIVERSITY',
#  'DA NANG UNIERSITY OF ECONOMICS',
#  'DA NANG UNIVERSITY',
#  'DA NANG UNIVERSITY OF ECONOMICS',
#  'DA NANG UNIVERSITY OF SCIENCE  TECHNOLOGY',
#  'DA NANG UNIVERSITY OF SCIENCE AND TECHNOLOGY',
#  'DA NANG UNIVERSITY OF TECHNOLOGY AND SCIENCE',
#  'DAEGU GYEONGBUK INSTITUTE OF SCIENCE AND TECHNOLOGY',
#  'DAEJEON UNIVERSITY',
#  'DALIAN UNIVERSITY OF FINANCE AND ECONOMICS',
#  'DANANG UNIVERSITY OF ECONOMICS',
#  'DARMA AGUNG UNIVERSITY',
#  'DARMA CENDIKA UNIVERSITY SURABAYA',
#  'DARMA PERSADA UNIVERSITY',
#  'DARMSTADT UNIVERSITY OF APPLIED SCIENCES',
#  'DARUL ULUM UNIVERSITY',
#  'DARUNNAJAH',
#  'DARUSSALAM GONTOR',
#  'DARUSSALAM GONTOR UNIVERSITY',
#  'DARUSSALAM GONTORUNIVERSITY',
#  'DARUSSALAM ISLAMIC HIGH SCHOOL',
#  'DAV SCHOOL OF BUSINESS MANAGEMENT',
#  'DAWOOD UET',
#  'DAWOOD UET KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING  TECHNOLOGY',
#  'DAWOOD UNIVERSITY OF ENGINEERING  TECHNOLOGY KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY  KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY KARACGI',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING TECHNOLOGY KARACHI',
#  'DE LA SALLE CATHOLIC UNIVERSITY',
#  'DE LA SALLE UNIVERSITY',
#  'DE LA SALLE UNIVERSITY MANADO',
#  'DE MONTFORT UNIVERSITY',
#  'DEAKIN UNIVERSITY',
#  'DEAKIN UNIVERSITY AUSTRALIA',
#  'DEFENSE UNIVERSITY INDONESIAN',
#  'DEFENSE UNIVERSITY OF REPUBLIC OF INDONESIA',
#  'DEL INSTITUTE OF TECHNOLOGY',
#  'DELFT UNIVERISTY OF TECHNOLOGY TU DELFT',
#  'DENMARK INSTITUE OF TECHNOLOGY',
#  'DEPARTMENT OF COMPUTER SCIENCE UNIVERSITY OF KARACHI',
#  'DESPARK COLLEGE',
#  'DHA SUFFA UNIVERSITY',
#  'DHA SUFFA UNIVERSITY KARACHI',
#  'DHARMA ANDALAS UNIVERSITY',
#  'DHARMA BUMIPUTERA SCHOOL OF ECONOMICS',
#  'DHYANA PURA BALI UNIVERSITY',
#  'DHYANA PURA UNIVERSITY',
#  'DIAN NUSWANTORO UNIVERSITY',
#  'DIAN NUSWANTORO UNIVERSITY OF SEMARANG',
#  'DICKINSON COLLEGE',
#  'DILOG TRAINING AND SERVICES',
#  'DIPENGORO UNIVERSITY',
#  'DIPINEGORO UNIVERSITY',
#  'DIPLOMATIC ACADEMY OF VIETNAM',
#  'DIPNEGORO UNIVERSITY',
#  'DIPONEGORO',
#  'DIPONEGORO  UNIVERSITY',
#  'DIPONEGORO OF UNIVERSITY',
#  'DIPONEGORO UANIVERSITY',
#  'DIPONEGORO UNIVERISTY',
#  'DIPONEGORO UNIVERSIRY',
#  'DIPONEGORO UNIVERSITY',
#  'DIPONEGORO UNIVERSITY  UNDIP ',
#  'DIPONEGORO UNIVERSITY  UNDIP',
#  'DIPONEGORO UNIVERSITY CIVIL ENGINEERING',
#  'DIPONEGORO UNIVERSITY UNDIP',
#  'DIPONEGORO UNIVERSITY UNDIP SEMARANG',
#  'DIPONEGORO UNIVERSITY UNIVERSITAS DIPONEGORO',
#  'DIPONEGORO UNIVERSITY AND JAYABAYA UNIVERSITY',
#  'DIPONEGORO UNIVERSITY COMPUTER ENGINEERING',
#  'DIPONEGORO UNIVERSITY SEMARANG',
#  'DIPONEGORO UNIVERSITY INDONESIA',
#  'DIPONEGORO UNIVERSITY SEMARANG CITY INDONESIA',
#  'DIPONEGORO UNIVESITY',
#  'DIPONEGORO UNVERSITY',
#  'DIPONEORO UNIVERSITY',
#  'DIPONGORO UNIVERSITY',
#  'DIPONOGORO UNIVERSITY',
#  'DIRGANTARA MARSEKAL SURYADARMA UNIVERSITY',
#  'DIV POLITEKNIK NEGERI MALANG',
#  'DJUANDA BOGOR UNIVVERSITY',
#  'DJUANDA UNIVERSITY',
#  'DONG NAI UNIVERSITY',
#  'DOUBLE DEGREE AT UNIVERSITY OF ARIZONA US AND SAMPOERNA UNIVERSITY JAKARTA',
#  'DOW UNIVERSITY OF HEALTH SCIENCES',
#  'DR SOETOMO UNIVERSITY',
#  'DR SOETOMO',
#  'DR SOETOMO UNIVERITY',
#  'DRB HICOM UNIVERSITY OF AUTOMOTIVE MALAYSIA',
#  'DRIYARKARA SCHOOL OF PHILOSOPHY',
#  'DUAL DEGREE PROGRAM IN SAMPOERNA UNIVERSITY AND ARIZONA UNIVERSITYITY',
#  'DUBLIN BUSINESS SCHOOL',
#  'DUBLIN BUSINESS SCHOOL IN COLLABORATION WITH KOLEJ POLYTECH MARA BANGI',
#  'DURHAM UNIVERSITY',
#  'DUTA WACANA CHRISTIAN UNIVERSITY',
#  'DUTA WACANA CHRISTIAN UNIVERSITY YOGYAKARTA',
#  'DUY TAN UNIVERSITY',
#  'DYNASTY COMPUTER',
#  'EASTERN INTERNATIONAL UNIVERSITY',
#  'EASTERN MEDITERRANEAN UNIVERSITY TURKEY',
#  'ECOLE NATIONALE SUPÉRIEURE DES INDUSTRIES CHIMIQUES ENSIC',
#  'ECONOMI',
#  'ECONOMIC',
#  'ECONOMIC AND BUSINESS',
#  'ECONOMIC AND BUSSINESS',
#  'ECONOMIC DEVELOPMENT',
#  'ECONOMIC EDUCATION',
#  'ECONOMICS',
#  'ECONOMICS AND BUSSINESS',
#  'ECONOMICS AND LAW UNIVERSITY',
#  'ECONOMICS UNIVERSITY  THE UNIVERSITY OF DANANG',
#  'ECONOMY',
#  'ECONOMY AND BUSINESS',
#  'EDINBURGH NAPIER',
#  'EDINBURGH NAPIER UNIVERSITY',
#  'EDUCATION',
#  'EDUCATION DEGREE',
#  'EDUCATION UNIVERSITY OF INDONESIAN',
#  'EFARINA UNIVERSITY',
#  'EFSEFSEF',
#  'EKONOMI',
#  'EKONOMI DAN BISNIS',
#  'EKONOMI MANAJEMEN',
#  'EKONOMI SYARIAH MANAJAMEN',
#  'EL  RAHMA EDUCATION CENTRE',
#  'EL RAHMA MALANG',
#  'ELANGOR INTERNATIONAL ISLAMIC UNIVERSITY COLLEGE',
#  'ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA',
#  'ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA EEPIS',
#  'ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA PENS',
#  'ELECTRONICS ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA',
#  'ELITE INTERNATIONAL COLLEGE',
#  'ELIZABETH INTERNATIONAL',
#  'EMBRYRIDDLE AERONAUTICAL UNIVERSITY',
#  'EMLYON BUSINESS SCHOOL',
#  'ENGINEERING',
#  'ENGLISH EDUCATION',
#  'ENGLISH LANGUAGE',
#  'ENGLISH TEACHER EDUCATION',
#  'ERASMUS UNIVERSITY  UNIVERSITAS GADJAH MADA',
#  'ERASMUS UNIVERSITY ROTTERDAM',
#  'ERCIYES UNIVERSITY',
#  'ERCIYES ÜNIVERSITESI TURKEY',
#  'ESA UNGGUL',
#  'ESA UNGGUL JAKARTA UNIVERSITY',
#  'ESA UNGGUL OF UNIVERSITY',
#  'ESA UNGGUL UNIVERSITY',
#  'ESC RENNES BUSINESS SCHOOL',
#  'ESQ BUSINESS SCHOOL',
#  'ESSEC BUSINESS SCHOOL',
#  'ESSEC BUSINESS SCHOOL SINGAPORE',
#  'EWHA WOMANS UNIVERSITY',
#  'EXTENSION EMPLOYEE PROGRAM AT MERCUBANA MENTENG',
#  'FACHHOCHSCHULE AACHEN',
#  'FACHHOCHSCHULE ERFURT',
#  'FACULTY OF ANIMAL SCIENCE GADJAH MADA UNIVERSITY',
#  'FACULTY OF ANIMAL SCIENCE UNIVERSITAS GADJAH MADA',
#  'FACULTY OF ECONOMIC AND COMMUNICATION',
#  'FACULTY OF ECONOMICS',
#  'FACULTY OF ECONOMICS AND BUSINESS UNIVERSITAS GADJAH MADA',
#  'FACULTY OF LAW UNIVERSITY OF BRAWIJAYA',
#  'FACULTY OF PSYCHOLOGY AIRLANGGA UNIVERSITY',
#  'FACULTY OF SOCIAL AND POLITIC SCIENCE',
#  'FACULTY OF TECHNOLOGY INFORMATION',
#  'FAJAR UNIVERS',
#  'FAJAR UNIVERSITY',
#  'FAJAR UNIVERSITY MAKASSAR',
#  'FAKULTAS EKONOMIKA DAN BISNIS',
#  'FAKULTAS HUKUM',
#  'FAKULTAS HUKUM UNIVERSITAS ISLAM INDONESIA',
#  'FAKULTAS HUKUM UNIVERSITAS SEBELAS MARET',
#  'FAKULTAS HUKUM UNIVERSITAS SRIWIJAYA',
#  'FAKULTAS ILMU SOSIAL ILMU POLITIK',
#  'FAKULTAS KEBUMAN DAN ENERGI',
#  'FAKULTAS KEGURUAN ILMU PENDIDIKAN',
#  'FAKULTAS KESEHATAN MASYARAKAT  UNIVERSITAS INDONESIA',
#  'FAKULTAS PENDIDIKAN ILMU SOSIAL',
#  'FAKULTAS PERTANIAN',
#  'FAKULTAS TEKNIK',
#  'FAKULTAS TEKNIK MUHAMMADIYAH JAKARTA',
#  'FAKULTAS TEKNIK UNIVERSITAS DARMA PERSADA',
#  'FAKULTAS TEKNIK UNIVERSITAS MUHAMMADIYAH JAKARTA',
#  'FAKULTAS TEKNOLOGI INFORMASI',
#  'FALCUTY OF LAW',
#  'FAR EASTERN FEDERAL UNIVERSITY',
#  'FAR EASTERN FEDERAL UNIVERSITY RUSSIA',
#  'FAR EASTERN UNIVERSITY',
#  'FARMASI',
#  'FAST NUCES',
#  'FAST NATIONAL INSTITUTE OF COMPUTER AND EMERGING SCIENCES',
#  'FAST NATIONAL UNIVERSITY OF COMPUTER  EMERGING SCIENCES',
#  'FAST NATIONAL UNIVERSITY OF COMPUTER AND EMERGING SCIENCES',
#  'FAST NUCES ISLAMABAD',
#  'FAST NUCES KARACHI',
#  'FAST NUCES LAHORE',
#  'FASTNATIONAL UNIVERSITY OF COMPUTER AND EMERGING SCIENCES',
#  'FASTNUCES',
#  'FATIMA JINNAH WOMEN UNIVERSITY',
#  'FATIMA JINNAH WOMEN UNIVERSITY RAWALPINDI',
#  'FEDERAL POLYTECHNIC ADO EKITI NIGERIA',
#  'FEDERAL UNIVERSITY OF TECHNOLOGY OWERRI',
#  'FEDERAL URDU UNIVERSITY OF ART SCIENCE AND TECHNOLOGY',
#  'FEDERAL URDU UNIVERSITY OF ARTS SCIENCE AND TECHNOLOGY',
#  'FEDERAL URDU UNIVERSITY OF ARTS SCIENCE AND TECHNOLOGY ISLAMABAD',
#  'FEDERATION UNIVERSITY AUSTRALIA',
#  'FINANCE',
#  'FINLANDIA',
#  'FISIP UPN VETERAN JAKARTA',
#  'FKIP BAHASA INGGRIS',
#  'FLINDERS UNIVERSITY SOUTH AUSTRALIA',
#  'FLORIDA INTERNATIONAL UNIVERSITY',
#  'FOON YEW ADVANCED STUDIES  NOW AS SOUTHERN UNIVERSITY COLLEGE',
#  'FOREGIN TRADE UNIVERSITY  HA NOI VIET NAM',
#  'FOREIGN TRADE UNIVERSITY',
#  'FOREIGN TRADE UNIVERSITY HCM CITY',
#  'FOREIGN TRADE UNIVERSITY IN HO CHI MINH CITY',
#  'FOREIGN TRADE UNIVERSITY HO CHI MINH CAMPUS',
#  'FORMAN CHRISTIAN COLLEGE A CHARTERED UNIVERSITY',
#  'FORMAN CHRISTIAN COLLEGE UNIVERSITY',
#  'FOUNDATION UNIVERSITY',
#  'FOUNDATION UNIVERSITY ISLAMABAD',
#  'FOUNDATION UNIVERSITY RAWALPINDI CAMPUS',
#  'FOUNDATION UNIVERSITY PAKISTAN',
#  'FPT UNIVERSITY',
#  'FPT ARENA  HCMC UNIVERSITY OF CULTURE',
#  'FPT POLY TECHNIC',
#  'FPT UNIVERSITY HO CHI MINH CITY',
#  'FRANKFURT UNIVERSITY OF APPLIED SCIENCES',
#  'FRIEDRICH SCHILLER UNIVERSITY JENA GERMANY',
#  'FT UNIVERSITAS MUHAMMADIYAH JAKARTA',
#  'FT UMJ',
#  'FTMS COLLEGE',
#  'FTMS GLOBAL COLLEGE CYBERJAYA',
#  'FUDAN UNIVERSITY',
#  'GL BAJAJ INSTITUTE OF MANAGEMENT AND RESEARCH',
#  'GADJAH MAD UNIVERSITY',
#  'GADJAH MADA',
#  'GADJAH MADA ENGINEERING',
#  'GADJAH MADA UIVERSITY',
#  'GADJAH MADA UNIVERSITY',
#  'GADJAH MADA UNIVERSITY  BRAWIJAYA UNIVERSITY',
#  'GADJAH MADA UNIVERSITY UGM',
#  'GADJAH MADA UNIVERSITY UNIVERSITAS GADJAH MADA',
#  'GADJAH MADA UNIVERSITY INDONESIA',
#  'GADJAH MADA UNIVERSITY YOGYAKARTA INDONESIA',
#  'GADJAH MADA UNIVERSOTY',
#  'GADJAH MADDA UNIVERSITY',
#  'GAJAH MADA UNIVERSITY',
#  'GAJAYANA MALANG UNIVERSITY',
#  'GAJAYANA UNIVERSITY',
#  'GAJDAH MADA UNIVERSITY',
#  'GALUH UNIVERSITY',
#  'GANESHA UNIVERSITY OF EDUCATION',
#  'GANESHA UNIVERSITY OF EDUCATIONUNDIKSHA',
#  'GARUT UNIVERSITY',
#  'GC UNIVERSITY FAISLABAD',
#  'GOVERNMENT COLLEGE UNIVERSITY FAISALABAD',
#  'GDANSK UNIVERSITY OF TECHNOLOGY',
#  'GENDERAL SOEDIRMAN UNIVERSITY',
#  'GENERAL ACHMAD YANI UNIVERSITY',
#  'GENERAL ACHMAD YANI UNIVERSITY UNJANI',
#  'GENERAL SOEDIRMAN UNIVERSITY',
#  'GEOMATIKA UNIVERSITY COLLEGE',
#  'GEORGIA INSTITUTE OF TECHNOLOGY',
#  'GEORGIA INSTITUTE OF TECHNOLOGY UNITED STATES',
#  'GERMAN MALAYSIAN INSTITUTE',
#  'GERMANMALAYSIAN INSTITUTE',
#  'GHAZI UNIVERSITY D G KHAN',
#  'GHULAM ISHAQ KHAN INSTITUTE',
#  'GHULAM ISHAQ KHAN INSTITUTE GIKI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING AND TECHNOLOGY TOPI SAWABI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCE AND TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES  TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES  TECHNOLOGY GIKI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY GIKI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY TOPI SAWABI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF SCIENCE AND TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF SCIENCE AND TECHNOLOGY SWABI',
#  'GICI BUSSINES SCHOOL',
#  'GIFU UNIVERSITY JAPAN',
#  ...]

# %%
z = []
cool = []
for x in unique_list:
  z.append(x.split())

for i in range(len(z)):
  if len(z[i]) == 0:
    continue
  
  if z[i][0].endswith('ITAS'):
    cool.append(' '.join(['UNIVERSITY'] + z[i][1:]))
  else:
    cool.append(' '.join(z[i][0:]))
cool
# Out:
# ['ANDALAS UNIVERSITY',
#  'ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA',
#  'BANDUNG POLYTECHNIC FOR MANUFACTURING POLMAN BANDUNG',
#  'HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND EDUCATION',
#  'JENDERAL SOEDIRMAN UNIVERSITY',
#  'LEGAL PROFESSION QUALIFYING BOARD',
#  'MEDAN STATE UNIVERSITY',
#  'NATIONAL INSTITUTE OF TECHNOLOGY BANDUNG',
#  'PADJAJARAN UNIVERSITY',
#  'SOLBRIDGE INTERNATIONAL SCHOOL OF BUSINESS',
#  'STATE POLYTECHNIC OF JEMBER',
#  'STATE POLYTECHNIC OF MALANG',
#  'SURABAYA STATE OF UNIVERSITY',
#  'TRILOGI UNIVERSITY',
#  'UNIVERSITY GADJAH MADA',
#  'UNIVERSITY NUSA MANDIRI',
#  'UNIVERSITY PEMBANGUNAN NASIONAL VETERAN YOGYAKARTA',
#  'UNIVERSITY OF INDONESIA',
#  'UNIVERSITY OF NORTH SUMATRA',
#  'YOGYAKARTA VETERAN NATIONAL DEVELOPMENT UNIVERSITY',
#  'ANGEL KANČEV UNIVERSITY OF RUSE',
#  'BALTAZAR ADAM KRČELIĆ COLLEGE OF BUSINESS ADMINISTRATION',
#  'CHERNORIZETS HRABAR FREE UNIVERSITY OF VARNA',
#  'DA TSENOV ACADEMY OF ECONOMICS SVISHTOV',
#  'GEORGE BARIȚIU UNIVERSITY',
#  'KONSTANTIN PRESLAVSKI SHUMEN UNIVERSITY',
#  'KRUSTYO SARAFOV NATIONAL ACADEMY FOR THEATRE AND FILM ARTS',
#  'LA GRACE UNIVERSITY ADVANCED TECHNICIANS SCHOOL OF BENIN',
#  '17 AGUSTUS 1945 JAKARTA UNIVERSITY',
#  '17 AGUSTUS 1945 UNIVERSITY',
#  '2 DEPOK SENIOR HIGH SCHOOL',
#  '23RQEWDWQ',
#  '57 SHS',
#  'A2L STIE PRASETIYA MANDIRI LAMPUNG',
#  'AACHEN UNIVERSITY OF APPLIED SCIENCE',
#  'ABBOTTABAD UNIVERSITY OF SCIENCE AND TECHNOLOGY',
#  'ABC UNI',
#  'ABDUL WALI KHAN UNIVERSITY MARDAN',
#  'ABE INTERNATIONAL BUSINESS COLLEGE',
#  'ABERYSTWYTH UNIVERSITY',
#  'ABFI INSTITUTE PERBANAS',
#  'ABFI PERBANAS',
#  'ABFII PERBANAS',
#  'ABIA STATE UNIVERSITY',
#  'ACADEMIES AUSTRALASIA INSTITUTE',
#  'ACADEMY AVIATION TRAINING CENTER',
#  'ACADEMY MARITIME CIREBON',
#  'ACADEMY METROLOGY AND INSTRUMENTATION',
#  'ACADEMY OF FINANCE VIETNAM',
#  'ACADEMY OF FOOD AND PHARMACY ANALYST PUTRA INDONESIA MALANG',
#  'ACADEMY OF HUMANITIES AND TECHNOLOGY',
#  'ACADEMY OF JOURNALISM AND COMMUNICATION',
#  'ACADEMY OF JOURNALISM AND COMMUNICATIONS',
#  'ACADEMY OF METROLOGY AND INSTRUMENTATION ITB',
#  'ACADEMY OF POLICY AND DEVELOPMENT',
#  'ACADEMY OF TOURISM NHI BANDUNG',
#  'ACADEMY OIL AND GAS BALONGAN INDRAMAYU',
#  'ASSOCIATION OF CHARTERED CERTIFIED ACCOUNTANTS',
#  'ACCOUNTING',
#  'ACCRA TECHNICAL UNIVERSITY',
#  'ADAMJEE GOVERNMENT SCIENCE COLLEGE',
#  'ADELEKE UNIVERSITY EDE OSUN STATE',
#  'ADHI TAMA INSTITUTE OF TECHNOLOGY',
#  'ADHI TAMA INSTITUTE OF TECHNOLOGY SURABAYA',
#  'ADHI TAMA SURABAYA INSTITUT OF TECHNOLOGY',
#  'ADHI TAMAINSTITUTE OF TECHNOLOGY',
#  'ADHYAKSA UNIVERSITAS ISLAM NEGERI JAMBI',
#  'ADI BUANA SURABAYA UNIVERSITY',
#  'ADI BUANA UNIVERSITY',
#  'ADISUTJIPTO COLLEGE OF TECHNOLOGY',
#  'ADISUTJIPTO COLLEGE OF TECHNOLOGY STTA',
#  'ADISUTJIPTOAEROSPACE INSTITUTE OF TECHNOLOGY',
#  'ADMINISTRASI',
#  'ADMINISTRASI PERKANTORAN',
#  'ADVANCE TERTIARY COLLEGE',
#  'ADVANCED TECHNOLOGY CENTRE ADTEC TAIPING',
#  'ADVENTIST UNIVERSITY OF INDONESIA',
#  'ADVENTIST UNIVERSITY OF THE PHILIPPINES',
#  'ADVOKAT',
#  'AFRICA INTERNATIONAL UNIVERSITY',
#  'AGRICULTURAL DEVELOPMENT POLYTECHNIC MALANG',
#  'AGRICULTURE',
#  'AGROCAMPUS WEST',
#  'AHMAD DAHLAN UNIVERSITY',
#  'AHMAD DAHLAN UNIVERSITY OF YOGYAKARTA',
#  'AHMAD DAHLAN UNIVERSITY YOGYAKARTA',
#  'AHMAD DAHLAN UNIVESITY',
#  'AIMST UNIVERSITY',
#  'AIR MARSHAL SURYADARMA UNIVERSITY',
#  'AIR UNIVERSITY',
#  'AIR UNIVERSITY ISLAMABAD',
#  'AIRALANGGA UNIVERSITY',
#  'AIRLANGGA',
#  'AIRLANGGA UNIVERSITY',
#  'AIRLANGGA BROADCAST EDUCATION',
#  'AIRLANGGA UNIVERISTY',
#  'AIRLANGGA UNIVERSITY',
#  'AIRLANGGA UNIVERSITY UNAIR',
#  'AIRLANGGA UNIVERSITY UNIVERSITAS AIRLANGGA',
#  'AIRLANGGA UNIVERSITY INDONESIA',
#  'AIRLANGGA UNIVERSITY SURABAYA',
#  'AIRLANGGA UNVERSITY',
#  'AISYIYAH YOGYAKARTA UNIVERSITY',
#  'AKADEMI PARIWISATA NHI BANDUNG',
#  'AKADEMI AKUNTANSI BUKITTINGGI',
#  'AKADEMI AKUNTANSI KEUANGAN DAN PERBANKAN INDONESIA',
#  'AKADEMI AKUNTANSI YAI',
#  'AKADEMI AKUNTANSI YAI JAKARTA',
#  'AKADEMI AKUNTANSI YAYASAN KELUARGA PAHLAWAN NEGARA',
#  'AKADEMI AKUNTANSI YKPN',
#  'AKADEMI AKUNTANSI YKPN YOGYAKARTA',
#  'AKADEMI ANALIS KESEHATAN DELIMA HUSADA GRESIK',
#  'AKADEMI BINA INSANI',
#  'AKADEMI BINA SARANA INFORMATIKA',
#  'AKADEMI BINASARANA INFORMATIKA',
#  'AKADEMI FARMASI SURABAYA',
#  'AKADEMI GIZI KARYA HUSADA KEDIRI',
#  'AKADEMI KEBIDANAN TUNAS HARAPAN BANGSA',
#  'AKADEMI KEBIDANAN WIJAYA KUSUMA MALANG',
#  'AKADEMI KEPERAWATAN HANG TUAH JAKARTA',
#  'AKADEMI KEPERAWATAN MUHAMMADIYAH MAKASSAR',
#  'AKADEMI KEPERAWATAN PEMKAB LABUHANBATU',
#  'AKADEMI KEUANGAN DAN PERBANKAN PONTIANAK',
#  'AKADEMI KIMIA ANALISIS CARAKA NUSANTARA DEPOK',
#  'AKADEMI KOMUNIKASI',
#  'AKADEMI KOMUNITAS INDUSTRI MANUFAKTUR BANTAENG',
#  'AKADEMI MANAJEMEN INFORMATIKA DAN KOMPUTER KOSGORO',
#  'AKADEMI MANAJEMEN INFORMATIKA KOMPUTERISASI BINA SARANA INFORMATIKA',
#  'AKADEMI METROLOGI DAN INSTRUMENTASI',
#  'AKADEMI MINYAK DAN GAS BALONGAN',
#  'AKADEMI MINYAK DAN GAS BALONGAN INDRAMAYU',
#  'AKADEMI PARIWISATA BUNDA PADANG',
#  'AKADEMI PARIWISATA INDONESIA',
#  'AKADEMI PARIWISATA JAKARTA',
#  'AKADEMI PARIWISATA JAKARTA INTERNATIONAL HOTELS',
#  'AKADEMI PARIWISATA MAJAPAHIT',
#  'AKADEMI PARIWISATA MAKASSAR',
#  'AKADEMI PARIWISATA MEDAN',
#  'AKADEMI PARIWISATA NASIONAL INDONESIA',
#  'AKADEMI PARIWISATA NHI BANDUNG',
#  'AKADEMI PARIWISATA NUSANTARA',
#  'AKADEMI PARIWISATA PERHOTELAN DARMA AGUNG MEDAN',
#  'AKADEMI PELAYARAN NASIONAL SURAKARTA',
#  'AKADEMI PIMPINAN PERUSAHAAN',
#  'AKADEMI REFRAKSI OPTISI',
#  'AKADEMI REFRAKSI OPTISION',
#  'AKADEMI SEKRETARI BUDI LUHUR',
#  'AKADEMI SEKRETARI DAN MANAJEMEN ARIYANTI',
#  'AKADEMI TEHNIK WARGA',
#  'AKADEMI TEKNIK RADIODIAGNOSTIK DAN RADIOTERAPI YAYASAN SIHAT BEURATA BANDA ACEH',
#  'AKADEMI TEKNIK TELEKOMUNIKASI SANDHY PUTRA JAKARTA',
#  'AKADEMI TEKNOLOGI AUB SURAKARTA',
#  'AKADEMI TEKNOLOGI WARGA SURAKARTA',
#  'AKADEMI TELEKOMUNIKASI BOGOR',
#  'AKADEMI TELEVISI INDONESIA',
#  'AKADEMI TELKOM JAKARTA',
#  'AKADEMI UNIVERSITAS BINA SARANA INFORMATIKA',
#  'AKADEMIA FINANSÓW I BIZNESU VISTULA',
#  'AKAMIGAS BALONGAN',
#  'AKAMIGAS BALONGAN INDRAMAYU',
#  'AKAMIGAS CEPU',
#  'AKANU IBIAM FEDERAL POLYTECHNIC UNWANA AFIKPO EBONYI STATE NIGERIA',
#  'AKBID PRIMA HUSADA BOGOR',
#  'AKEDEMI PARIWISATA PARAMITHA',
#  'AKPAR NHI',
#  'AKPAR NHI BANDUNG',
#  'AKPAR TRISAKTI',
#  'AKPINDO',
#  'AKPRIND INSTITUTE OF SCIENCE TECHNOLOGY',
#  'AKPRIND INSTITUTE OF SCIENCE TECHNOLOGY YOGYAKARTA',
#  'AKPRIND INSTITUTE OF SCIENCE AND TECHNOLOGY',
#  'AKPRIND INSTITUTE OF SCIENCE AND TECHNOLOGY YOGYAKARTA',
#  'AKPRIND YOGYAKARTA INSTITUTE OF SCIENCE TECHNOLOGY',
#  'AKRB AKADEMI KOMUNIKASI RADYA BINATAMA YOGYAKARTA',
#  'AKUNTANSI',
#  'AL AZHAR INDONESIA UNIVERSITY',
#  'AL ALBAYT UNIVERSITY',
#  'AL ALBAYT UNIVERSITY JORDAN',
#  'AL AZHAR INDONESIA UNIVERSITY',
#  'AL AZHAR UNIVERSITY',
#  'AL AZHAR UNIVERSITY OF INDONESIA',
#  'AL AZHAR UNIVERSITY CAIRO',
#  'AL GHIFARI UNIVERSITY',
#  'ALAZHAR',
#  'ALAZHAR INDONESIA',
#  'ALAZHAR INDONESIA UNIVERSITY',
#  'ALAZHAR UNIVERSITY',
#  'ALAZHAR UNIVERSITY FACULTY OF SCIENCE',
#  'ALAZHAR UNIVERSITY OF INDONESIA',
#  'ALMAWADDAH',
#  'ALAUDDIN ISLAMIC STATE UNIVERSITY',
#  'ALAUDDIN ISLAMIC STATE UNIVERSITY OF MAKASSAR',
#  'ALAUDDIN STATE ISLAMIC UNIVERSITY',
#  'ALAUDDIN STATE ISLAMIC UNIVERSITY OF MAKASSAR',
#  'ALAUDDIN STATE ISLAMIC UNVIRSITY OF MAKASSAR',
#  'ALETHEIA UNIVERSITY CHINA',
#  'ALIGARH MUSLIM UNIVERSITY',
#  'ALPENADRIAUNIVERSITÄT KLAGENFURT',
#  'AMA COMPUTER COLLEGE',
#  'AMBARRUKMO TOURISM INSTITUTE',
#  'AMBARRUKMO TOURISM INSTITUTE OF YOGYAKARTA',
#  'AMIK BINA SARANA INFORMATIKAAPU',
#  'AMIK BINA SARANA INFORMATIKA',
#  'AMIK BSI BANDUNG',
#  'AMIK BSI SUKABUMI',
#  'AMIK BSI TANGERANG',
#  'AMIK CITRA BUANA INDONESIA',
#  'AMIK DIAN CIPTA CENDIKIA',
#  'AMIK GARUT',
#  'AMIK MASTER LAMPUNG',
#  'AMIK MEDICOM',
#  'AMIK MEDICOM MEDAN',
#  'AMIK PN INDRAMAYU',
#  'AMIK PURNAMA NIAGA INDRAMAYU',
#  'AMIK SOLOK',
#  'AMIK TEKNOKRAT',
#  'AMIK TUNAS BANGSA',
#  'AMIK TUNAS BANGSA PEMATANGSIANTAR',
#  'AMIKOM PURWOKERTO UNIVERSITY',
#  'AMIKOM UNIVERSITY PURWOKERTO',
#  'AMIKOM UNIVERSITY YOGYAKARTA',
#  'AMIKOM YOGYAKARTA',
#  'AMIKOM YOGYAKARTA UNIVERSITY',
#  'AMITY BUSINESS SCHOOL',
#  'AMPTA TOURISM INSTITUTE STP AMPTA YOGYAKARTA',
#  'ANDALAS',
#  'ANDALAS UIVERSITY',
#  'ANDALAS UNIVERSITAS',
#  'ANDALAS UNIVERSITYI',
#  'ANDALAS UNIVERSIY',
#  'ANDALAS UNIVESITY',
#  'ANGLIA RUSKIN UNIVERSITY',
#  'ANGLIA RUSKIN UNIVERSITY FTMS COLLEGE',
#  'ANGLO CHINESE JUNIOR COLLEGE',
#  'ANTARTIKA SENIOR HIGH SCHOOL',
#  'APCOMS',
#  'APIKES BANDUNG',
#  'APU AND STAFFORSHIRE UK DOUBLE DEGREE',
#  'ARRANIRY ISLAMIC STATE UNIVERSITY BANDA ACEH INDONESIA',
#  'ARRANIRY STATE ISLAMIC UNIVERSITY',
#  'ARID AGRICULTURE UNIVERSITY RAWALPINDI',
#  'ARID INSTITUTE OF MANAGEMENT SCIENCES LAHORE',
#  'ARMY PUBLIC COLLEGE OF MANAGEMENT AND SCIENCES AFFILIATED WITH UET TAXILA',
#  'ARMY PUBLIC COLLEGE OF MANAGEMENT AND SCIENCES AFFILIATED WITH UNIVERSITY OF ENGINEERING AND TECHNOLOGY TAXILA',
#  'ARMY PUBLIC COLLEGE OF MANAGEMENT SCIENCES',
#  'ARS INTERNASIONAL UNIVERSITY',
#  'ARS UNIVERSITY',
#  'ARSHAD AYUB BUSINESS SCHOOL',
#  'ART AND DESIGN',
#  'ASIA E UNIVERSITY',
#  'ASIA METROPOLITAN UNIVERSITY',
#  'ASIA PACIFIC INSTITUTE OF INFORMATION TECHNOLOGY',
#  'ASIA PACIFIC INSTITUTE OF INFORMATION TECHNOLOGY KUALA LUMPUR',
#  'ASIA PACIFIC INTERNATIONAL UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY STAFFORDSHIRE UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY STAFFORDSHIRE UNIVERSITY',
#  'ASIA PACIFIC UNIVERSITY MALAYSIA',
#  'ASIA PACIFIC UNIVERSITY OF TECHNOLOGY INNOVATION',
#  'ASIA PACIFIC UNIVERSITY OF TECHNOLOGY INNOVATION APU',
#  'ASIA PACIFIC UNIVERSITY OF TECHNOLOGY AND INNOVATION',
#  'ASIA PACIFIC UNIVERSITY TECHNOLOGY AND INNOVATION',
#  'ASIA PACIFIC UNIVERSITY TECHNOLOGY AND INNOVATION APU',
#  'ASIA PACIFIC UNIVERSITY KUALA LUMPUR MALAYSIA',
#  'ASIA UNIVERSITY',
#  'ASIA UNIVERSITY TAIWAN',
#  'ASIAPACIFIC INTERNATIONAL UNIVERSITY',
#  'ASIAPACIFIC INTERNATIONAL UNIVERSITY THAILAND',
#  'ASIAN BANKING FINANCE AND INFORMATICS INSTITUTE PERBANAS',
#  'ASIAN BANKING FINANCE AND INFORMATICS PERBANAS INSTITUTE',
#  'ASIAN BANKING FINANCE INFORMATICS INSTITUTE PERBANAS',
#  'ASMI SANTA MARIA YOGYAKARTA',
#  'ASSOCIATION OF CERTIFIED CHARTERED ACCOUNTANTS',
#  'ASSOCIATION OF CERTIFIED CHARTERED ACCOUNTANTS UK',
#  'ASSOCIATION OF CHARTERED CERTIFIED ACCOUNTANT ACCA',
#  'ASSOCIATION OF CHARTERED CERTIFIED ACCOUNTANTS ACCA',
#  'ASTON UNIVERSITY',
#  'ASTRAKHAN STATE TECHNICAL UNIVERSITY',
#  'ATI POLYTECHNIC PADANG',
#  'ATMA JAY CATHOLIC UNIVERSITY OF INDONESIA',
#  'ATMA JAYA',
#  'ATMA JAYA CATHOLIC INDONESIA UNIVERSITY',
#  'ATMA JAYA CATHOLIC INDONESIA UNIVERSITY JAKARTA',
#  'ATMA JAYA CATHOLIC UNIVERSITY',
#  'ATMA JAYA CATHOLIC UNIVERSITY JAKARTA',
#  'ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA JAKARTA',
#  'ATMA JAYA CATHOLIC UNVERSITY OF INDONESIA',
#  'ATMA JAYA CHATOLIC UNIVERSITY',
#  'ATMA JAYA CHATOLIC UNIVERSITY OF INDONESIA',
#  'ATMA JAYA CHATOLIC UNIVERSITY OF INDONESIA JAKARTA',
#  'ATMA JAYA JAKARTA',
#  'ATMA JAYA JAKARTA UNIVERSITY',
#  'ATMA JAYA MAKASSAR UNIVERSITY',
#  'ATMA JAYA UNIVERSITY',
#  'ATMA JAYA UNIVERSITY CATHOLIC OF INDONESIA',
#  'ATMA JAYA UNIVERSITY JAKARTA',
#  'ATMA JAYA UNIVERSITY MAKASSAR',
#  'ATMA JAYA UNIVERSITY OF YOGYAKARTA',
#  'ATMA JAYA UNIVERSITY OG JOGJAKARTA',
#  'ATMA JAYA UNIVERSITY YOGYAKARTA',
#  'ATMA JAYA UNIVESTITY',
#  'ATMA JAYA YOGYAJARTA UNIVERSITY',
#  'ATMA JAYA YOGYAKARTA',
#  'ATMA JAYA YOGYAKARTA UNIVERSITY',
#  'ATMA JAYA YOGYAKARTA UNVERSITY',
#  'ATMA JAYA YOYAKARTA UNIVERSITY',
#  'ATMAJAYA CATHOLIC UNIVERSITY',
#  'ATMAJAYA CATHOLIC UNIVERSITY OF INDONESIA',
#  'ATMAJAYA CATHOLIC UNIVERSITY YOGYAKARTA',
#  'ATMAJAYA CHATOLIC UNIVERSITY',
#  'ATMAJAYA JAKARTA',
#  'ATMAJAYA JAKARTA UNIVERSITY',
#  'ATMAJAYA UNIVERSITY',
#  'ATMAJAYA UNIVERSITY YOGYAKARTA',
#  'ATMAJAYA YOGYAKARTA',
#  'ATMI SURAKARTA',
#  'ATMJAYA CATHOLIC UNIVERSITY OF INDONESIA JAKARTA',
#  'AUCHI POLYTECHNIC AUCHI EDO STATE NIGERIA',
#  'AUCKLAND INSTITUTE OF STUDIES',
#  'AUCKLAND UNIVERSITY OF TECHNOLOGY',
#  'AVIATION POLYTECHNIC OF MAKASSAR',
#  'AVIATION POLYTECHNIC OF SURABAYA',
#  'AZZAHRA UNIVERSITY',
#  'BABSON COLLEGE',
#  'BACH KHOA UNIVERSITY',
#  'BACH KHOA UNVERSITY',
#  'BACHELOR IN BANKING',
#  'BACHELOR OF ACCOUNTING HONS',
#  'BACHELOR OF BUSINESS ADMINISTRATION HONS INTERNATIONAL BUSINESS',
#  'BADDI UNIVERSITY OF EMERGING SCIENCES AND TECHNOLOGY',
#  'BAHAUDDIN ZAKARIYA UNIVERSITY',
#  'BAHAUDDIN ZAKARIYA UNIVERSITY MULTAN',
#  'BAHAUDDIN ZAKARIYA UNIVERSITY MULTAN PAKISTAN',
#  'BAHAUDDIN ZAKRYA UNIVERSITY MULTAN',
#  'BAHAUDIN ZAKARIA UNIVERSITY MULTAN',
#  'BAHAUDIN ZAKARIYA UNIVERSITY MULTAN',
#  'BAHAUDIN ZAKRIYA UNIVERSITY MULTAN',
#  'BAHRIA UNIVERSITY',
#  'BAHRIA UNIVERSITY ISLAMABAD',
#  'BAHRIA UNIVERSITY ISLAMABAD CAMPUS',
#  'BAHRIA UNIVERSITY ISLAMABAD PAKISTAN',
#  'BAHRIA UNIVERSITY KARACHI',
#  'BAHRIA UNIVERSITY KARACHI CAMPUS',
#  'BAHUDDIN ZAKARIYA UNIVERSITY MULTAN',
#  'BAKRIE UNIVERISTY',
#  'BAKRIE UNIVERSITY',
#  'BALI STATE POLYTECHNIC',
#  'BALI TOURISM INSTITUTE',
#  'BALI TOURISM POLYTECHNIC',
#  'BALINDO PARADISO',
#  'BALOCHISTAN UNIVERSITY OF ENGINEERING AND TECHNOLOGY KHUZDAR',
#  'BALOCHISTAN UNIVERSITY OF INFORMATION TECHNOLOGY ENGINEERING AND MANAGEMENT SCIENCES',
#  'BALONGAN OIL AND GAS ACADEMY',
#  'BALUCHISTAN UNIVERSITY OF INFORMATION TECHNOLOGY ENGINEERING AND MANAGEMENT SCIENCES QUETTA',
#  'BANARAS HINDU UNIVERSITY',
#  'BANDAR LAMPUNG UNIVERSITY',
#  'BANDUNG COLLEGE OF SOCIAL WALFERE',
#  'BANDUNG COLLEGE OF SOCIAL WELFARE',
#  'BANDUNG INSITUTE OF TECHNOLOGY',
#  'BANDUNG INSTITUT OF TECHNOLOGY',
#  'BANDUNG INSTITUT OF TECHNOLOGY ITB',
#  'BANDUNG INSTITUT TECHNOLOGY',
#  'BANDUNG INSTITUTE OF SCIENCE TECHNOLOGY',
#  'BANDUNG INSTITUTE OF TACHNOLOGY',
#  'BANDUNG INSTITUTE OF TECHNOLOGHY',
#  'BANDUNG INSTITUTE OF TECHNOLOGI',
#  'BANDUNG INSTITUTE OF TECHNOLOGIES',
#  'BANDUNG INSTITUTE OF TECHNOLOGY',
#  'BANDUNG INSTITUTE OF TECHNOLOGY ITB',
#  'BANDUNG INSTITUTE OF TECHNOLOGY ITB',
#  'BANDUNG INSTITUTE OF TECHNOLOGY BANDUNG',
#  'BANDUNG INSTITUTE OF TECHNOLOGYINSTITUT TEKNOLOGI BANDUNG',
#  'BANDUNG INSTITUTE OF TECHNOOGY',
#  'BANDUNG INSTITUTE OF TECHONOLOGY',
#  'BANDUNG INSTITUTE OF TECHONOLOGY ITB',
#  'BANDUNG INSTITUTE OF TECNOLOGY',
#  'BANDUNG INSTITUTE OF TEECHNOLOGY',
#  'BANDUNG INSTITUTE OF TOURISM',
#  'BANDUNG INSTITUTE OF TOURISM NHI',
#  'BANDUNG INSTITUTE TECHNOLOGY',
#  'BANDUNG INSTUTE OF TECHNOLOGY',
#  'BANDUNG INTITUTE OF TECHONOLOGY',
#  'BANDUNG ISLAM UNIVERSITY',
#  'BANDUNG ISLAMIC OF UNIVERSITY',
#  'BANDUNG ISLAMIC UNICERSITY',
#  'BANDUNG ISLAMIC UNIVERSITY',
#  'BANDUNG ISLAMIC UNIVERSITY UNISBA',
#  'BANDUNG ISLAMIC UNIVERSITY UNIVERSITAS ISLAM BANDUNG',
#  'BANDUNG LAW SCHOOL',
#  'BANDUNG NATIONAL INSTITUE OF TECHNOLOGY',
#  'BANDUNG NATIONAL INSTITUTE OF TECHNOLOGY',
#  'BANDUNG OF INSTITUE TECHNOLOGY',
#  'BANDUNG OF INSTITUTE TECHNOLOGY',
#  'BANDUNG PILOT ACADEMY',
#  'BANDUNG POLYTECHNIC FOR MANUFACTURING',
#  'BANDUNG POLYTECHNIC OF MANUFACTURE',
#  'BANDUNG POLYTECHNIC OF MANUFACTURING',
#  'BANDUNG POLYTECHNIC OF SOCIAL WELFARE',
#  'BANDUNG POLYTHECHNIC OF TEXTILE TECHNOLOGY STTT',
#  'BANDUNG POLYTHECNIC SOCIAL WELFARE',
#  'BANDUNG RAYA OF UNIVERSITY',
#  'BANDUNG RAYA UNIVERSITY',
#  'BANDUNG STATE OF POLYTECHNIC',
#  'BANDUNG STATE POLYTECHNIC',
#  'BANDUNG STATE POLYTHECNIC',
#  'BANDUNG TECHNOLOGY INSTITUTE',
#  'BANDUNG TOURISM OF INSTITUTE',
#  'BANDUNG İSLAMIC UNIVERSITY',
#  'BANGALORE UNIVERSITY',
#  'BANGKA BELITUNG UNIVERSITY',
#  'BANGKOK SUVARNABHUMI COLLEGE',
#  'BANGKOK UNIVERSITY',
#  'BANGLADESH UNIVERSITY OF PROFESSIONALS',
#  'BANGOR UNIVERSITY',
#  'BANGOR UNIVERSITYMANAGEMENT DEVELOPMENT INSTITUTE OF SINGAPORE',
#  'BANKING ACADEMY OF VIETNAM',
#  'BANKING UNIVERSITY OF HO CHI MINH CITY',
#  'BANYUWANGI MARITIME ACADEMI',
#  'BATAM INTERNATIONAL UNIVERSITY',
#  'BATAM STATE POLYTECHNIC',
#  'BATAM STATE POLYTECHNICS',
#  'BATAM UNIVERSITY',
#  'BATANGHARI OF BATANGHARI',
#  'BATIK ISLAMIC UNIVERSITY OF SURAKARTA',
#  'BBPLKI SERANG',
#  'BEIHANG UNIVERSITY',
#  'BEIJING INSTITUTE OF TECHNOLOGY',
#  'BEIJING UNIVERSITY OF CHEMICAL TECHNOLOGY',
#  'BELARUSIANRUSSIAN UNIVERSITY',
#  'BENAZIR BHUTTO SHAHEED UNIVERSITY LYARI',
#  'BENGKULU UNIVERSITY',
#  'BERJAYA UNIVERSITY COLLEGE',
#  'BETHEL',
#  'BHAKTI ANINDYA',
#  'BHAKTI KENCANA UNIVERSITY',
#  'BHARATHIAR UNIVERSITY',
#  'BHARATI VIDYAPEETH DEEMED UNIVERSITY PUNE',
#  'BHAYANGKARA',
#  'BHAYANGKARA JAKARTA RAYA',
#  'BHAYANGKARA JAKARTA RAYA UNIVERSITY',
#  'BHAYANGKARA JAYA UNIVERSITY',
#  'BHAYANGKARA UNIVERSITY',
#  'BICOL UNIVERSITY',
#  'BILKENT UNIVERSITY',
#  'BIMBINGAN KONSELING',
#  'BINA BANGSA UNIVERCITY',
#  'BINA BANGSA UNIVERSITY',
#  'BINA BUSANTARA UNIVERSITY',
#  'BINA DARMA',
#  'BINA DARMA UNIVERSITY',
#  'BINA INSAN UNIVERSITY OF LUBUKLINGGAU',
#  'BINA INSANI UNIVERSITY',
#  'BINUS UNIVERSITY',
#  'BINA NUSANTARA INTERNATIONAL UNIVERSITY CBS INTERNATIONAL BUSINESS SCHOOL',
#  'BINA NUSANTARA UNIVERSITY BINUS UNIVERSITY',
#  'BINA NUSANTARA UNIVERSITY ONLINE PROGRAM',
#  'BINA NUSANTARA UNIVERSITY MALANG',
#  'BINA NUSANTARA UNIVERSITY ONLINE LEARNING',
#  'BINA NUSANTARA UNOVERSITY',
#  'BINA NUSNTARA',
#  'BINA SARANA INFOMATIKA',
#  'BINA SARANA INFORMATIKA',
#  'BINA SARANA INFORMATIKA BSI',
#  'BINA SARANA INFORMATIKA BSI BANDUNG',
#  'BINA SARANA INFORMATIKA UNIVERCITY',
#  'BINA SARANA INFORMATIKA UNIVERSITY',
#  'BINAS SARANA INFORMATIKA',
#  'BINAWAN',
#  'BINAWAN UNIVERSITY',
#  'BINUS BINA NUSANTARA UNIVERSITY',
#  'BINUS UNIVERSITAS BINA NUSANTARA',
#  'BINUS ASO SCHOOL OF ENGINEERING',
#  'BINUS BUSINESS SCHOOL',
#  'BINUS INTERNATIONAL',
#  'BINUS INTERNATIONAL UNIVERSITY',
#  'BINUS INTERNATIONAL UNIVERSITY NINGBO UNIVERSITY',
#  'BINUS ONLINE LEARNING UNIVERSITY',
#  'BINUS SCHOOL BEKASI',
#  'BINUS SCHOOL OF BUSINESS MANAGEMENT',
#  'BINUS SCHOOL OF COMPUTER SCIENCE',
#  'BINUS UMIVERSITY',
#  'BINUS UNIVERISTY',
#  'BINUS UNIVERSITY BUSINESS SCHOOL',
#  'BINUS UNIVERSITY ALAM SUTERA',
#  'BINUS UNIVERSITY GRADUATE PROGRAM',
#  'BINUS UNIVERSITY INTERNATIONAL',
#  'BINUS UNIVERSITY JAKARTA',
#  'BINUS UNIVERSTIY',
#  'BIOTECHNOLOGY RESEARCH INSTITUTE',
#  'BIRMINGHAM CITY UNIVERSITY',
#  'BIRMINGHAM CITY UNIVERSITY UNITED KINGDOM',
#  'BIRSA INSTITUTE OF TECHNOLOGY SINDRI',
#  'BLESSED TRINITY COLLEGE',
#  'BLK WONOGIRI',
#  'BLUE MOUNTAINS INTERNATIONAL HOTEL MANAGEMENT SCHOOL',
#  'BOGIR AGRICULTURAL UNIVERSITY',
#  'BOGOR AGRICULTULAR UNIVERSITY',
#  'BOGOR AGRICULTURAL UNIVERSITY',
#  'BOGOR AGRICULTURAL IPB UNIVERSITY',
#  'BOGOR AGRICULTURAL INSTITUTE',
#  'BOGOR AGRICULTURAL OF UNIVERSITY',
#  'BOGOR AGRICULTURAL UNIVERCITY',
#  'BOGOR AGRICULTURAL UNIVERSIT',
#  'BOGOR AGRICULTURAL UNIVERSITY',
#  'BOGOR AGRICULTURAL UNIVERSITY IPB UNIVERSITY',
#  'BOGOR AGRICULTURAL UNIVERSITY IPB',
#  'BOGOR AGRICULTURAL UNIVERSITY IPB',
#  'BOGOR AGRICULTURE INSTITUTE IPB',
#  'BOGOR AGRICULTURE UNIVERISTY',
#  'BOGOR AGRICULTURE UNIVERSITY',
#  'BOGOR AGRICULTURE UNIVERSITY IPB',
#  'BOGOR AGRICULURAL UNIVERSITY',
#  'BOGOR AGRICUTURAL UNIVERSITY',
#  'BOGOR INSTITUTE OF AGRICULTURE',
#  'BOGOR PAKUAN UNIVERSITY',
#  'BOGOR UNIVERSITY',
#  'BOND UNIVERISTY',
#  'BOND UNIVERSITY',
#  'BONNRHEINSIEG UNIVERSITY OF APPLIED SCIENCES',
#  'BORNEO UNIVERSITY OF TARAKAN',
#  'BOROBUDUR UNIVERSITY',
#  'BOSOWA UNIVERSITY',
#  'BOSOWA UNIVERSITY MAKASSAR',
#  'BOSTON UNIVERSITY',
#  'BOY AGRICULTURAL UNIVERSITY',
#  'BPP UNIVERSITY',
#  'BPP UNIVERSITY LONDON',
#  'BPP UNIVERSITY MANCHESTER UNITED KINGDOM',
#  'BRAC UNIVERSITY',
#  'BRAWIJAWA UNIVERSITY',
#  'BRAWIJAYA',
#  'BRAWIJAYA MALANG',
#  'BRAWIJAYA NATIONAL UNIVERSITY',
#  'BRAWIJAYA OF UNIVERSITY',
#  'BRAWIJAYA UNEVIRSITY',
#  'BRAWIJAYA UNIVERISTY',
#  'BRAWIJAYA UNIVERSITIES',
#  'BRAWIJAYA UNIVERSITU',
#  'BRAWIJAYA UNIVERSITY',
#  'BRAWIJAYA UNIVERSITY CIVIL ENGINEERING',
#  'BRAWIJAYA UNIVERSITY MALANG',
#  'BRAWIJAYA UNIVERSITY INDONESIAN',
#  'BRAWIJAYA UNIVERSITY MALANG INDONESIA',
#  'BRAWIJAYA UNIVERSTY',
#  'BRAWIJAYA UNIVESITY',
#  'BRAWIJAYA UNYVERSITY',
#  'BRAWIJAYAA UNIVERSITY',
#  'BRICKFIELDS ASIA COLLEGE',
#  'BRICKFIELDS ASIA COLLEGE UNIVERSITY OF LONDON EXTERNAL LAW PROGRAMME',
#  'BRITISH UNIVERSITY VIETNAM',
#  'BROADCASTING',
#  'BRUNEL UNIVERSITY LONDON',
#  'UNIVERSITY BINA SARANA INFORMATIKA',
#  'BSI UNIVERSITY',
#  'BUANA PERJUANGAN KARAWANG UNIVERSITY',
#  'BUANA PERJUANGAN UNIVERSITY',
#  'BUDAPEST UNIVERSITY OF TECHNOLOGY AND ECONOMICS',
#  'BUDDHI DHARMA UNIVERSITY',
#  'BUDI LUHUR',
#  'BUDI LUHUR JAKARTA',
#  'BUDI LUHUR UNIVERCITY',
#  'BUDI LUHUR UNIVERSITY',
#  'BUDI LUHUR UNIVERSITY MAJOR COMMUNICATION SCIENCE',
#  'BUDI LUHUR UNOVERSITY',
#  'BUDI LUHUR UNVERSITY',
#  'BUDILUHUR',
#  'BUDILUHUR UNIVERSITY',
#  'BUITEMS',
#  'BUITEMS QUETTA PAKISTAN',
#  'BUNDA MULIA',
#  'BUNDA MULIA UNIVERSITT',
#  'BUNDA MULIA UNIVERSITY',
#  'BUNDA MULIIA UNIVERSITY',
#  'BUNDA MULLIA UNIVERSITY',
#  'BUNG HATTA',
#  'BUNG HATTA UNIVERSITY',
#  'BUNG HATTA UNIVESITY',
#  'BUNG KARNO UNIVERSITY',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS HOTEL MANAGEMENT SCHOOL',
#  'BUSINESS SCHOOL IPB UNIVERSITY',
#  'BZU MULTAN',
#  'CAIRO UNIVERSITY',
#  'CAIRO UNUVERSITY',
#  'CAL POLY POMONA',
#  'CALCUTTA UNIVERSITY',
#  'CALIFORNIA STATE POLYTECHNIC UNIVERSITY POMONA',
#  'CALIFORNIA STATE UNIVERSITY OF LONG BEACH',
#  'CALIFORNIA STATE UNIVERSITYFULLERTON',
#  'CAMPBELL UNIVERSITY',
#  'CAMPUS UNIVERSITAS PRAMITA',
#  'CAN THO UNIVERSITY',
#  'CANAKKALE ONSEKIZ MART UNIVERSITY',
#  'CANKAYA UNIVERSITY',
#  'CAPITAL UN IVERSITY OF SCIENCE AND TECHNOLOGY ISLAMABAD',
#  'CAPITAL UNIVERSITY OF SCIENCE TECHNOLOGY',
#  'CAPITAL UNIVERSITY OF SCIENCE TECHNOLOGY CUST',
#  'CAPITAL UNIVERSITY OF SCIENCE AND TECHNOLOGY',
#  'CAPITAL UNIVERSITY OF SCIENCE AND TECHNOLOGY ISLAMABAD',
#  'CARDIFF METROPOLITAN UNIVERSITY',
#  'CARDIFF UNIVERSITY',
#  'CARDIFF UNIVERSITY UK',
#  'CARDIFF UNIVESITY',
#  'CARNEGIE MELLON UNIVERSITY',
#  'CASS BUSINESS SCHOOL CITY UNIVERSITY OF LONDON',
#  'CATHOLIC PARAHYANGAN UNIVERSITY',
#  'CATHOLIC SANTO THOMAS UNIVERSITY',
#  'CATHOLIC SCHOOL OF PHILOSOPHY LEDALERO',
#  'CATHOLIC UNIVERSITY INDONESIA ATMA JAYA',
#  'CATHOLIC UNIVERSITY OF ATMA JAYA',
#  'CATHOLIC UNIVERSITY OF ATMA JAYA JAKARTA',
#  'CATHOLIC UNIVERSITY OF DE LA SALLE MANADO',
#  'CATHOLIC UNIVERSITY OF INDONESIA ATMA JAYA',
#  'CATHOLIC UNIVERSITY OF INDONESIA ATMA JAYA JAKARTA',
#  'CATHOLIC UNIVERSITY OF PARAHYANGAN',
#  'CATOLIC UNIVERSITY OF WIDYA MANDALA MADIUN',
#  'CATUR INSAN CENDEKIA UNIVERSITY',
#  'CECOS UNIVERSITY OF IT EMERGING SCIENCES',
#  'CECOS UNIVERSITY PESHAWAR',
#  'CEME NUST',
#  'CENDERAWASIH UNIVERSITY',
#  'CENTRAL UNIVERSITY OF FINANCE AND ECONOMICS',
#  'CENTRAL WASHINGTON UNIVERSITY',
#  'CENTRO ESCOLAR UNIVERSITY',
#  'CEP CCIT FT UI',
#  'CEP CCIT FTUI',
#  'CHANDIGARH UNIVERSITY',
#  'CHANDRAGUPT INSTITUTE OF MANAGEMENT PATNA',
#  'CHANG JUNG CHRISTIAN UNIVERSITY',
#  'CHARTERED INSTITUTE OF MARKETING UNITED KINGDOM',
#  'CHATOLIC MUSI CHARITAS UNIVERSITY',
#  'CHENG SHIU UNIVERSITY',
#  'CHENG SHIU UNIVERSITY TAIWAN',
#  'CHIA NAN UNIVERSITY OF PHARMACY AND SCIENCE',
#  'CHIA NAN UNIVERSITY TAIWAN',
#  'CHICKEN',
#  'CHICKEN LITTLE',
#  'CHONGQING MEDICAL UNIVERSITY',
#  'CHONGQING UNIVERSITY OF ARTS AND SCIENCE',
#  'CHRISTIAN INDONESIA PAULUS UNIVERSITY MAKASSAR',
#  'CHRISTIAN MARANATHA UNIVERSITY',
#  'CHRISTIAN SATYA WACANA UNIVERSITY',
#  'CHRISTIAN UNIVERSITY DUTA WACANA',
#  'CHRISTIAN UNIVERSITY OF INDONESIA',
#  'CHRISTIAN UNIVERSITY OF INDONESIA TORAJA',
#  'CHRISTIAN UNIVERWSITY OF INDONESIA',
#  'CHULALONGKORN UNIVERSITY',
#  'CHULALONGKORN UNIVERSITY THAILAND',
#  'CIKRA 1',
#  'CIPUTRA',
#  'CIPUTRA UNIVERSITY',
#  'CIPUTRA UNIVERSITY SURABAYA',
#  'CITAMA MIDWIFERY ACADEMY',
#  'CITY LAW SCHOOL',
#  'CITY UNIVERSITY LONDON',
#  'CITY UNIVERSITY MALAYSIA',
#  'CITY UNIVERSITY OF MALAYSIA',
#  'CITY UNIVERSITY OF LONDON',
#  'CITY UNIVERSITY OF LONDONS BUSINESS SCHOOL',
#  'CIVIC EDUCATION',
#  'CIVIL AVIATION SAFETY AND ENGINEERING ACADEMY',
#  'COLGATE UNIVERSITY',
#  'COLLEGE OF FOREIGN ECONOMIC RELATION',
#  'COLLEGE OF FOREIGN LANGUAGE STIBA MALANG',
#  'COLLEGE OF NURSING SUBANG JAYA MEDICAL CENTRE',
#  'COLLEGE UNIVERSITY POLYTECH MARA KUALA LUMPUR',
#  'COLORADO SCHOOL OF MINES',
#  'COLORADO SCHOOL OF MINES USA',
#  'COMMERCIAL ADMINISTRATION',
#  'COMMUNCATION AND BUSINESS OF LSPR JAKARTA',
#  'COMMUNICATION',
#  'COMMUNICATION BUSINESS INSTITUTE OF LONDON SCHOOL OF PUBLIC RELATION',
#  'COMMUNICATION BUSINESS INSTITUTE OF LONDON SCHOOL OF PUBLIC RELATIONS',
#  'COMMUNICATION AND BUSINESS INSTITUTE LSPR JAKARTA',
#  'COMMUNICATION AND BUSINESS INSTITUTE OF LSPR JAKARTA',
#  'COMMUNICATION STUDIES',
#  'COMMUNICATION VISUAL DESIGN',
#  'COMMUNITY HEALTH NURSES TRAINING COLLEGE TAMALE',
#  'COMPUTER SCIENCE',
#  'COMPUTER UNIVERSITY',
#  'COMPUTER UNIVERSITY OF INDONESIA',
#  'COMSAT5 UNIVERSITY ISLAMABAD LAHORE CAMPUS',
#  'COMSATS INSTITUTION OF INFORMATION TECHNOLOGY',
#  'COMSATS UNIVERSITY',
#  'COMSATS UNIVERSITY ISLAMABAD',
#  'COMSATS UNIVERSITY ISLAMABAD SAHIWAL CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD LAHORE CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD ABBOTTABAD CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD ABBOTTABAD',
#  'COMSATS UNIVERSITY ISLAMABAD ATTOCK CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD LAHORE CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABAD WAH CAMPUS',
#  'COMSATS UNIVERSITY ISLAMABADLAHORE CAMPUS',
#  'COMSATS UNIVERSITY LAHORE CAMPUS',
#  'COMSATS UNIVERSITY WAH CAMPUS',
#  'COMSATS UNIVERSTY ISLAMABAD',
#  'COOPERATIVE INSTITUTE OF INDONESIA',
#  'CORNELL UNIVERSITY',
#  'COSMOPOINT COLLEGE',
#  'COTTON UNIVERSITY',
#  'COVENTRY UNIVERSITY',
#  'COVENTRY UNIVERSITY LONDON CAMPUS',
#  'COVENTRY UNIVERSITY UNITED KINGDOM',
#  'CPA AUSTRALIA',
#  'CRAWFORD UNIVERSITY',
#  'CRISTIAN UNIVERSITY OF INDONESIA',
#  'CUNY HUNTER COLLEGE',
#  'CURTIN SINGAPORE',
#  'CURTIN UNIVERSITY',
#  'CURTIN UNIVERSITY MALAYSIA',
#  'CURTIN UNIVERSITY OF TECHNOLOGY',
#  'CURTIN UNIVERSITY SINGAPORE',
#  'CURTIN UNIVERSITY SARAWAK',
#  'CYBERJAYA UNIVERSITY',
#  'CYBERNETICS INTERNATIONAL COLLEGE OF TECHNOLOGY',
#  'CYCU TAIWAN',
#  'CẦN THƠ UNIVERSITY',
#  'DA NANG UNIERSITY OF ECONOMICS',
#  'DA NANG UNIVERSITY',
#  'DA NANG UNIVERSITY OF ECONOMICS',
#  'DA NANG UNIVERSITY OF SCIENCE TECHNOLOGY',
#  'DA NANG UNIVERSITY OF SCIENCE AND TECHNOLOGY',
#  'DA NANG UNIVERSITY OF TECHNOLOGY AND SCIENCE',
#  'DAEGU GYEONGBUK INSTITUTE OF SCIENCE AND TECHNOLOGY',
#  'DAEJEON UNIVERSITY',
#  'DALIAN UNIVERSITY OF FINANCE AND ECONOMICS',
#  'DANANG UNIVERSITY OF ECONOMICS',
#  'DARMA AGUNG UNIVERSITY',
#  'DARMA CENDIKA UNIVERSITY SURABAYA',
#  'DARMA PERSADA UNIVERSITY',
#  'DARMSTADT UNIVERSITY OF APPLIED SCIENCES',
#  'DARUL ULUM UNIVERSITY',
#  'DARUNNAJAH',
#  'DARUSSALAM GONTOR',
#  'DARUSSALAM GONTOR UNIVERSITY',
#  'DARUSSALAM GONTORUNIVERSITY',
#  'DARUSSALAM ISLAMIC HIGH SCHOOL',
#  'DAV SCHOOL OF BUSINESS MANAGEMENT',
#  'DAWOOD UET',
#  'DAWOOD UET KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING TECHNOLOGY',
#  'DAWOOD UNIVERSITY OF ENGINEERING TECHNOLOGY KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY KARACGI',
#  'DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY KARACHI',
#  'DAWOOD UNIVERSITY OF ENGINEERING TECHNOLOGY KARACHI',
#  'DE LA SALLE CATHOLIC UNIVERSITY',
#  'DE LA SALLE UNIVERSITY',
#  'DE LA SALLE UNIVERSITY MANADO',
#  'DE MONTFORT UNIVERSITY',
#  'DEAKIN UNIVERSITY',
#  'DEAKIN UNIVERSITY AUSTRALIA',
#  'DEFENSE UNIVERSITY INDONESIAN',
#  'DEFENSE UNIVERSITY OF REPUBLIC OF INDONESIA',
#  'DEL INSTITUTE OF TECHNOLOGY',
#  'DELFT UNIVERISTY OF TECHNOLOGY TU DELFT',
#  'DENMARK INSTITUE OF TECHNOLOGY',
#  'DEPARTMENT OF COMPUTER SCIENCE UNIVERSITY OF KARACHI',
#  'DESPARK COLLEGE',
#  'DHA SUFFA UNIVERSITY',
#  'DHA SUFFA UNIVERSITY KARACHI',
#  'DHARMA ANDALAS UNIVERSITY',
#  'DHARMA BUMIPUTERA SCHOOL OF ECONOMICS',
#  'DHYANA PURA BALI UNIVERSITY',
#  'DHYANA PURA UNIVERSITY',
#  'DIAN NUSWANTORO UNIVERSITY',
#  'DIAN NUSWANTORO UNIVERSITY OF SEMARANG',
#  'DICKINSON COLLEGE',
#  'DILOG TRAINING AND SERVICES',
#  'DIPENGORO UNIVERSITY',
#  'DIPINEGORO UNIVERSITY',
#  'DIPLOMATIC ACADEMY OF VIETNAM',
#  'DIPNEGORO UNIVERSITY',
#  'DIPONEGORO',
#  'DIPONEGORO UNIVERSITY',
#  'DIPONEGORO OF UNIVERSITY',
#  'DIPONEGORO UANIVERSITY',
#  'DIPONEGORO UNIVERISTY',
#  'DIPONEGORO UNIVERSIRY',
#  'DIPONEGORO UNIVERSITY',
#  'DIPONEGORO UNIVERSITY UNDIP',
#  'DIPONEGORO UNIVERSITY UNDIP',
#  'DIPONEGORO UNIVERSITY CIVIL ENGINEERING',
#  'DIPONEGORO UNIVERSITY UNDIP',
#  'DIPONEGORO UNIVERSITY UNDIP SEMARANG',
#  'DIPONEGORO UNIVERSITY UNIVERSITAS DIPONEGORO',
#  'DIPONEGORO UNIVERSITY AND JAYABAYA UNIVERSITY',
#  'DIPONEGORO UNIVERSITY COMPUTER ENGINEERING',
#  'DIPONEGORO UNIVERSITY SEMARANG',
#  'DIPONEGORO UNIVERSITY INDONESIA',
#  'DIPONEGORO UNIVERSITY SEMARANG CITY INDONESIA',
#  'DIPONEGORO UNIVESITY',
#  'DIPONEGORO UNVERSITY',
#  'DIPONEORO UNIVERSITY',
#  'DIPONGORO UNIVERSITY',
#  'DIPONOGORO UNIVERSITY',
#  'DIRGANTARA MARSEKAL SURYADARMA UNIVERSITY',
#  'DIV POLITEKNIK NEGERI MALANG',
#  'DJUANDA BOGOR UNIVVERSITY',
#  'DJUANDA UNIVERSITY',
#  'DONG NAI UNIVERSITY',
#  'DOUBLE DEGREE AT UNIVERSITY OF ARIZONA US AND SAMPOERNA UNIVERSITY JAKARTA',
#  'DOW UNIVERSITY OF HEALTH SCIENCES',
#  'DR SOETOMO UNIVERSITY',
#  'DR SOETOMO',
#  'DR SOETOMO UNIVERITY',
#  'DRB HICOM UNIVERSITY OF AUTOMOTIVE MALAYSIA',
#  'DRIYARKARA SCHOOL OF PHILOSOPHY',
#  'DUAL DEGREE PROGRAM IN SAMPOERNA UNIVERSITY AND ARIZONA UNIVERSITYITY',
#  'DUBLIN BUSINESS SCHOOL',
#  'DUBLIN BUSINESS SCHOOL IN COLLABORATION WITH KOLEJ POLYTECH MARA BANGI',
#  'DURHAM UNIVERSITY',
#  'DUTA WACANA CHRISTIAN UNIVERSITY',
#  'DUTA WACANA CHRISTIAN UNIVERSITY YOGYAKARTA',
#  'DUY TAN UNIVERSITY',
#  'DYNASTY COMPUTER',
#  'EASTERN INTERNATIONAL UNIVERSITY',
#  'EASTERN MEDITERRANEAN UNIVERSITY TURKEY',
#  'ECOLE NATIONALE SUPÉRIEURE DES INDUSTRIES CHIMIQUES ENSIC',
#  'ECONOMI',
#  'ECONOMIC',
#  'ECONOMIC AND BUSINESS',
#  'ECONOMIC AND BUSSINESS',
#  'ECONOMIC DEVELOPMENT',
#  'ECONOMIC EDUCATION',
#  'ECONOMICS',
#  'ECONOMICS AND BUSSINESS',
#  'ECONOMICS AND LAW UNIVERSITY',
#  'ECONOMICS UNIVERSITY THE UNIVERSITY OF DANANG',
#  'ECONOMY',
#  'ECONOMY AND BUSINESS',
#  'EDINBURGH NAPIER',
#  'EDINBURGH NAPIER UNIVERSITY',
#  'EDUCATION',
#  'EDUCATION DEGREE',
#  'EDUCATION UNIVERSITY OF INDONESIAN',
#  'EFARINA UNIVERSITY',
#  'EFSEFSEF',
#  'EKONOMI',
#  'EKONOMI DAN BISNIS',
#  'EKONOMI MANAJEMEN',
#  'EKONOMI SYARIAH MANAJAMEN',
#  'EL RAHMA EDUCATION CENTRE',
#  'EL RAHMA MALANG',
#  'ELANGOR INTERNATIONAL ISLAMIC UNIVERSITY COLLEGE',
#  'ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA',
#  'ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA EEPIS',
#  'ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA PENS',
#  'ELECTRONICS ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA',
#  'ELITE INTERNATIONAL COLLEGE',
#  'ELIZABETH INTERNATIONAL',
#  'EMBRYRIDDLE AERONAUTICAL UNIVERSITY',
#  'EMLYON BUSINESS SCHOOL',
#  'ENGINEERING',
#  'ENGLISH EDUCATION',
#  'ENGLISH LANGUAGE',
#  'ENGLISH TEACHER EDUCATION',
#  'ERASMUS UNIVERSITY UNIVERSITAS GADJAH MADA',
#  'ERASMUS UNIVERSITY ROTTERDAM',
#  'ERCIYES UNIVERSITY',
#  'ERCIYES ÜNIVERSITESI TURKEY',
#  'ESA UNGGUL',
#  'ESA UNGGUL JAKARTA UNIVERSITY',
#  'ESA UNGGUL OF UNIVERSITY',
#  'ESA UNGGUL UNIVERSITY',
#  'ESC RENNES BUSINESS SCHOOL',
#  'ESQ BUSINESS SCHOOL',
#  'ESSEC BUSINESS SCHOOL',
#  'ESSEC BUSINESS SCHOOL SINGAPORE',
#  'EWHA WOMANS UNIVERSITY',
#  'EXTENSION EMPLOYEE PROGRAM AT MERCUBANA MENTENG',
#  'FACHHOCHSCHULE AACHEN',
#  'FACHHOCHSCHULE ERFURT',
#  'FACULTY OF ANIMAL SCIENCE GADJAH MADA UNIVERSITY',
#  'FACULTY OF ANIMAL SCIENCE UNIVERSITAS GADJAH MADA',
#  'FACULTY OF ECONOMIC AND COMMUNICATION',
#  'FACULTY OF ECONOMICS',
#  'FACULTY OF ECONOMICS AND BUSINESS UNIVERSITAS GADJAH MADA',
#  'FACULTY OF LAW UNIVERSITY OF BRAWIJAYA',
#  'FACULTY OF PSYCHOLOGY AIRLANGGA UNIVERSITY',
#  'FACULTY OF SOCIAL AND POLITIC SCIENCE',
#  'FACULTY OF TECHNOLOGY INFORMATION',
#  'FAJAR UNIVERS',
#  'FAJAR UNIVERSITY',
#  'FAJAR UNIVERSITY MAKASSAR',
#  'FAKULTAS EKONOMIKA DAN BISNIS',
#  'FAKULTAS HUKUM',
#  'FAKULTAS HUKUM UNIVERSITAS ISLAM INDONESIA',
#  'FAKULTAS HUKUM UNIVERSITAS SEBELAS MARET',
#  'FAKULTAS HUKUM UNIVERSITAS SRIWIJAYA',
#  'FAKULTAS ILMU SOSIAL ILMU POLITIK',
#  'FAKULTAS KEBUMAN DAN ENERGI',
#  'FAKULTAS KEGURUAN ILMU PENDIDIKAN',
#  'FAKULTAS KESEHATAN MASYARAKAT UNIVERSITAS INDONESIA',
#  'FAKULTAS PENDIDIKAN ILMU SOSIAL',
#  'FAKULTAS PERTANIAN',
#  'FAKULTAS TEKNIK',
#  'FAKULTAS TEKNIK MUHAMMADIYAH JAKARTA',
#  'FAKULTAS TEKNIK UNIVERSITAS DARMA PERSADA',
#  'FAKULTAS TEKNIK UNIVERSITAS MUHAMMADIYAH JAKARTA',
#  'FAKULTAS TEKNOLOGI INFORMASI',
#  'FALCUTY OF LAW',
#  'FAR EASTERN FEDERAL UNIVERSITY',
#  'FAR EASTERN FEDERAL UNIVERSITY RUSSIA',
#  'FAR EASTERN UNIVERSITY',
#  'FARMASI',
#  'FAST NUCES',
#  'FAST NATIONAL INSTITUTE OF COMPUTER AND EMERGING SCIENCES',
#  'FAST NATIONAL UNIVERSITY OF COMPUTER EMERGING SCIENCES',
#  'FAST NATIONAL UNIVERSITY OF COMPUTER AND EMERGING SCIENCES',
#  'FAST NUCES ISLAMABAD',
#  'FAST NUCES KARACHI',
#  'FAST NUCES LAHORE',
#  'FASTNATIONAL UNIVERSITY OF COMPUTER AND EMERGING SCIENCES',
#  'FASTNUCES',
#  'FATIMA JINNAH WOMEN UNIVERSITY',
#  'FATIMA JINNAH WOMEN UNIVERSITY RAWALPINDI',
#  'FEDERAL POLYTECHNIC ADO EKITI NIGERIA',
#  'FEDERAL UNIVERSITY OF TECHNOLOGY OWERRI',
#  'FEDERAL URDU UNIVERSITY OF ART SCIENCE AND TECHNOLOGY',
#  'FEDERAL URDU UNIVERSITY OF ARTS SCIENCE AND TECHNOLOGY',
#  'FEDERAL URDU UNIVERSITY OF ARTS SCIENCE AND TECHNOLOGY ISLAMABAD',
#  'FEDERATION UNIVERSITY AUSTRALIA',
#  'FINANCE',
#  'FINLANDIA',
#  'FISIP UPN VETERAN JAKARTA',
#  'FKIP BAHASA INGGRIS',
#  'FLINDERS UNIVERSITY SOUTH AUSTRALIA',
#  'FLORIDA INTERNATIONAL UNIVERSITY',
#  'FOON YEW ADVANCED STUDIES NOW AS SOUTHERN UNIVERSITY COLLEGE',
#  'FOREGIN TRADE UNIVERSITY HA NOI VIET NAM',
#  'FOREIGN TRADE UNIVERSITY',
#  'FOREIGN TRADE UNIVERSITY HCM CITY',
#  'FOREIGN TRADE UNIVERSITY IN HO CHI MINH CITY',
#  'FOREIGN TRADE UNIVERSITY HO CHI MINH CAMPUS',
#  'FORMAN CHRISTIAN COLLEGE A CHARTERED UNIVERSITY',
#  'FORMAN CHRISTIAN COLLEGE UNIVERSITY',
#  'FOUNDATION UNIVERSITY',
#  'FOUNDATION UNIVERSITY ISLAMABAD',
#  'FOUNDATION UNIVERSITY RAWALPINDI CAMPUS',
#  'FOUNDATION UNIVERSITY PAKISTAN',
#  'FPT UNIVERSITY',
#  'FPT ARENA HCMC UNIVERSITY OF CULTURE',
#  'FPT POLY TECHNIC',
#  'FPT UNIVERSITY HO CHI MINH CITY',
#  'FRANKFURT UNIVERSITY OF APPLIED SCIENCES',
#  'FRIEDRICH SCHILLER UNIVERSITY JENA GERMANY',
#  'FT UNIVERSITAS MUHAMMADIYAH JAKARTA',
#  'FT UMJ',
#  'FTMS COLLEGE',
#  'FTMS GLOBAL COLLEGE CYBERJAYA',
#  'FUDAN UNIVERSITY',
#  'GL BAJAJ INSTITUTE OF MANAGEMENT AND RESEARCH',
#  'GADJAH MAD UNIVERSITY',
#  'GADJAH MADA',
#  'GADJAH MADA ENGINEERING',
#  'GADJAH MADA UIVERSITY',
#  'GADJAH MADA UNIVERSITY',
#  'GADJAH MADA UNIVERSITY BRAWIJAYA UNIVERSITY',
#  'GADJAH MADA UNIVERSITY UGM',
#  'GADJAH MADA UNIVERSITY UNIVERSITAS GADJAH MADA',
#  'GADJAH MADA UNIVERSITY INDONESIA',
#  'GADJAH MADA UNIVERSITY YOGYAKARTA INDONESIA',
#  'GADJAH MADA UNIVERSOTY',
#  'GADJAH MADDA UNIVERSITY',
#  'GAJAH MADA UNIVERSITY',
#  'GAJAYANA MALANG UNIVERSITY',
#  'GAJAYANA UNIVERSITY',
#  'GAJDAH MADA UNIVERSITY',
#  'GALUH UNIVERSITY',
#  'GANESHA UNIVERSITY OF EDUCATION',
#  'GANESHA UNIVERSITY OF EDUCATIONUNDIKSHA',
#  'GARUT UNIVERSITY',
#  'GC UNIVERSITY FAISLABAD',
#  'GOVERNMENT COLLEGE UNIVERSITY FAISALABAD',
#  'GDANSK UNIVERSITY OF TECHNOLOGY',
#  'GENDERAL SOEDIRMAN UNIVERSITY',
#  'GENERAL ACHMAD YANI UNIVERSITY',
#  'GENERAL ACHMAD YANI UNIVERSITY UNJANI',
#  'GENERAL SOEDIRMAN UNIVERSITY',
#  'GEOMATIKA UNIVERSITY COLLEGE',
#  'GEORGIA INSTITUTE OF TECHNOLOGY',
#  'GEORGIA INSTITUTE OF TECHNOLOGY UNITED STATES',
#  'GERMAN MALAYSIAN INSTITUTE',
#  'GERMANMALAYSIAN INSTITUTE',
#  'GHAZI UNIVERSITY D G KHAN',
#  'GHULAM ISHAQ KHAN INSTITUTE',
#  'GHULAM ISHAQ KHAN INSTITUTE GIKI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING AND TECHNOLOGY TOPI SAWABI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCE AND TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES TECHNOLOGY GIKI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY GIKI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY TOPI SAWABI',
#  'GHULAM ISHAQ KHAN INSTITUTE OF SCIENCE AND TECHNOLOGY',
#  'GHULAM ISHAQ KHAN INSTITUTE OF SCIENCE AND TECHNOLOGY SWABI',
#  'GICI BUSSINES SCHOOL',
#  'GIFU UNIVERSITY JAPAN',
#  ...]

# %%
unique_list=pd.DataFrame(cool)
unique_list.columns=['school_name']

unique_list=pd.DataFrame(unique_list['school_name'].unique()) #Unique again after changing language

# %%
unique_list.columns=['school_names']
unique_list
# Out:
#                                            school_names
# 0                                    ANDALAS UNIVERSITY
# 1            ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA
# 2     BANDUNG POLYTECHNIC FOR MANUFACTURING POLMAN B...
# 3     HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND ...
# 4                         JENDERAL SOEDIRMAN UNIVERSITY
# ...                                                 ...
# 9275                           ĐẠI HỌC BÁCH KHOA HÀ NỘI
# 9276                                  ĐẠI HỌC CÔNG ĐOÀN
# 9277                        ĐẠI HỌC TÀI CHÍNH MARKETING
# 9278                         IMG SRCJAVASCRIPTALERTTEST
# 9279                               東洋大学 TOYO UNIVERSITY
#
# [9280 rows x 1 columns]

# %%
#Save cleaned names to a csv

unique_list.to_csv('unique_list.csv')

# %% [markdown]
# ##Clean the scraped list of unis

# %%
uniname = pd.read_csv('/content/universities_list.txt', delimiter =",", header=None, names=["uni_names"])
#listuniname = pd.DataFrame(remove_punct(listuniname))

# %%
seriesuniname=uniname.squeeze()
#remove_punct(listuniname)

# %%
seriesuniname
# Out:
# 0                                                        [
# 1                      '"Angel Kančev" University of Ruse'
# 2          '"Baltazar Adam Krčelić" College of Business...
# 3          '"Chernorizets Hrabar"  Free University of V...
# 4          '"D.A. Tsenov" Academy of Economics - Svishtov'
#                                ...
# 17345                         'Zumbi dos Palmares Faculty'
# 17346                              'Zunyi Medical College'
# 17347                               'Zunyi Normal College'
# 17348                                    'Zuyd University'
# 17349                                                    ]
# Name: uni_names, Length: 17350, dtype: object

# %%
new_list1 = []
for x in seriesuniname:
      new_list1.append(x.strip())

df8= new_list1

# %%
uninamesnopunct=pd.DataFrame(remove_punct(df8))
uninamesnopunct
# Out:
#                                                        0
# 0
# 1                        Angel Kančev University of Ruse
# 2      Baltazar Adam Krčelić College of Business Admi...
# 3          Chernorizets Hrabar  Free University of Varna
# 4               DA Tsenov Academy of Economics  Svishtov
# ...                                                  ...
# 17345                         Zumbi dos Palmares Faculty
# 17346                              Zunyi Medical College
# 17347                               Zunyi Normal College
# 17348                                    Zuyd University
# 17349
#
# [17350 rows x 1 columns]

# %%
uninamesnopunct.replace([""], np.nan, inplace=True)
cleanuninames=uninamesnopunct.dropna()
cleanuninames.columns=['UniNames']
cleanuninames
# Out:
#                                                 UniNames
# 1                        Angel Kančev University of Ruse
# 2      Baltazar Adam Krčelić College of Business Admi...
# 3          Chernorizets Hrabar  Free University of Varna
# 4               DA Tsenov Academy of Economics  Svishtov
# 5                              George Barițiu University
# ...                                                  ...
# 17344                        Zugdidi Teaching University
# 17345                         Zumbi dos Palmares Faculty
# 17346                              Zunyi Medical College
# 17347                               Zunyi Normal College
# 17348                                    Zuyd University
#
# [17348 rows x 1 columns]

# %%
#Save cleaned scraped uni list

cleanuninames.to_csv('cleanuninames.csv')

# %% [markdown]
# #Use FuzzyWuzzy only, to match dataset names with list names

# %% [markdown]
# ##FuzzyWuzzy matching the dataset names with scraped list

# %%
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.7/dist-packages (0.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein) (57.4.0)

# %%
from fuzzywuzzy import fuzz
from tqdm import tqdm

# %%
data1=unique_list.copy()
data2=cleanuninames.copy()
name_match = []

# %%
df1_names = list(unique_list.school_names)
df2_match = list(cleanuninames.UniNames)

# %%
#Defining a function to return the match and similarity score of the fuzz.ratio() scorer. 
#The function will take in a term(name), list of terms(list_names), and a minimum similarity score(min_score) to return the match. 

def match_names(name, list_names, min_score=0):
  max_score=-1
  max_name=''
  for x in list_names:
    score=fuzz.token_sort_ratio(name, x)
    if (score > min_score) & (score > max_score):
      max_name = x
      max_score = score
  return (max_name, max_score)

# %%
#For loop to create a list of tuples with the first value being the name from the 
#second dataframe (name to replace) and the second value from the 
#first dataframe (string replacing the name value). Then, casting the list of tuples as a dictionary. 

names = []
for x in tqdm(df1_names):
  match = match_names(x, df2_match, 75)
  if match[1] >=75:
    name = (str(x), str(match[0]))
    names.append(name)
    
name_dict=dict(names)
name_dict

# %%
name_dict.keys()

# %%
#data10=data1["school_names"].map(name_dict)
data10=pd.DataFrame(data1["school_names"].map(name_dict)) #mapping together unique list with the dict
data10

# %%
fuzz.token_sort_ratio('UNIVERSITY OF KENT','Kent University')
# Out:
# 91

# %%
#Save dict to a file
dictionary = name_dict
  
try:
    geeky_file = open('/content/name_dict.txt', 'wt')
    geeky_file.write(str(dictionary))
    geeky_file.close()
  
except:
    print("Unable to write to file")

# %% [markdown]
# ##Reading dict .txt files saved from previous run

# %%
# importing the module
import ast
  
# reading the data from the file
with open('/content/name_dict.txt') as f:
    data = f.read()
  
print("Data type before reconstruction : ", type(data))
      
# reconstructing the data as a dictionary
name_dict = ast.literal_eval(data)
  
print("Data type after reconstruction : ", type(name_dict))
print(name_dict)

# %% [markdown]
# ##Checking Fuzzy list with unique_list

# %%
#data10=data1["school_names"].map(name_dict)
data60=pd.DataFrame(deduplipydf["school_names"].map(d_60))
data60

# %%
compared_60 = pd.concat([deduplipydf, data60], axis=1, join='inner')
compared_60

# %%
compared_60.to_csv("combined_65-5.1k.csv")

# %% [markdown]
# #Deuplipy attempt

# %% [markdown]
# ##Deduplipy for clustering school names of dataset

# %%
#https://deduplipy.readthedocs.io/en/latest/api/deduplicator.html
# !pip install deduplipy

# %%
from deduplipy.deduplicator import Deduplicator
from thefuzz.fuzz import ratio, partial_ratio, token_set_ratio, token_sort_ratio

# %%
#try with uninames with list
data1=unique_list.copy()
data2=cleanuninames.copy()
data2=data2.rename(columns={'UniNames': 'school_names'})
df_predict=pd.concat([data1, data2], ignore_index=True)

#Couldn't use this before, used too much RAM and crashed

# %%
#df_train=cleanuninames.copy()
df_predict=unique_list.copy()

# %%
field_info = {'school_names':[token_set_ratio,token_sort_ratio]}

# %%
myDedupliPy = Deduplicator(field_info=field_info, interaction=True, verbose=1)

# %%
myDedupliPy.fit(df_predict)
# Out:
# Nr. 1 (0+/0-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    KONSTANTIN PRESLAVSKI SHUMEN UNIVERSITY
# -> school_names_2    KONSTANTIN PRESLAVSKI SHUMEN UNIVERSITY
# Y
#
# Nr. 2 (1+/0-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    AKBID PRIMA HUSADA BOGOR
# -> school_names_2    AKBID PRIMA HUSADA BOGOR
# y
#
# Nr. 3 (2+/0-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BANDUNG COLLEGE OF SOCIAL WALFERE
# -> school_names_2    BANDUNG COLLEGE OF SOCIAL WALFERE
# y
#
# Nr. 4 (3+/0-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    KONSTANTIN PRESLAVSKI SHUMEN UNIVERSITY
# -> school_names_2    AKBID PRIMA HUSADA BOGOR
# n
#
# Nr. 5 (3+/1-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUTE AGAMA ISLAM NEGERI KUDUS
# -> school_names_2    MASTER OF LAW UNIVERSITY OF SYIAH KUALA
# n
#
# Nr. 6 (3+/2-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BINUS UNIVERSITY INTERNATIONAL
# -> school_names_2    INTERNATIONAL UNIVERSITY OF MALAYA WALES
# n
#
# Nr. 7 (3+/3-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BEIHANG UNIVERSITY
# -> school_names_2    NIRMA UNIVERSITY
# n
#
# Nr. 8 (3+/4-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    HELO UNIVERSITY
# -> school_names_2    TROY UNIVERSITY
# n
#
# Nr. 9 (3+/5-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BOGOR UNIVERSITY
# -> school_names_2    UNIVERSITY OF
# n
#
# Nr. 10 (3+/6-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NIRMA UNIVERSITY
# -> school_names_2    UNIVERSITY GUNDARMA
# n
#
# Nr. 11 (3+/7-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH MALANG UNIVERSITY
# -> school_names_2    UNIVERSITY MUHAMMADIYAH
# y
# Last uncertainty improvement: 0.003
# Uncertainty: 0.489
# Classifier converged, enter 'f' to stop training
#
# Nr. 12 (4+/7-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    RESPATI INDONESIA OF UNIVERSITY
# -> school_names_2    UNIVERSITY OF PRIMA INDONESIA
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.499
#
# Nr. 13 (4+/8-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    DAWOOD UNIVERSITY OF ENGINEERING AND TECHNOLOGY
# -> school_names_2    MEHRAN UNIVERSITY OF ENGINEERING AND TECHNOLOGY
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.497
#
# Nr. 14 (4+/9-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NANJING UNIVERSITY OF INFORMATION SCIENCE AND TECHNOLOGY
# -> school_names_2    SARHAD UNIVERSITY OF SCIENCE AND INFORMATION TECHNOLOGY
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.499
#
# Nr. 15 (4+/10-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    CIPUTRA UNIVERSITY
# -> school_names_2    UNIVERSITY CIPUTRA SURABAYA
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.499
#
# Nr. 16 (5+/10-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY PUTRA INDONESIA YPTK PADANGC
# -> school_names_2    UNIVERSITY PUTRA INDONESIA UPI
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.499
#
# Nr. 17 (6+/10-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    STATE ISLAMIC UNIVERSITY SULTAN SYARIF KASIM RIAU
# -> school_names_2    SULTAN SHARIF KASIM STATE ISLAMIC UNIVERSITY
# y
# Last uncertainty improvement: 0.003
# Uncertainty: 0.496
# Classifier converged, enter 'f' to stop training
#
# Nr. 18 (7+/10-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    HCM UNIVERSITY OF SCIENCE
# -> school_names_2    NATIONAL UNIVERSITY OF SCIENCE AND TECHNOLOGYNUST
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.491
# Classifier converged, enter 'f' to stop training
#
# Nr. 19 (7+/11-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    JEMBER OF UNIVERSITY
# -> school_names_2    UNIVERSITY NEGERI JEMBER
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 20 (8+/11-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SEKOLAH TINGGI ILMU EKONOMI DWIMULYA
# -> school_names_2    SEKOLAH TINGGI ILMU EKONOMI IBBI
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 21 (9+/11-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF LAKE DARIEN
# -> school_names_2    UNIVERSITY OF LAKE KATRINE
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.500
# Classifier converged, enter 'f' to stop training
#
# Nr. 22 (9+/12-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITIT ILMU SOSIAL DAN ILMU POLITIK JAKARTA
# -> school_names_2    INSTITUT ILMU SOSIAL DAN ILMU POLITIK IISIP JAKARTA
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 23 (10+/12-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIV MUHAMMADIYAH SIDOARJO
# -> school_names_2    UNIVERSITY MUHAMMADIYAH SIDOARJO
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.500
# Classifier converged, enter 'f' to stop training
#
# Nr. 24 (11+/12-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SEKOLAH TINGGI ILMU EKONOMI IBBI
# -> school_names_2    SEKOLAH TINGGI ILMU EKONOMI MIFTAHUL HUDA
# y
# Last uncertainty improvement: 0.001
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 25 (12+/12-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING AND TECHNOLOGY TOPI SAWABI
# -> school_names_2    GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY GIKI
# y
# Last uncertainty improvement: 0.001
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 26 (13+/12-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    QUAIDEAWAM UNIVERSITY OF ENGINEERING SCIENCE AND TECHNOLOGY
# -> school_names_2    QUAIDEAWAM UNIVERSITY OF SCIENCE AND TECHNOLOGY NAWABSHAH
# y
# Last uncertainty improvement: 0.001
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 27 (14+/12-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ALDA
# -> school_names_2    UNIVERSITY OF EAST ELTA
# n
# Last uncertainty improvement: 0.002
# Uncertainty: 0.497
# Classifier converged, enter 'f' to stop training
#
# Nr. 28 (14+/13-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NEW SOUTH WALES UNSW AUSTRALIA
# -> school_names_2    UNIVERSITY OF NEW SOUTH WALES UNSW SYDNEY
# y
# Last uncertainty improvement: 0.002
# Uncertainty: 0.498
# Classifier converged, enter 'f' to stop training
#
# Nr. 29 (15+/13-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    HO CHI MINH CITY INTERNATIONAL UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.002
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 30 (15+/14-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ELTA
# -> school_names_2    UNIVERSITY OF EAST LINDSAY
# n
# Last uncertainty improvement: 0.002
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 31 (15+/15-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY PRIMA INDONESIA MEDAN
# n
# Last uncertainty improvement: 0.002
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 32 (15+/16-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PELITA HARAPAN UNIVERSITY UPH
# -> school_names_2    UNIVERSITY PELITA HARAPAN RMIT UNIVERSITY
# y
# Last uncertainty improvement: 0.001
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 33 (16+/16-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    FPT UNIVERSITY HO CHI MINH CITY
# -> school_names_2    HO CHI MINH CITY UNIVERSITY OF TRANSPORT
# n
# Last uncertainty improvement: 0.001
# Uncertainty: 0.500
# Classifier converged, enter 'f' to stop training
#
# Nr. 34 (16+/17-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BANDUNG RAYA UNIVERSITY
# -> school_names_2    UNIVERSITY ILAM BANDUNG
# n
# Last uncertainty improvement: 0.002
# Uncertainty: 0.497
# Classifier converged, enter 'f' to stop training
#
# Nr. 35 (16+/18-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SRIWIJAYA
# -> school_names_2    SRIWIJAYA UNIVERSITAS
# y
# Last uncertainty improvement: 0.002
# Uncertainty: 0.498
# Classifier converged, enter 'f' to stop training
#
# Nr. 36 (17+/18-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SEKOLAH TINGGI ILMU EKONOMI GICI
# -> school_names_2    SEKOLAH TINGGI ILMU EKONOMI SURAKARTA
# y
# Last uncertainty improvement: 0.002
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 37 (18+/18-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    LIVERPOOL JOHN MORES UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.495
# Classifier converged, enter 'f' to stop training
#
# Nr. 38 (18+/19-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF PELITA HARAPAN
# -> school_names_2    UNIVERSITY PELITA HARAPAN RMIT UNIVERSITY
# y
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 39 (19+/19-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SENIOR HIGH SCHOOL 3
# -> school_names_2    SENIOR HIGH SCHOOL 6 SOUTH TANGERANG
# y
# Last uncertainty improvement: 0.004
# Uncertainty: 0.496
# Classifier converged, enter 'f' to stop training
#
# Nr. 40 (20+/19-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH UNIVERSITY OF KENDARI
# -> school_names_2    UNIVERSITY OF MUHAMMADIYAH MALAG
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.497
# Classifier converged, enter 'f' to stop training
#
# Nr. 41 (20+/20-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    OPEN UNIVERSITY OF MALAYSIA
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.493
# Classifier converged, enter 'f' to stop training
#
# Nr. 42 (20+/21-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSI
# -> school_names_2    UNIVERSITY
# y
# Last uncertainty improvement: 0.004
# Uncertainty: 0.497
# Classifier converged, enter 'f' to stop training
#
# Nr. 43 (21+/21-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY
# -> school_names_2    UNIVERSITY OF MERCUBUANA
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 44 (21+/22-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MILITARY INSTITUTE OF SCIENCE AND TECHNOLOGY
# -> school_names_2    NATIONAL INSTITUTE OF SCIENCE AND TECHNOLOGY
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 45 (21+/23-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NORTH SUMATERA UTARA UNIVERSITY
# -> school_names_2    UNIVERSITY SUMATERA UTARA MEDAN
# y
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 46 (22+/23-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SYIAH KUALA UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.495
# Classifier converged, enter 'f' to stop training
#
# Nr. 47 (22+/24-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SMA NEGERI 9 JAKARTA
# -> school_names_2    SMK NEGERI 40 JAKARTA
# y
# Last uncertainty improvement: 0.005
# Uncertainty: 0.500
# Classifier converged, enter 'f' to stop training
#
# Nr. 48 (23+/24-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    CHENG SHIU UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.496
# Classifier converged, enter 'f' to stop training
#
# Nr. 49 (23+/25-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIA OPEN UNIVERSITY
# -> school_names_2    UNIVERSITY TERBUKA INDONESIA
# y
# Last uncertainty improvement: 0.005
# Uncertainty: 0.496
# Classifier converged, enter 'f' to stop training
#
# Nr. 50 (24+/25-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERISITI TEKNOLOGI MALAYSIA
# -> school_names_2    UNIVERSITY TECHNOLOGY MALAYSIA
# y
# Last uncertainty improvement: 0.005
# Uncertainty: 0.500
# Classifier converged, enter 'f' to stop training
#
# Nr. 51 (25+/25-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    POLYTECHNIC STATE OF PADANG
# -> school_names_2    STATE POLYTECHNIC OF MEDAN
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 52 (25+/26-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    CHRISTIAN UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY OF NORTH CHRISTIAN
# y
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 53 (26+/26-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MEHRAN UNIVERSITY OF ENGINEERING TECHNOLOGY
# -> school_names_2    UNIVERSITY OF ENGINEERING TECHNOLOGY UETPESHAWAR
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 54 (26+/27-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY ISLAM NEGERI UIN SUNAN GUNUNG DJATI BANDUNG
# -> school_names_2    UNIVERSITY ISLAM NEGERI SUNAN GUNUNGDJATI BANDUNG
# y
# Last uncertainty improvement: 0.004
# Uncertainty: 0.496
# Classifier converged, enter 'f' to stop training
#
# Nr. 55 (27+/27-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ALDA
# -> school_names_2    UNIVERSITY OF EAST ANTWON
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 56 (27+/28-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NEW BOYD
# -> school_names_2    UNIVERSITY OF NEW BRAEDEN
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.500
# Classifier converged, enter 'f' to stop training
#
# Nr. 57 (27+/29-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ALDA
# -> school_names_2    UNIVERSITY OF EAST CARAPORT
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.498
# Classifier converged, enter 'f' to stop training
#
# Nr. 58 (27+/30-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIA OPEN UNIVERSITY
# -> school_names_2    RESPATI INDONESIA UNIVERSITY
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.495
# Classifier converged, enter 'f' to stop training
#
# Nr. 59 (27+/31-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH MALANG OF UNIVERSITY
# -> school_names_2    UNIVERSITY OF MUHAMMADIYAH GRESIK
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 60 (27+/32-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SEKOLAH TINGGI ILMU EKONOMI IBBI
# -> school_names_2    SEKOLAH TINGGI ILMU EKONOMI SURAKARTA
# y
# Last uncertainty improvement: 0.006
# Uncertainty: 0.493
# Classifier converged, enter 'f' to stop training
#
# Nr. 61 (28+/32-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH SURAKARTA OF UNIVERSITY
# -> school_names_2    UNIVERSITY OF MUHAMMADIYAH JAKARTA
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 62 (28+/33-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUT AGAMA ISLAM NEGERI
# -> school_names_2    INSTITUT AGAMA ISLAM NEGERI IAIN SYEKH NURJATI CIREBON
# y
# Last uncertainty improvement: 0.006
# Uncertainty: 0.495
# Classifier converged, enter 'f' to stop training
#
# Nr. 63 (29+/33-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    THANG LONG UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.496
# Classifier converged, enter 'f' to stop training
#
# Nr. 64 (29+/34-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NATIONAL UNIVERSITY OF SCIENCE AND TECHNOLOGY NUST
# -> school_names_2    NORWEGIAN UNIVERSITY OF TECHNOLOGY AND SCIENCE
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.492
# Classifier converged, enter 'f' to stop training
#
# Nr. 65 (29+/35-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF SURABAYA
# -> school_names_2    WIDYA MANDALA CATHOLIC UNIVERSITY OF SURABAYA
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.500
# Classifier converged, enter 'f' to stop training
#
# Nr. 66 (29+/36-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    GUNADARNA UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.497
# Classifier converged, enter 'f' to stop training
#
# Nr. 67 (29+/37-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    ISLAMIC UNIVESITY OF INDONESIA
# -> school_names_2    UNIVERSITY MUSLIM OF INDONESIA
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.497
# Classifier converged, enter 'f' to stop training
#
# Nr. 68 (29+/38-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NATIONAL UNVERSITY OF SCIENCE AND TECHNOLOGY NUST
# -> school_names_2    NATIONAL YUNLIN UNIVERSITY OF SCIENCE AND TECHNOLOGY
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.489
# Classifier converged, enter 'f' to stop training
#
# Nr. 69 (29+/39-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    STIE YAI
# -> school_names_2    STIE YAI JAKARTA
# y
# Last uncertainty improvement: 0.010
# Uncertainty: 0.499
#
# Nr. 70 (30+/39-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY NEGERI SURABAYA TEKNIK SIPIL
# -> school_names_2    UNIVERSITY SURABAYA
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.497
#
# Nr. 71 (30+/40-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SENIOR HIGH SCHOOL
# -> school_names_2    SENIOR HIGH SCHOOL 6 SOUTH TANGERANG
# y
# Last uncertainty improvement: 0.010
# Uncertainty: 0.492
#
# Nr. 72 (31+/40-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY BANDUNG RAYA
# -> school_names_2    UNIVERSITY ILAM BANDUNG
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.498
#
# Nr. 73 (31+/41-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NORTH ONA
# -> school_names_2    UNIVERSITY OF NORTH RODERICK
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.500
#
# Nr. 74 (31+/42-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INTERNATIONAL ISLAMIC UNIVERSITY
# -> school_names_2    INTERNATIONAL MEDICAL UNIVERSITY
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.495
# Classifier converged, enter 'f' to stop training
#
# Nr. 75 (31+/43-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PANCASAKTI UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.496
# Classifier converged, enter 'f' to stop training
#
# Nr. 76 (31+/44-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BUITEMS
# -> school_names_2    MADIUN
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.497
# Classifier converged, enter 'f' to stop training
#
# Nr. 77 (31+/45-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY BRAWIJAYA BRAWIJAYA UNIVERSITY
# -> school_names_2    UNIVERSITY OF BRAWIJAYA
# y
# Last uncertainty improvement: 0.004
# Uncertainty: 0.494
# Classifier converged, enter 'f' to stop training
#
# Nr. 78 (32+/45-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF CARMENBOROUGH
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.494
# Classifier converged, enter 'f' to stop training
#
# Nr. 79 (32+/46-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY PENDIDIKAN INDONESIA
# -> school_names_2    UNIVERSITY PENDIDIKAN INDONESIA INDONESIA UNIVERSITY OF EDUCATION
# y
# Last uncertainty improvement: 0.003
# Uncertainty: 0.490
# Classifier converged, enter 'f' to stop training
#
# Nr. 80 (33+/46-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SATYA WACANA CRISTIAN UNIVERSITY
# -> school_names_2    UNIVERSITY OF KRISTEN SATYA WACANA
# y
# Last uncertainty improvement: 0.003
# Uncertainty: 0.490
# Classifier converged, enter 'f' to stop training
#
# Nr. 81 (34+/46-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SRIWIJAYA UNIVERSITY
# -> school_names_2    SRIWIJAYA UNIVERSITY UNIVERSITAS SRIWIJAYA
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.499
# Classifier converged, enter 'f' to stop training
#
# Nr. 82 (35+/46-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    JAKARTA UNIVERSITY
# -> school_names_2    UNIVERSITY BHAYANGKARA OF JAKARTA RAYA
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.498
# Classifier converged, enter 'f' to stop training
#
# Nr. 83 (35+/47-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY
# -> school_names_2    UNIVERSITY OF VISALIA
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.494
# Classifier converged, enter 'f' to stop training
#
# Nr. 84 (35+/48-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BRAWIJAYA UNIVERSITY
# -> school_names_2    UNIVERSITY BRAWIJAYA BRAWIJAYA UNIVERSITY
# y
# Last uncertainty improvement: 0.010
# Uncertainty: 0.484
#
# Nr. 85 (36+/48-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY PEKALONGAN
# -> school_names_2    UNIVERSITY MUHAMMADIYAH PEKAJANGAN PEKALONGAN
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.485
#
# Nr. 86 (36+/49-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY BRAWIJAYA
# -> school_names_2    UNIVERSITY BRAWIJAYA BRAWIJAYA UNIVERSITY
# y
# Last uncertainty improvement: 0.010
# Uncertainty: 0.479
#
# Nr. 87 (37+/49-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST HOLLY
# -> school_names_2    UNIVERSITY OF WEST KILEY
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.487
#
# Nr. 88 (37+/50-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF ENGINEERING TECHNOLOGY LAHORE
# -> school_names_2    UNIVERSITY OF LAHORE
# n
# Last uncertainty improvement: 0.016
# Uncertainty: 0.472
#
# Nr. 89 (37+/51-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PADJADJARAN UNIVERSITY
# -> school_names_2    UNIVERSITY PADJADJARAN PADJADJARAN UNIVERSITY
# y
# Last uncertainty improvement: 0.016
# Uncertainty: 0.467
#
# Nr. 90 (38+/51-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF ROBERTSCHESTER
# n
# Last uncertainty improvement: 0.016
# Uncertainty: 0.472
#
# Nr. 91 (38+/52-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY DIPONEGORO
# -> school_names_2    UNIVERSITY DIPONEGORO DIPONEGORO UNIVERSITY
# y
# Last uncertainty improvement: 0.016
# Uncertainty: 0.464
#
# Nr. 92 (39+/52-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF MACEJKOVICSIDE
# n
# Last uncertainty improvement: 0.016
# Uncertainty: 0.473
#
# Nr. 93 (39+/53-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY PADJADJARAN
# -> school_names_2    UNIVERSITY PADJADJARAN PADJADJARAN UNIVERSITY
# y
# Last uncertainty improvement: 0.012
# Uncertainty: 0.461
#
# Nr. 94 (40+/53-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    FLORIDA INTERNATIONAL UNIVERSITY
# -> school_names_2    INTERNATIONAL UNIVERSITY HCMU
# n
# Last uncertainty improvement: 0.012
# Uncertainty: 0.462
#
# Nr. 95 (40+/54-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITI TEKNOLOGI MARA UITM ARAUPERLIS
# -> school_names_2    UNIVERSITI TEKNOLOGI MARA UITM CAWANGAN PERLIS
# y
# Last uncertainty improvement: 0.012
# Uncertainty: 0.453
#
# Nr. 96 (41+/54-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    FAST NATIONAL INSTITUTE OF COMPUTER AND EMERGING SCIENCES
# -> school_names_2    NATIONAL UNIVERSITY OF COMPUTER AND EMERGING SCIENCES FAST KARACHI
# y
# Last uncertainty improvement: 0.012
# Uncertainty: 0.458
#
# Nr. 97 (42+/54-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    TUNKU ABDUL RAHMAN UNIVERSITY COLLEGE KL MAIN CAMPUS
# -> school_names_2    TUNKU ABDUL RAHMAN UNIVERSITY COLLEGE TAR UC
# y
# Last uncertainty improvement: 0.012
# Uncertainty: 0.450
#
# Nr. 98 (43+/54-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIAN COMPUTER UNIVERSITY
# -> school_names_2    UNIVERSITY OF INDONESIAN
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.448
# Classifier converged, enter 'f' to stop training
#
# Nr. 99 (43+/55-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY PENDIDIKAN INDONESIA
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.450
# Classifier converged, enter 'f' to stop training
#
# Nr. 100 (43+/56-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY ALAZHAR INDONESIA
# -> school_names_2    UNIVERSITY INDONESIA UI
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.452
# Classifier converged, enter 'f' to stop training
#
# Nr. 101 (43+/57-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    HERIOT WATT UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.447
# Classifier converged, enter 'f' to stop training
#
# Nr. 102 (43+/58-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SMK GARUDA NUSANTARA
# -> school_names_2    SMK KARYA NUSANTARA
# y
# Last uncertainty improvement: 0.005
# Uncertainty: 0.450
# Classifier converged, enter 'f' to stop training
#
# Nr. 103 (44+/58-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY ISLAM KEDIRI
# -> school_names_2    UNIVERSITY ISLAM NEGERI
# y
# Last uncertainty improvement: 0.015
# Uncertainty: 0.465
#
# Nr. 104 (45+/58-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NEW ALYSONLAND
# -> school_names_2    UNIVERSITY OF NEW CLOYDLAND
# n
# Last uncertainty improvement: 0.015
# Uncertainty: 0.478
#
# Nr. 105 (45+/59-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF BARONBOROUGH
# n
# Last uncertainty improvement: 0.023
# Uncertainty: 0.456
#
# Nr. 106 (45+/60-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF HAZLECHESTER
# n
# Last uncertainty improvement: 0.023
# Uncertainty: 0.465
#
# Nr. 107 (45+/61-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NEW BOYD
# -> school_names_2    UNIVERSITY OF NEW CLOYDLAND
# n
# Last uncertainty improvement: 0.023
# Uncertainty: 0.468
#
# Nr. 108 (45+/62-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    FEDERAL URDU UNIVERSITY OF ARTS SCIENCE AND TECHNOLOGY
# -> school_names_2    UNIVERSITY OF SCIENCE AND TECHNOLOGY JAYAPURA
# n
# Last uncertainty improvement: 0.023
# Uncertainty: 0.455
#
# Nr. 109 (45+/63-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIA UNIVERSITY
# -> school_names_2    UNIVERSITY SARI MUTIARA INDONESIA MEDAN
# n
# Last uncertainty improvement: 0.023
# Uncertainty: 0.439
#
# Nr. 110 (45+/64-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    DIPONEGORO UNIVERSITY SEMARANG
# -> school_names_2    UNIVERSITY DIPONEGORO DIPONEGORO UNIVERSITY
# y
# Last uncertainty improvement: 0.017
# Uncertainty: 0.448
#
# Nr. 111 (46+/64-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF STRACKEBURY
# n
# Last uncertainty improvement: 0.017
# Uncertainty: 0.439
#
# Nr. 112 (46+/65-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF LAVINIAPORT
# n
# Last uncertainty improvement: 0.017
# Uncertainty: 0.447
#
# Nr. 113 (46+/66-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF ROOBCHESTER
# n
# Last uncertainty improvement: 0.017
# Uncertainty: 0.455
#
# Nr. 114 (46+/67-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF NAPOLEONTON
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.462
# Classifier converged, enter 'f' to stop training
#
# Nr. 115 (46+/68-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF ANGELAHAVEN
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.469
# Classifier converged, enter 'f' to stop training
#
# Nr. 116 (46+/69-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    AMIK TUNAS BANGSA
# -> school_names_2    AMIK TUNAS BANGSA PEMATANGSIANTAR
# y
# Last uncertainty improvement: 0.008
# Uncertainty: 0.476
# Classifier converged, enter 'f' to stop training
#
# Nr. 117 (47+/69-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NATIONAL UNIVERSITY OF SCIENCE TECHNOLOGY
# -> school_names_2    UNIVERSITY OF SCIENCE HCM NATIONAL UNIVERSITY
# n
# Last uncertainty improvement: 0.028
# Uncertainty: 0.448
#
# Nr. 118 (47+/70-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    KANAZAWA UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.028
# Uncertainty: 0.447
#
# Nr. 119 (47+/71-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUT ILMU ADMINISTRASI DAN MANAJEMEN STIAMI
# -> school_names_2    INSTITUT MANAJEMEN STIAMI
# n
# Last uncertainty improvement: 0.028
# Uncertainty: 0.454
#
# Nr. 120 (47+/72-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    STIKUBANK UNIVERSITY
# -> school_names_2    UNIVERSITY STIKUBANK UNISBANK SEMARANG
# y
# Last uncertainty improvement: 0.028
# Uncertainty: 0.460
#
# Nr. 121 (48+/72-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY BENGKULU UNIVERSITY OF BENGKULU
# -> school_names_2    UNIVERSITY OF BENGKULU
# y
# Last uncertainty improvement: 0.028
# Uncertainty: 0.453
#
# Nr. 122 (49+/72-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST ENGLAND
# -> school_names_2    UNIVERSITY OF WEST JEFF
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.442
#
# Nr. 123 (49+/73-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY DIAN NUSWANTORO UDINUS
# -> school_names_2    UNIVERSITY DIAN NUSWANTORO SEMARANG
# y
# Last uncertainty improvement: 0.010
# Uncertainty: 0.438
#
# Nr. 124 (50+/73-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST FREDDIE
# -> school_names_2    UNIVERSITY OF WEST JEFF
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.447
#
# Nr. 125 (50+/74-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NORWEGIAN UNIVERSITY OF SCIENCE AND TECHNOLOGY
# -> school_names_2    SEOUL NATIONAL UNIVERSITY OF SCIENCE AND TECHNOLOGY
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.443
#
# Nr. 126 (50+/75-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ELTA
# -> school_names_2    UNIVERSITY OF EAST GERALDINE
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.439
#
# Nr. 127 (50+/76-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUT TEKNOLOGI 10 NOVEMBER SURABAYA ITS
# -> school_names_2    INSTITUT TEKNOLOGI SEPULUH NOVEMBER SURABAYA
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.436
# Classifier converged, enter 'f' to stop training
#
# Nr. 128 (51+/76-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY MUSLIM NUSANTARA MEDAN
# -> school_names_2    UNIVERSITY OF MUSLIM NUSANTARA ALWASLIYAH
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.436
# Classifier converged, enter 'f' to stop training
#
# Nr. 129 (52+/76-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ELTA
# -> school_names_2    UNIVERSITY OF EAST KAITLIN
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.441
# Classifier converged, enter 'f' to stop training
#
# Nr. 130 (52+/77-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NATIONAL KAOHSIUNG UNIVERSITY OF SCIENCE AND TECHNOLOGY
# -> school_names_2    NATIONAL YUNLIN UNIVERSITY OF SCIENCE AND TECHNOLOGY YUNTECH
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.438
# Classifier converged, enter 'f' to stop training
#
# Nr. 131 (52+/78-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITI INSTITUSI TEKNOLOGI MARA UITM
# -> school_names_2    UNIVERSITI TEKNOLOGI MARA UITM MELAKA
# y
# Last uncertainty improvement: 0.005
# Uncertainty: 0.436
# Classifier converged, enter 'f' to stop training
#
# Nr. 132 (53+/78-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH UNIVERSITY OF MAGELANG
# -> school_names_2    UNIVERSITY MUHAMMADIYAH OF JAKARTA
# y
# Last uncertainty improvement: 0.005
# Uncertainty: 0.436
# Classifier converged, enter 'f' to stop training
#
# Nr. 133 (54+/78-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST COLEMAN
# -> school_names_2    UNIVERSITY OF WEST LAUREN
# n
# Last uncertainty improvement: 0.007
# Uncertainty: 0.443
# Classifier converged, enter 'f' to stop training
#
# Nr. 134 (54+/79-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PASUNDAN UNIVERSITY INDONESIA
# -> school_names_2    UNIVERSITY PUTERA INDONESIA
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.436
# Classifier converged, enter 'f' to stop training
#
# Nr. 135 (54+/80-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY NEGERI YOGYAKARTA
# -> school_names_2    UNIVERSITY TEKNOLGI YOGYAKARTA
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.428
# Classifier converged, enter 'f' to stop training
#
# Nr. 136 (54+/81-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH SEMARANG UNIVERSITY
# -> school_names_2    UNIVERSITY MUHAMMADIYAH PALEMBANH
# y
# Last uncertainty improvement: 0.008
# Uncertainty: 0.421
# Classifier converged, enter 'f' to stop training
#
# Nr. 137 (55+/81-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    CRISTIAN UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY OF EDUCATION INDONESIA
# n
# Last uncertainty improvement: 0.015
# Uncertainty: 0.436
#
# Nr. 138 (55+/82-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUT TEKNOLOGI SAINS BANDUNG
# -> school_names_2    INTITUTE TEKNOLOGI BANDUNG
# y
# Last uncertainty improvement: 0.015
# Uncertainty: 0.429
#
# Nr. 139 (56+/82-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST FELIX
# -> school_names_2    UNIVERSITY OF EAST MIGUEL
# n
# Last uncertainty improvement: 0.015
# Uncertainty: 0.443
#
# Nr. 140 (56+/83-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITI TEKNOLOGI MARA PENANG
# -> school_names_2    UNIVERSITI TEKNOLOGI MARA KEDAH
# y
# Last uncertainty improvement: 0.015
# Uncertainty: 0.429
#
# Nr. 141 (57+/83-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BANDUNG RAYA UNIVERSITY
# -> school_names_2    UNIVERSITY KEBANGSAAN BANDUNG
# n
# Last uncertainty improvement: 0.015
# Uncertainty: 0.434
#
# Nr. 142 (57+/84-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY BANDUNG RAYA
# -> school_names_2    UNIVERSITY KEBANGSAAN BANDUNG
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.431
#
# Nr. 143 (57+/85-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ELTA
# -> school_names_2    UNIVERSITY OF EAST NEDRAMOUTH
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.429
#
# Nr. 144 (57+/86-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PGRI UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY COMPUTER OF INDONESIA
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.426
#
# Nr. 145 (57+/87-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF BRAWIJAYA MALANG INDONESIA
# -> school_names_2    UNIVERSITY OF INDONESIA UI
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.417
# Classifier converged, enter 'f' to stop training
#
# Nr. 146 (57+/88-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUT AGAMA ISLAM NEGERI PAREPARE
# -> school_names_2    INSTITUT AGAMA ISLAM NEGERI SURAKARTA
# y
# Last uncertainty improvement: 0.010
# Uncertainty: 0.415
# Classifier converged, enter 'f' to stop training
#
# Nr. 147 (58+/88-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF 17 AGUSTUS 1945 JAKARTA
# -> school_names_2    UNIVERSITY OF 17 AGUSTUS 1945 SEMARANG
# y
# Last uncertainty improvement: 0.010
# Uncertainty: 0.415
# Classifier converged, enter 'f' to stop training
#
# Nr. 148 (59+/88-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PRIMA INDONESIA UNIVERSITY
# -> school_names_2    UNIVERSITY TEKNOKRAT INDONESIA
# p
#
# Nr. 148 (59+/88-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF 17 AGUSTUS 1945 JAKARTA
# -> school_names_2    UNIVERSITY OF 17 AGUSTUS 1945 SEMARANG
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.422
# Classifier converged, enter 'f' to stop training
#
# Nr. 149 (59+/89-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NEW BESSIETON
# -> school_names_2    UNIVERSITY OF NEW BOYD
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.418
# Classifier converged, enter 'f' to stop training
#
# Nr. 150 (59+/90-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST ANDREFURT
# -> school_names_2    UNIVERSITY OF WEST ORA
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.412
# Classifier converged, enter 'f' to stop training
#
# Nr. 151 (59+/91-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH UNIVERSITY OF TANGERANG
# -> school_names_2    UNIVERSITY OF MUHAMMADIYAH METRO
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.410
# Classifier converged, enter 'f' to stop training
#
# Nr. 152 (59+/92-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY COLLEGE LONDON
# -> school_names_2    UNIVERSITY OF LONDON UNIVERSITY COLLEGE LONDON
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.401
# Classifier converged, enter 'f' to stop training
#
# Nr. 153 (60+/92-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY INDONESIA
# -> school_names_2    UNIVERSITY INDONESIA UNIVERSITY OF INDONESIA
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.398
# Classifier converged, enter 'f' to stop training
#
# Nr. 154 (61+/92-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIA UNIVERSITY
# -> school_names_2    UNIVERSITY INDONESIA UNIVERSITY OF INDONESIA
# y
# Last uncertainty improvement: 0.017
# Uncertainty: 0.415
#
# Nr. 155 (62+/92-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UET LAHORE
# -> school_names_2    UET LAHORE CITY CAMPUS
# y
# Last uncertainty improvement: 0.017
# Uncertainty: 0.431
#
# Nr. 156 (63+/92-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY
# -> school_names_2    UNIVERSITY CENDERAWASIH
# n
# Last uncertainty improvement: 0.017
# Uncertainty: 0.423
#
# Nr. 157 (63+/93-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    CENDERAWASIH UNIVERSITY
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.017
# Uncertainty: 0.416
#
# Nr. 158 (63+/94-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    ATMA JAY CATHOLIC UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY OF INDONESIA UI
# n
# Last uncertainty improvement: 0.017
# Uncertainty: 0.409
#
# Nr. 159 (63+/95-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITI TEKNOLOGI MARA UITM SHAH ALAM
# -> school_names_2    UNIVERSITI TEKNOLOGI MARA UITM PERAK
# y
# Last uncertainty improvement: 0.016
# Uncertainty: 0.405
#
# Nr. 160 (64+/95-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY MUHAMMADIYAH SUMATERA UTARA
# -> school_names_2    UNIVERSITY MUHAMMADIYAH NORTH SUMATERA
# y
# Last uncertainty improvement: 0.008
# Uncertainty: 0.402
# Classifier converged, enter 'f' to stop training
#
# Nr. 161 (65+/95-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY PEMBANGUNAN NASIONAL VETERAN
# -> school_names_2    UNIVERSITY PEMBANGUNAN NASIONAL VETERANYOGYAKARTA
# y
# Last uncertainty improvement: 0.013
# Uncertainty: 0.389
#
# Nr. 162 (66+/95-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INTERNATIONAL MEDICAL UNIVERSITY
# -> school_names_2    UNIVERSITY INTERNATIONAL BATAM
# n
# Last uncertainty improvement: 0.013
# Uncertainty: 0.383
#
# Nr. 163 (66+/96-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ELTA
# -> school_names_2    UNIVERSITY OF EAST FELIX
# n
# Last uncertainty improvement: 0.013
# Uncertainty: 0.379
#
# Nr. 164 (66+/97-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NEW SOUTH WALES AUSTRALIA
# -> school_names_2    UNIVERSITY OF NEW SOUTH WALES SYDNEY
# y
# Last uncertainty improvement: 0.013
# Uncertainty: 0.382
#
# Nr. 165 (67+/97-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST ADELEMOUTH
# -> school_names_2    UNIVERSITY OF WEST ORA
# n
# Last uncertainty improvement: 0.013
# Uncertainty: 0.389
#
# Nr. 166 (67+/98-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    METHODIST UNIVERSITY OF INDONESIA
# -> school_names_2    PGRI UNIVERSITY OF INDONESIA
# n
# Last uncertainty improvement: 0.007
# Uncertainty: 0.386
# Classifier converged, enter 'f' to stop training
#
# Nr. 167 (67+/99-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MALANG NATIONAL INSTITUTE OF TECHNOLOGY
# -> school_names_2    MEDAN INSTITUTE OF TECHNOLOGY
# n
# Last uncertainty improvement: 0.007
# Uncertainty: 0.384
# Classifier converged, enter 'f' to stop training
#
# Nr. 168 (67+/100-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NORTH SUMATERA
# -> school_names_2    UNIVERSITY OF SUMATERA UTARA
# y
# Last uncertainty improvement: 0.007
# Uncertainty: 0.380
# Classifier converged, enter 'f' to stop training
#
# Nr. 169 (68+/100-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PADJADJARAN UNIVERSITY BANDUNG
# -> school_names_2    UNIVERSITY BANDUNG RAYA
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.389
# Classifier converged, enter 'f' to stop training
#
# Nr. 170 (68+/101-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ELTA
# -> school_names_2    UNIVERSITY OF EAST HOLLIEMOUTH
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.386
# Classifier converged, enter 'f' to stop training
#
# Nr. 171 (68+/102-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ELTA
# -> school_names_2    UNIVERSITY OF EAST MARCELLUSHAVEN
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.384
# Classifier converged, enter 'f' to stop training
#
# Nr. 172 (68+/103-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PGRI UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY OF EDUCATION INDONESIA
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.380
# Classifier converged, enter 'f' to stop training
#
# Nr. 173 (68+/104-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITI TUNKU ABDUL RAHMAN UTAR KAMPAR CAMPUS
# -> school_names_2    UNIVERSITI TUNKU ABDUL RAHMAN UTAR SUNGAI LONG CAMPUS
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.369
#
# Nr. 174 (69+/104-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY TUNKU ABDUL RAHMAN KAMPAR
# -> school_names_2    UTAR UNIVERSITY TUNKU ABDUL RAHMAN
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.365
#
# Nr. 175 (70+/104-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SEKOLAH TINGGI ILMU EKONOMI IBBI
# -> school_names_2    SEKOLAH TINGGI ILMU EKONOMI LA TANSA MASHIRO
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.361
#
# Nr. 176 (71+/104-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    NATIONAL KAOHSIUNG UNIVERSITY OF SCIENCE AND TECHNOLOGY
# -> school_names_2    NATIONAL PINGTUNG UNIVERSITY OF SCIENCE AND TECHNOLOGY
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.364
#
# Nr. 177 (71+/105-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY TUNKU ABDUL RAHMAN UTAR
# -> school_names_2    UNIVERSITY TUNKU ABDUL RAHMAN KAMPAR
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.370
#
# Nr. 178 (72+/105-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    MUHAMMADIYAH SEMARANG OF UNIVERSITY
# -> school_names_2    UNIVERSITY SEMARANG
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.365
# Classifier converged, enter 'f' to stop training
#
# Nr. 179 (72+/106-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    HUMAN CAPITAL
# -> school_names_2    HUMAN CAPITAL MANAGEMENT
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.373
# Classifier converged, enter 'f' to stop training
#
# Nr. 180 (73+/106-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF
# -> school_names_2    UNIVERSITY OF EMELIEBURY
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.367
# Classifier converged, enter 'f' to stop training
#
# Nr. 181 (73+/107-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIA UNIVERSITY OF EDUCATION
# -> school_names_2    UNIVERSITY INDONESIA UNIVERSITY OF INDONESIA
# n
# Last uncertainty improvement: 0.009
# Uncertainty: 0.376
# Classifier converged, enter 'f' to stop training
#
# Nr. 182 (73+/108-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SULTAN AGENG TIRTAYASA
# ...
# -> school_names_1    UNIVERSITY KRISTEN PALANGKA RAYA
# -> school_names_2    UNIVERSITY KRISTEN PETRA
# y
# Last uncertainty improvement: 0.013
# Uncertainty: 0.346
#
# Nr. 248 (94+/153-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SEKOLAH TINGGI ILMU EKONOMI PARIWISATA MANADO
# -> school_names_2    SEKOLAH TINGGI ILMU EKONOMI PASUNDAN
# y
# Last uncertainty improvement: 0.013
# Uncertainty: 0.357
#
# Nr. 249 (95+/153-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST AIDAN
# -> school_names_2    UNIVERSITY OF WEST OF ENGLAND
# n
# Last uncertainty improvement: 0.013
# Uncertainty: 0.367
#
# Nr. 250 (95+/154-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY AISYIYAH YOGYAKARTA
# -> school_names_2    UNIVERSITY NEGERI YOGYAKARTA
# n
# Last uncertainty improvement: 0.013
# Uncertainty: 0.364
#
# Nr. 251 (95+/155-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY INDONESIA UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY TEKNOKRAT INDONESIA
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.358
#
# Nr. 252 (95+/156-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PRIMA INDONESIA UNIVERSITY
# -> school_names_2    UNIVERSITY HINDU INDONESIA
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.353
#
# Nr. 253 (95+/157-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUT AGAMA ISLAM NEGERI PADANGSIDIMPUAN
# -> school_names_2    INSTITUT AGAMA ISLAM NEGERI SAMARINDA
# y
# Last uncertainty improvement: 0.009
# Uncertainty: 0.350
# Classifier converged, enter 'f' to stop training
#
# Nr. 254 (96+/157-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    AFRICA INTERNATIONAL UNIVERSITY
# -> school_names_2    INTERNATIONAL CLASS TRISAKTI UNIVERSITY
# n
# Last uncertainty improvement: 0.006
# Uncertainty: 0.356
# Classifier converged, enter 'f' to stop training
#
# Nr. 255 (96+/158-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITI INSTITUT TEKNOLOGI MARA UITM
# -> school_names_2    UNIVERSITI TEKNOLOGI MARA UITM PUNCAK ALAM
# y
# Last uncertainty improvement: 0.006
# Uncertainty: 0.352
# Classifier converged, enter 'f' to stop training
#
# Nr. 256 (97+/158-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF BINA DARMA
# -> school_names_2    UNIVERSITY OF DARMA PERSADA
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.357
# Classifier converged, enter 'f' to stop training
#
# Nr. 257 (97+/159-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF JANETBERG
# -> school_names_2    UNIVERSITY OF JENKINSBERG
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.353
# Classifier converged, enter 'f' to stop training
#
# Nr. 258 (97+/160-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    PRIMA UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY COMPUTER OF INDONESIA
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.352
# Classifier converged, enter 'f' to stop training
#
# Nr. 259 (97+/161-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF ROGAHNBURY
# -> school_names_2    UNIVERSITY OF SHANNABURY
# n
# Last uncertainty improvement: 0.005
# Uncertainty: 0.349
# Classifier converged, enter 'f' to stop training
#
# Nr. 260 (97+/162-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY MUHAMMADIYAH JAMBI
# -> school_names_2    UNIVERSITY MUHAMMADIYAH PAREPARE
# y
# Last uncertainty improvement: 0.005
# Uncertainty: 0.347
# Classifier converged, enter 'f' to stop training
#
# Nr. 261 (98+/162-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF SOUTH ALAN
# -> school_names_2    UNIVERSITY OF SOUTH MARQUISEVIEW
# p
#
# Nr. 261 (98+/162-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY MUHAMMADIYAH JAMBI
# -> school_names_2    UNIVERSITY MUHAMMADIYAH PAREPARE
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.361
#
# Nr. 262 (98+/163-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ADDISONCHESTER
# -> school_names_2    UNIVERSITY OF EAST ALDA
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.358
#
# Nr. 263 (98+/164-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ALDA
# -> school_names_2    UNIVERSITY OF EAST GORDON
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.354
#
# Nr. 264 (98+/165-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ALDA
# -> school_names_2    UNIVERSITY OF EAST ORANGE
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.349
#
# Nr. 265 (98+/166-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF COLLINTON
# -> school_names_2    UNIVERSITY OF NAPOLEONTON
# n
# Last uncertainty improvement: 0.014
# Uncertainty: 0.347
#
# Nr. 266 (98+/167-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF BEAHANSIDE
# -> school_names_2    UNIVERSITY OF BETHESDA
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.343
# Classifier converged, enter 'f' to stop training
#
# Nr. 267 (98+/168-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY ISLAM MAKASSAR
# -> school_names_2    UNIVERSITY ISLAM RIAU
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.341
# Classifier converged, enter 'f' to stop training
#
# Nr. 268 (98+/169-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY ISLAM LAMONGAN
# -> school_names_2    UNIVERSITY ISLAM RIAU
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.338
# Classifier converged, enter 'f' to stop training
#
# Nr. 269 (98+/170-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF DACHSHIRE
# -> school_names_2    UNIVERSITY OF LARSONSHIRE
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.337
# Classifier converged, enter 'f' to stop training
#
# Nr. 270 (98+/171-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST FELIX
# -> school_names_2    UNIVERSITY OF EAST HOLLIEMOUTH
# n
# Last uncertainty improvement: 0.004
# Uncertainty: 0.335
# Classifier converged, enter 'f' to stop training
#
# Nr. 271 (98+/172-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    AISYIYAH YOGYAKARTA UNIVERSITY
# -> school_names_2    ATMAJAYA UNIVERSITY YOGYAKARTA
# n
# Last uncertainty improvement: 0.003
# Uncertainty: 0.332
# Classifier converged, enter 'f' to stop training
#
# Nr. 272 (98+/173-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NORTH KRISTIAN
# -> school_names_2    UNIVERSITY OF NORTH LILLIESTAD
# n
# Last uncertainty improvement: 0.003
# Uncertainty: 0.329
# Classifier converged, enter 'f' to stop training
#
# Nr. 273 (98+/174-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BINUS UNIVERSITY INTERNATIONAL
# -> school_names_2    HO CHI MINH CITY INTERNATIONAL UNIVERSITY
# n
# Last uncertainty improvement: 0.003
# Uncertainty: 0.328
# Classifier converged, enter 'f' to stop training
#
# Nr. 274 (98+/175-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF HAHNMOUTH
# -> school_names_2    UNIVERSITY OF JOESPHMOUTH
# n
# Last uncertainty improvement: 0.003
# Uncertainty: 0.326
# Classifier converged, enter 'f' to stop training
#
# Nr. 275 (98+/176-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    TEKNOKRAT INDONESIA UNIVERSITY
# -> school_names_2    UNIVERSITY RESPATI INDONESIA
# n
# Last uncertainty improvement: 0.003
# Uncertainty: 0.323
# Classifier converged, enter 'f' to stop training
#
# Nr. 276 (98+/177-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIAN ISLAMIC UNIVERSITY UNIVERSITAS ISLAM INDONESIA
# -> school_names_2    UNIVERSITY OF ISLAM INDONESIAN
# y
# Last uncertainty improvement: 0.003
# Uncertainty: 0.323
# Classifier converged, enter 'f' to stop training
#
# Nr. 277 (99+/177-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INSTITUT AGAMA ISLAM NEGERI METRO
# -> school_names_2    INSTITUT AGAMA ISLAM NEGERI PADANGSIDIMPUAN
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.333
#
# Nr. 278 (100+/177-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    SEKOLAH TINGGI ILMU EKONOMI HARAPAN
# -> school_names_2    SEKOLAH TINGGI ILMU EKONOMI NASIONAL
# y
# Last uncertainty improvement: 0.011
# Uncertainty: 0.344
#
# Nr. 279 (101+/177-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY MUHAMMADIYAH OF JEMBER
# -> school_names_2    UNIVERSITY MUHAMMADIYAH OF YOGYAKARTA
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.350
#
# Nr. 280 (101+/178-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY INDONESIA OF EDUCATION
# -> school_names_2    UNIVERSITY OF PRIMA INDONESIA
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.348
#
# Nr. 281 (101+/179-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIA OPEN UNIVERSITY
# -> school_names_2    UNIVERSITY KOMPUTER INDONESIA UNIKOM BANDUNG
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.342
#
# Nr. 282 (101+/180-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    AACHEN UNIVERSITY OF APPLIED SCIENCE
# -> school_names_2    UNIVERSITY OF APPLIED SCIENCE KAISERSLAUTERN
# n
# Last uncertainty improvement: 0.011
# Uncertainty: 0.339
#
# Nr. 283 (101+/181-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    CRISTIAN UNIVERSITY OF INDONESIA
# -> school_names_2    UNIVERSITY OF ALAZHAR INDONESIA
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.329
# Classifier converged, enter 'f' to stop training
#
# Nr. 284 (101+/182-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    HCM UNIVERSITY OF SCIENCE
# -> school_names_2    UNIVERSITY
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.329
# Classifier converged, enter 'f' to stop training
#
# Nr. 285 (101+/183-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF SOUTH GOLDA
# -> school_names_2    UNIVERSITY OF SOUTH SALVADORFURT
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.328
# Classifier converged, enter 'f' to stop training
#
# Nr. 286 (101+/184-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST FELIX
# -> school_names_2    UNIVERSITY OF EAST GILESTOWN
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.326
# Classifier converged, enter 'f' to stop training
#
# Nr. 287 (101+/185-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF WEST BREANA
# -> school_names_2    UNIVERSITY OF WEST GERMANBERG
# n
# Last uncertainty improvement: 0.010
# Uncertainty: 0.323
# Classifier converged, enter 'f' to stop training
#
# Nr. 288 (101+/186-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    CRISTIAN UNIVERSITY OF INDONESIA
# -> school_names_2    INDONESIA UNIVERSITY OF EDUCATION UPI
# n
# Last uncertainty improvement: 0.002
# Uncertainty: 0.322
# Classifier converged, enter 'f' to stop training
#
# Nr. 289 (101+/187-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ANTWON
# -> school_names_2    UNIVERSITY OF EAST CARAPORT
# n
# Last uncertainty improvement: 0.002
# Uncertainty: 0.320
# Classifier converged, enter 'f' to stop training
#
# Nr. 290 (101+/188-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY ISLAM NEGERI SYARIF HIDAYATULLAH JAKARTA
# -> school_names_2    UNIVERSITY ISLAM NEGERI SYARIFHIDAYATULLAH JAKARTA
# y
# Last uncertainty improvement: 0.002
# Uncertainty: 0.318
# Classifier converged, enter 'f' to stop training
#
# Nr. 291 (102+/188-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NORTH KRISTIAN
# -> school_names_2    UNIVERSITY OF NORTH OTHO
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.327
# Classifier converged, enter 'f' to stop training
#
# Nr. 292 (102+/189-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF LAKE ELMO
# -> school_names_2    UNIVERSITY OF LAKE MICHALE
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.324
# Classifier converged, enter 'f' to stop training
#
# Nr. 293 (102+/190-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF SOUTH CORBIN
# -> school_names_2    UNIVERSITY OF SOUTH FAUSTO
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.323
# Classifier converged, enter 'f' to stop training
#
# Nr. 294 (102+/191-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF EAST ALDA
# -> school_names_2    UNIVERSITY OF EAST NEDRAMOUTH
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.321
# Classifier converged, enter 'f' to stop training
#
# Nr. 295 (102+/192-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    BANDUNG RAYA OF UNIVERSITY
# -> school_names_2    UNIVERSITY BALE BANDUNG
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.318
# Classifier converged, enter 'f' to stop training
#
# Nr. 296 (102+/193-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    INDONESIAN UNIVERSITY OF EDUCATION UPI
# -> school_names_2    UNIVERSITY OF ISLAM INDONESIAN
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.310
# Classifier converged, enter 'f' to stop training
#
# Nr. 297 (102+/194-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    POLYTECHNIC STATE OF PADANG
# -> school_names_2    POLYTECHNIC STATE OF SEMARANG
# y
# Last uncertainty improvement: 0.008
# Uncertainty: 0.306
# Classifier converged, enter 'f' to stop training
#
# Nr. 298 (103+/194-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    IOWA STATE UNIVERSITY
# -> school_names_2    PENNSYLVANIA STATE UNIVERSITY
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.313
# Classifier converged, enter 'f' to stop training
#
# Nr. 299 (103+/195-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NORTH PROVIDENCI
# -> school_names_2    UNIVERSITY OF NORTH SANDY
# n
# Last uncertainty improvement: 0.008
# Uncertainty: 0.312
# Classifier converged, enter 'f' to stop training
#
# Nr. 300 (103+/196-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITI INSTITUSI TEKNOLOGI MARA UITM
# -> school_names_2    UNIVERSITI TEKNOLOGI MARA UITM PUNCAK ALAM
# y
# Last uncertainty improvement: 0.008
# Uncertainty: 0.310
# Classifier converged, enter 'f' to stop training
#
# Nr. 301 (104+/196-)
# Is this a match? (y)es, (n)o, (p)revious, (s)kip, (f)inish
# -> school_names_1    UNIVERSITY OF NEW LESSIE
# -> school_names_2    UNIVERSITY OF NEW NOVA
# f
#  score  count
#   0.05   7428
#   0.10    699
#   0.15    279
#   0.20    109
#   0.25    102
#   0.30     68
#   0.35     25
#   0.40      0
#   0.45      0
#   0.50      0
#   0.55      0
#   0.60      0
#   0.65      0
#   0.70      1
#   0.75     35
#   0.80     36
#   0.85     72
#   0.90     94
#   0.95    250
#   1.00    502
# active learning finished
# blocking rules found
# ['school_names first_three_letters', 'school_names first_three_letters_no_space']
# Deduplicator
#   - col_names = ['school_names']
#   - field_info = {'school_names': ['token_set_ratio', 'token_sort_ratio']}
#   - interaction = True
#   - rules_info = {'school_names': ['whole_field', 'first_word', 'first_two_words', 'first_three_letters', 'first_four_letters', 'first_five_letters', 'first_three_letters_no_space', 'first_four_letters_no_space', 'first_five_letters_no_space', 'sorted_integers', 'first_integer', 'last_integer', 'largest_integer', 'three_letter_abbreviation']}
#   - recall = 1.0

# %%
res = myDedupliPy.predict(df_predict, score_threshold=0.1)
res.sort_values('deduplication_id')
# Out:
# blocking started
# blocking finished
# Nr of pairs: 6785201
# scoring started
# scoring finished
# Nr of filtered pairs: 229075
# Clustering started
# Clustering finished
#                      school_names  deduplication_id
# 0              ANDALAS UNIVERSITY                 1
# 223             ANDALAS UIVERSITY                 1
# 224           ANDALAS UNIVERSITAS                 1
# 225           ANDALAS UNIVERSITYI                 1
# 226             ANDALAS UNIVERSIY                 1
# ...                           ...               ...
# 9275     ĐẠI HỌC BÁCH KHOA HÀ NỘI              9276
# 9276            ĐẠI HỌC CÔNG ĐOÀN              9277
# 9277  ĐẠI HỌC TÀI CHÍNH MARKETING              9278
# 9278   IMG SRCJAVASCRIPTALERTTEST              9279
# 9279         東洋大学 TOYO UNIVERSITY              9280
#
# [9280 rows x 2 columns]

# %%
res.nunique()
# Out:
# school_names        9280
# deduplication_id    4792
# dtype: int64

# %%
res.to_csv('deduplipy.csv')

# %% [markdown]
# ##Reading Deduplipy CSV of clusters and match using FuzzyWuzzy with the scraped uni list

# %%
deduplipydf = pd.read_csv('/content/deduplipy.csv', usecols= ['school_names','deduplication_id'])

# %%
deduplipydf
# Out:
#                                            school_names  deduplication_id
# 0                                    ANDALAS UNIVERSITY                 1
# 1            ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA                10
# 2     BANDUNG POLYTECHNIC FOR MANUFACTURING POLMAN B...                47
# 3     HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND ...               105
# 4                         JENDERAL SOEDIRMAN UNIVERSITY               126
# ...                                                 ...               ...
# 9275                           ĐẠI HỌC BÁCH KHOA HÀ NỘI              9276
# 9276                                  ĐẠI HỌC CÔNG ĐOÀN              9277
# 9277                        ĐẠI HỌC TÀI CHÍNH MARKETING              9278
# 9278                         IMG SRCJAVASCRIPTALERTTEST              9279
# 9279                               東洋大学 TOYO UNIVERSITY              9280
#
# [9280 rows x 2 columns]

# %%
deduplipydf1=deduplipydf.groupby('deduplication_id').head(1)

# %%
df1_names = list(deduplipydf1.school_names)
df2_match = list(cleanuninames.UniNames)

# %%
#Defining a function to return the match and similarity score of the fuzz.ratio() scorer. 
#The function will take in a term(name), list of terms(list_names), and a minimum similarity score(min_score) to return the match. 

def match_names(name, list_names, min_score=0):
  max_score=-1
  max_name=''
  for x in list_names:
    score=fuzz.token_sort_ratio(name, x)
    if (score > min_score) & (score > max_score):
      max_name = x
      max_score = score
  return (max_name, max_score)

# %%
#For loop to create a list of tuples with the first value being the name from the 
#second dataframe (name to replace) and the second value from the 
#first dataframe (string replacing the name value). Then, casting the list of tuples as a dictionary. 

names = []
for x in tqdm(df1_names):
  match = match_names(x, df2_match, 71)
  if match[1] >= 72:
    name = (str(x), str(match[0]))
    names.append(name)
    
dedup_name_dict=dict(names)
dedup_name_dict
# Out:
# 100%|██████████| 4792/4792 [23:33<00:00,  3.39it/s]
# {'ANDALAS UNIVERSITY': 'Andalas University',
#  'ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA': 'Atma Jaya Catholic University of Indonesia',
#  'HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND EDUCATION': 'Ho Chi Minh City University of Technology and Education',
#  'JENDERAL SOEDIRMAN UNIVERSITY': 'General Soedirman University',
#  'MEDAN STATE UNIVERSITY': 'State University of Medan',
#  'NATIONAL INSTITUTE OF TECHNOLOGY BANDUNG': 'Bandung National Institute of Technology',
#  'PADJAJARAN UNIVERSITY': 'Padjadjaran University',
#  'SOLBRIDGE INTERNATIONAL SCHOOL OF BUSINESS': 'International School of Business',
#  'STATE POLYTECHNIC OF MALANG': 'Polytechnic School of Malanje',
#  'SURABAYA STATE OF UNIVERSITY': 'Surabaya State University',
#  'TRILOGI UNIVERSITY': 'Trilogi University',
#  'UNIVERSITY GADJAH MADA': 'Gajah Mada University',
#  'UNIVERSITY NUSA MANDIRI': 'Nusa Nipa University',
#  'UNIVERSITY PEMBANGUNAN NASIONAL VETERAN YOGYAKARTA': 'Veteran National Development University of Yogyakarta',
#  'UNIVERSITY OF INDONESIA': 'Indonesia University',
#  'UNIVERSITY OF NORTH SUMATRA': 'Islamic University of North Sumatra',
#  'YOGYAKARTA VETERAN NATIONAL DEVELOPMENT UNIVERSITY': 'Veteran National Development University of Yogyakarta',
#  'ANGEL KANČEV UNIVERSITY OF RUSE': 'Angel Kančev University of Ruse',
#  'BALTAZAR ADAM KRČELIĆ COLLEGE OF BUSINESS ADMINISTRATION': 'Baltazar Adam Krčelić College of Business Administration',
#  'CHERNORIZETS HRABAR FREE UNIVERSITY OF VARNA': 'Chernorizets Hrabar  Free University of Varna',
#  'DA TSENOV ACADEMY OF ECONOMICS SVISHTOV': 'DA Tsenov Academy of Economics  Svishtov',
#  'GEORGE BARIȚIU UNIVERSITY': 'George Barițiu University',
#  'KONSTANTIN PRESLAVSKI SHUMEN UNIVERSITY': 'Konstantin Preslavski Shumen University',
#  'KRUSTYO SARAFOV NATIONAL ACADEMY FOR THEATRE AND FILM ARTS': 'Krustyo Sarafov National Academy for Theatre and Film Arts',
#  'LA GRACE UNIVERSITY ADVANCED TECHNICIANS SCHOOL OF BENIN': 'La Grace University Advanced Technicians School of Benin',
#  '17 AGUSTUS 1945 JAKARTA UNIVERSITY': '17 August 1945 University Jakarta',
#  'AACHEN UNIVERSITY OF APPLIED SCIENCE': 'Aachen University of Applied Sciences',
#  'ABBOTTABAD UNIVERSITY OF SCIENCE AND TECHNOLOGY': 'Abbottabad University of Science and Technology',
#  'ABDUL WALI KHAN UNIVERSITY MARDAN': 'Abdul Wali Khan University',
#  'ABE INTERNATIONAL BUSINESS COLLEGE': 'ABE International Business College',
#  'ABERYSTWYTH UNIVERSITY': 'Aberystwyth University',
#  'ABFI INSTITUTE PERBANAS': 'ABFI Institute Perbanas Jakarta',
#  'ABIA STATE UNIVERSITY': 'Abia State University',
#  'ACADEMY AVIATION TRAINING CENTER': 'Estonian Aviation Academy',
#  'ACADEMY MARITIME CIREBON': 'Maine Maritime Academy',
#  'ACADEMY OF FINANCE VIETNAM': 'Academy of Finance',
#  'ACADEMY OF HUMANITIES AND TECHNOLOGY': 'Academy of Humanities and Technology',
#  'ACADEMY OF JOURNALISM AND COMMUNICATION': 'School of Journalism and Communication',
#  'ACADEMY OF POLICY AND DEVELOPMENT': 'Development Academy of The Philippines',
#  'ACADEMY OF TOURISM NHI BANDUNG': 'Kazakh Academy of Sport and Tourism',
#  'ACCRA TECHNICAL UNIVERSITY': 'Accra Technical University',
#  'ADELEKE UNIVERSITY EDE OSUN STATE': 'Osun State University',
#  'ADHI TAMA INSTITUTE OF TECHNOLOGY': 'Adhi Tama Institute of Technology Surabaya',
#  'ADI BUANA SURABAYA UNIVERSITY': 'Sunan Giri Surabaya University',
#  'ADISUTJIPTO COLLEGE OF TECHNOLOGY': 'Baguio College of Technology',
#  'ADISUTJIPTOAEROSPACE INSTITUTE OF TECHNOLOGY': 'AirForce Institute of Technology',
#  'ADVANCE TERTIARY COLLEGE': 'Advanced Teachers Training College',
#  'ADVENTIST UNIVERSITY OF INDONESIA': 'Adventist University of Indonesia',
#  'ADVENTIST UNIVERSITY OF THE PHILIPPINES': 'Adventist University of the Philippines',
#  'AFRICA INTERNATIONAL UNIVERSITY': 'Africa International University',
#  'AGROCAMPUS WEST': 'Agrocampus West',
#  'AHMAD DAHLAN UNIVERSITY': 'Ahmad Dahlan University',
#  'AHMAD DAHLAN UNIVERSITY OF YOGYAKARTA': 'Muhammadiyah University of Yogyakarta',
#  'AIMST UNIVERSITY': 'AIMST University',
#  'AIR MARSHAL SURYADARMA UNIVERSITY': 'Suryadarma University',
#  'AIR UNIVERSITY': 'Air University',
#  'AIRLANGGA UNIVERSITY UNAIR': 'Airlangga University',
#  'AIRLANGGA UNIVERSITY INDONESIA': 'AlAzhar University Indonesia',
#  'AIRLANGGA UNIVERSITY SURABAYA': 'Bhayangkara University Surabaya',
#  'AISYIYAH YOGYAKARTA UNIVERSITY': 'Yogyakarta State University',
#  'AKADEMI KOMUNIKASI': 'Åbo Akademi University',
#  'AKPRIND INSTITUTE OF SCIENCE TECHNOLOGY': 'SRM Institute of Science and Technology',
#  'AL AZHAR INDONESIA UNIVERSITY': 'AlAzhar University Indonesia',
#  'ALAUDDIN ISLAMIC STATE UNIVERSITY': 'State Islamic University of Alauddin',
#  'ALETHEIA UNIVERSITY CHINA': 'Aletheia University',
#  'ALIGARH MUSLIM UNIVERSITY': 'Aligarh Muslim University',
#  'AMA COMPUTER COLLEGE': 'ACTS Computer College',
#  'AMIKOM PURWOKERTO UNIVERSITY': 'Muhammadiyah University of Purwokerto',
#  'AMIKOM UNIVERSITY YOGYAKARTA': 'Cokroaminoto University  Yogyakarta',
#  'AMITY BUSINESS SCHOOL': 'BGFI Business School',
#  'ANGLIA RUSKIN UNIVERSITY': 'Anglia Ruskin University',
#  'ARID AGRICULTURE UNIVERSITY RAWALPINDI': 'Anand Agricultural University',
#  'ARID INSTITUTE OF MANAGEMENT SCIENCES LAHORE': 'Institute of Management Sciences Lahore',
#  'ARMY PUBLIC COLLEGE OF MANAGEMENT SCIENCES': 'Grafton College of Management Sciences',
#  'ARS INTERNASIONAL UNIVERSITY': 'International ARS University',
#  'ARSHAD AYUB BUSINESS SCHOOL': 'Barna Business School',
#  'ASIA E UNIVERSITY': 'Asia e University',
#  'ASIA METROPOLITAN UNIVERSITY': 'Asia Metropolitan University',
#  'ASIA PACIFIC INSTITUTE OF INFORMATION TECHNOLOGY': 'COMSATS Institute of Information Technology',
#  'ASIA PACIFIC UNIVERSITY OF TECHNOLOGY INNOVATION': 'Asia Pacific University of Technology and Innovation',
#  'ASTON UNIVERSITY': 'Aston University',
#  'ASTRAKHAN STATE TECHNICAL UNIVERSITY': 'Karaganda State Technical University',
#  'ATI POLYTECHNIC PADANG': 'Bolgatanga Polytechnic',
#  'ATMA JAYA CATHOLIC UNIVERSITY': 'Atma Jaya Catholic University of Indonesia',
#  'ATMA JAYA CATHOLIC UNIVERSITY JAKARTA': 'Santa María La Antigua Catholic University',
#  'ATMA JAYA MAKASSAR UNIVERSITY': 'Atma Jaya Makassar University',
#  'ATMAJAYA CATHOLIC UNIVERSITY': 'Australian Catholic University',
#  'ATMAJAYA CATHOLIC UNIVERSITY YOGYAKARTA': 'Atma Jaya Yogyakarta University',
#  'AUCKLAND INSTITUTE OF STUDIES': 'Institute of Audiovisual Studies',
#  'AUCKLAND UNIVERSITY OF TECHNOLOGY': 'Auckland University of Technology',
#  'AVIATION POLYTECHNIC OF MAKASSAR': 'Polytechnical Institute of Madagascar',
#  'AZZAHRA UNIVERSITY': 'Azzahra University',
#  'BABSON COLLEGE': 'Babson College',
#  'BACH KHOA UNIVERSITY': 'Hoa Binh University',
#  'BACHELOR OF BUSINESS ADMINISTRATION HONS INTERNATIONAL BUSINESS': 'Riga International School of Economics and Business Administration',
#  'BADDI UNIVERSITY OF EMERGING SCIENCES AND TECHNOLOGY': 'Baddi University of Emerging Sciences and Technology',
#  'BAHAUDDIN ZAKARIYA UNIVERSITY': 'Bahauddin Zakariya University',
#  'BAHRIA UNIVERSITY': 'Bahria University',
#  'BAHRIA UNIVERSITY ISLAMABAD': 'Islamic Batik University',
#  'BAKRIE UNIVERISTY': 'Bakrie University',
#  'BALI STATE POLYTECHNIC': 'Stella Maris Polytechnic',
#  'BALI TOURISM INSTITUTE': 'Azerbaijan Institute of Tourism',
#  'BALI TOURISM POLYTECHNIC': 'Polytechnic of Turin',
#  'BALOCHISTAN UNIVERSITY OF ENGINEERING AND TECHNOLOGY KHUZDAR': 'Balochistan University of Engineering and Technology Khuzdar',
#  'BALOCHISTAN UNIVERSITY OF INFORMATION TECHNOLOGY ENGINEERING AND MANAGEMENT SCIENCES': 'CECOS University of Information Technology and Emerging Sciences',
#  'BANARAS HINDU UNIVERSITY': 'Banaras Hindu University',
#  'BANDAR LAMPUNG UNIVERSITY': 'Bandar Lampung University',
#  'BANDUNG INSITUTE OF TECHNOLOGY': 'Bandung Institute of Technology',
#  'BANDUNG INSTITUTE OF TECHNOLOGYINSTITUT TEKNOLOGI BANDUNG': 'Bandung Institute of Science and Technology',
#  'BANDUNG INSTITUTE OF TOURISM': 'Institute of Business and Tourism',
#  'BANDUNG ISLAM UNIVERSITY': 'Islamic University of Bandung',
#  'BANDUNG LAW SCHOOL': 'Bandung School of Law',
#  'BANDUNG NATIONAL INSTITUE OF TECHNOLOGY': 'Bandung National Institute of Technology',
#  'BANDUNG RAYA OF UNIVERSITY': 'Bandung Raya University',
#  'BANDUNG STATE OF POLYTECHNIC': 'Camiguin Polytechnic State College',
#  'BANGKOK SUVARNABHUMI COLLEGE': 'Bangkok Suvarnabhumi College',
#  'BANGLADESH UNIVERSITY OF PROFESSIONALS': 'Bangladesh University of Professionals',
#  'BANKING ACADEMY OF VIETNAM': 'Banking Academy of Vietnam',
#  'BANKING UNIVERSITY OF HO CHI MINH CITY': 'Banking University of Ho Chi Minh City',
#  'BANYUWANGI MARITIME ACADEMI': 'Antwerp Maritime Academy',
#  'BATAM INTERNATIONAL UNIVERSITY': 'International University Batam',
#  'BATAM STATE POLYTECHNIC': 'The Polytechnic',
#  'BATIK ISLAMIC UNIVERSITY OF SURAKARTA': 'Islamic Batik University',
#  'BEIHANG UNIVERSITY': 'Beihang University',
#  'BEIJING INSTITUTE OF TECHNOLOGY': 'Beijing Institute of Technology',
#  'BEIJING UNIVERSITY OF CHEMICAL TECHNOLOGY': 'Beijing University of Chemical Technology',
#  'BELARUSIANRUSSIAN UNIVERSITY': 'BelarusianRussian University',
#  'BENAZIR BHUTTO SHAHEED UNIVERSITY LYARI': 'Benazir Bhutto Shaheed University Lyari',
#  'BENGKULU UNIVERSITY': 'Bengkulu University',
#  'BERJAYA UNIVERSITY COLLEGE': 'BERJAYA University College',
#  'BHAKTI KENCANA UNIVERSITY': 'Panca Bhakti University',
#  'BHARATHIAR UNIVERSITY': 'Bharathiar University',
#  'BHARATI VIDYAPEETH DEEMED UNIVERSITY PUNE': 'Bharati Vidyapeeth Deemed to be University',
#  'BHAYANGKARA JAKARTA RAYA': 'Bhayangkara Jakarta Raya University',
#  'BICOL UNIVERSITY': 'Bicol University',
#  'BILKENT UNIVERSITY': 'Bilkent University',
#  'BINA BANGSA UNIVERCITY': 'Nusa Bangsa University',
#  'BINA BUSANTARA UNIVERSITY': 'Dian Nusantara University',
#  'BINA DARMA UNIVERSITY': 'Bina Darma University',
#  'BINA INSANI UNIVERSITY': 'Ba Isago University',
#  'BINA NUSANTARA UNIVERSITY ONLINE PROGRAM': 'Kediri Nusantara PGRI University',
#  'BINA NUSANTARA UNIVERSITY MALANG': 'Dian Nusantara University',
#  'BINAWAN UNIVERSITY': 'Okinawa University',
#  'BINUS ASO SCHOOL OF ENGINEERING': 'School of Engineering',
#  'BINUS SCHOOL OF COMPUTER SCIENCE': 'School of Computer Science',
#  'BINUS UNIVERSITY JAKARTA': 'Jakarta University',
#  'BIOTECHNOLOGY RESEARCH INSTITUTE': 'Forest Research Institute',
#  'BIRMINGHAM CITY UNIVERSITY': 'Birmingham City University',
#  'BIRSA INSTITUTE OF TECHNOLOGY SINDRI': 'Birla Institute of Technology',
#  'BLESSED TRINITY COLLEGE': 'Blessed Trinity College',
#  'BLUE MOUNTAINS INTERNATIONAL HOTEL MANAGEMENT SCHOOL': 'Blue Mountains International Hotel Management School',
#  'BOGIR AGRICULTURAL UNIVERSITY': 'Bogor Agricultural University',
#  'BOGOR AGRICULTURAL INSTITUTE': 'Bogor Agricultural University',
#  'BOGOR PAKUAN UNIVERSITY': 'Pakuan University',
#  'BOND UNIVERISTY': 'Bond University',
#  'BONNRHEINSIEG UNIVERSITY OF APPLIED SCIENCES': 'BonnRheinSieg University of Applied Sciences',
#  'BORNEO UNIVERSITY OF TARAKAN': 'Borneo Tarakan University',
#  'BOROBUDUR UNIVERSITY': 'Borobudur University',
#  'BOSOWA UNIVERSITY': 'Showa University',
#  'BOY AGRICULTURAL UNIVERSITY': 'Bogor Agricultural University',
#  'BPP UNIVERSITY': 'BPP University',
#  'BRAC UNIVERSITY': 'BRAC University',
#  'BRAWIJAWA UNIVERSITY': 'Brawijaya University',
#  'BRAWIJAYA NATIONAL UNIVERSITY': 'National Law University',
#  'BRICKFIELDS ASIA COLLEGE': 'Brookfield College',
#  'BRITISH UNIVERSITY VIETNAM': 'Vietnam Maritime University',
#  'BRUNEL UNIVERSITY LONDON': 'Brunel University',
#  'UNIVERSITY BINA SARANA INFORMATIKA': 'Manonmaniam Sundaranar University',
#  'BSI UNIVERSITY': 'Asia University',
#  'BUANA PERJUANGAN KARAWANG UNIVERSITY': 'Sangga Buana University',
#  'BUDAPEST UNIVERSITY OF TECHNOLOGY AND ECONOMICS': 'Budapest University of Technology and Economics',
#  'BUDDHI DHARMA UNIVERSITY': 'Bina Darma University',
#  'BUNG KARNO UNIVERSITY': 'Bung Karno University',
#  'BUSINESS ADMINISTRATION': 'Institute of Business Administration',
#  'BUSINESS HOTEL MANAGEMENT SCHOOL': 'Business Management  School',
#  'BUSINESS SCHOOL IPB UNIVERSITY': 'Universal Business School',
#  'CAIRO UNIVERSITY': 'Cairo University',
#  'CALCUTTA UNIVERSITY': 'University of Calcutta',
#  'CALIFORNIA STATE POLYTECHNIC UNIVERSITY POMONA': 'California State Polytechnic UniversityPomona',
#  'CALIFORNIA STATE UNIVERSITY OF LONG BEACH': 'California State UniversityLong Beach',
#  'CALIFORNIA STATE UNIVERSITYFULLERTON': 'California State UniversityFullerton',
#  'CAMPBELL UNIVERSITY': 'Campbell University',
#  'CAMPUS UNIVERSITAS PRAMITA': 'LINK CAMPUS University',
#  'CAN THO UNIVERSITY': 'Can Tho University',
#  'CANAKKALE ONSEKIZ MART UNIVERSITY': 'Suez Canal University',
#  'CANKAYA UNIVERSITY': 'Çankaya University',
#  'CAPITAL UN IVERSITY OF SCIENCE AND TECHNOLOGY ISLAMABAD': 'Institute of Applied Sciences and Technology',
#  'CAPITAL UNIVERSITY OF SCIENCE TECHNOLOGY': 'Al Ain University of Science and Technology',
#  'CARDIFF METROPOLITAN UNIVERSITY': 'Cardiff Metropolitan University',
#  'CARNEGIE MELLON UNIVERSITY': 'Carnegie Mellon University',
#  'CASS BUSINESS SCHOOL CITY UNIVERSITY OF LONDON': 'University of Lorraine  ICN Business School',
#  'CATHOLIC PARAHYANGAN UNIVERSITY': 'Parahyangan Catholic University',
#  'CATHOLIC SANTO THOMAS UNIVERSITY': 'Saint Thomas Catholic University',
#  'CATHOLIC UNIVERSITY OF ATMA JAYA': 'Atma Jaya Catholic University of Indonesia',
#  'CATOLIC UNIVERSITY OF WIDYA MANDALA MADIUN': 'Widya Mandala Catholic University of Madiun',
#  'CATUR INSAN CENDEKIA UNIVERSITY': 'Indiana University East',
#  'CECOS UNIVERSITY OF IT EMERGING SCIENCES': 'University of Economic Sciences',
#  'CECOS UNIVERSITY PESHAWAR': 'University of Peshawar',
#  'CENDERAWASIH UNIVERSITY': 'Cenderawasih University',
#  'CENTRAL UNIVERSITY OF FINANCE AND ECONOMICS': 'Central University of Finance and Economics',
#  'CENTRAL WASHINGTON UNIVERSITY': 'Central Washington University',
#  'CENTRO ESCOLAR UNIVERSITY': 'Centro Escolar University',
#  'CHANDIGARH UNIVERSITY': 'Chandigarh University',
#  'CHANDRAGUPT INSTITUTE OF MANAGEMENT PATNA': 'Indian Institute of Management Ranchi',
#  'CHANG JUNG CHRISTIAN UNIVERSITY': 'Chang Jung Christian University',
#  'CHATOLIC MUSI CHARITAS UNIVERSITY': 'Catholic University of Argentina',
#  'CHENG SHIU UNIVERSITY': 'Cheng Shiu University',
#  'CHIA NAN UNIVERSITY OF PHARMACY AND SCIENCE': 'Chia Nan University of Pharmacy and Science',
#  'CHIA NAN UNIVERSITY TAIWAN': 'National Chi Nan University',
#  'CHONGQING MEDICAL UNIVERSITY': 'China Medical University',
#  'CHONGQING UNIVERSITY OF ARTS AND SCIENCE': 'Hunan University of Arts and Science',
#  'CHRISTIAN INDONESIA PAULUS UNIVERSITY MAKASSAR': 'Paul Christian University of Indonesia',
#  'CHRISTIAN MARANATHA UNIVERSITY': 'Maranatha Christian University',
#  'CHRISTIAN SATYA WACANA UNIVERSITY': 'Satya Wacana Christian University',
#  'CHULALONGKORN UNIVERSITY': 'Chulalongkorn University',
#  'CIPUTRA UNIVERSITY': 'Tripura University',
#  'CITY LAW SCHOOL': 'Bucerius Law School',
#  'CITY UNIVERSITY LONDON': 'City University London',
#  'CITY UNIVERSITY MALAYSIA': 'Nagoya City University',
#  'CIVIL AVIATION SAFETY AND ENGINEERING ACADEMY': 'Odessa State Academy of Civil Engineering and Architecture',
#  'COLGATE UNIVERSITY': 'Colgate University',
#  'COLLEGE OF FOREIGN ECONOMIC RELATION': 'YAI College of Economics',
#  'COLLEGE OF FOREIGN LANGUAGE STIBA MALANG': 'College of Foreign Languages in Swiecie',
#  'COLLEGE OF NURSING SUBANG JAYA MEDICAL CENTRE': 'Makati Medical Center College of Nursing',
#  'COLLEGE UNIVERSITY POLYTECH MARA KUALA LUMPUR': 'Kuala Lumpur Metropolitan University College',
#  'COLORADO SCHOOL OF MINES': 'Colorado School of Mines',
#  'COMMERCIAL ADMINISTRATION': 'University of Administration',
#  'COMPUTER SCIENCE': 'School of Computer Science',
#  'COMPUTER UNIVERSITY': 'AMA Computer University',
#  'COMSATS INSTITUTION OF INFORMATION TECHNOLOGY': 'COMSATS Institute of Information Technology',
#  'COMSATS UNIVERSITY ISLAMABAD': 'Comrat State University',
#  'COOPERATIVE INSTITUTE OF INDONESIA': 'Indonesian Institute of Cooperative  Management',
#  'CORNELL UNIVERSITY': 'Cornell University',
#  'COSMOPOINT COLLEGE': 'Rosemont College',
#  'COTTON UNIVERSITY': 'Cotton University',
#  'COVENTRY UNIVERSITY': 'Coventry University',
#  'CRAWFORD UNIVERSITY': 'Crawford University',
#  'CRISTIAN UNIVERSITY OF INDONESIA': 'Christian University of Indonesia',
#  'CUNY HUNTER COLLEGE': 'Humber College',
#  'CURTIN UNIVERSITY MALAYSIA': 'Curtin University',
#  'CURTIN UNIVERSITY SARAWAK': 'Curtin University',
#  'CYBERJAYA UNIVERSITY': 'Cyber University',
#  'CYBERNETICS INTERNATIONAL COLLEGE OF TECHNOLOGY': 'International Institute of Technology',
#  'CẦN THƠ UNIVERSITY': 'Can Tho University',
#  'DA NANG UNIERSITY OF ECONOMICS': 'Nagoya University of Economics',
#  'DAEGU GYEONGBUK INSTITUTE OF SCIENCE AND TECHNOLOGY': 'Bandung Institute of Science and Technology',
#  'DAEJEON UNIVERSITY': 'Maejo University',
#  'DALIAN UNIVERSITY OF FINANCE AND ECONOMICS': 'Anhui University of Finance and Economics',
#  'DARMA AGUNG UNIVERSITY': 'Darma Agung University',
#  'DARMA CENDIKA UNIVERSITY SURABAYA': 'Bhayangkara University Surabaya',
#  'DARMA PERSADA UNIVERSITY': 'Darma Persada University',
#  'DARMSTADT UNIVERSITY OF APPLIED SCIENCES': 'Darmstadt University of Applied Sciences',
#  'DARUL ULUM UNIVERSITY': 'Darul Ulum University',
#  'DARUSSALAM GONTOR UNIVERSITY': 'Assam Down Town University',
#  'DAV SCHOOL OF BUSINESS MANAGEMENT': 'Business Management  School',
#  'DAWOOD UNIVERSITY OF ENGINEERING TECHNOLOGY': 'Dawood University of Engineering and Technology',
#  'DE LA SALLE CATHOLIC UNIVERSITY': 'De La Salle Catholic University',
#  'DE LA SALLE UNIVERSITY': 'De La Salle University',
#  'DE MONTFORT UNIVERSITY': 'De Montfort University',
#  'DEAKIN UNIVERSITY': 'Deakin University',
#  'DEFENSE UNIVERSITY INDONESIAN': 'Indonesian Development University',
#  'DEFENSE UNIVERSITY OF REPUBLIC OF INDONESIA': 'Veteran University of the Republic of Indonesia',
#  'DEL INSTITUTE OF TECHNOLOGY': 'Institute of Technology',
#  'DELFT UNIVERISTY OF TECHNOLOGY TU DELFT': 'Delft University of Technology',
#  'DENMARK INSTITUE OF TECHNOLOGY': 'Dundalk Institute of Technology',
#  'DEPARTMENT OF COMPUTER SCIENCE UNIVERSITY OF KARACHI': 'National University of Computer and Emerging Sciences',
#  'DESPARK COLLEGE': 'SPA College',
#  'DHA SUFFA UNIVERSITY': 'DHA Suffa University',
#  'DHARMA ANDALAS UNIVERSITY': 'Andalas University',
#  'DHARMA BUMIPUTERA SCHOOL OF ECONOMICS': 'School of Administration and Economics',
#  'DHYANA PURA BALI UNIVERSITY': 'Darwan Ali University',
#  'DIAN NUSWANTORO UNIVERSITY': 'Dian Nuswantoro University',
#  'DICKINSON COLLEGE': 'Dickinson College',
#  'DIPENGORO UNIVERSITY': 'Diponegoro University',
#  'DIPLOMATIC ACADEMY OF VIETNAM': 'Diplomatic Academy of Vietnam',
#  'DIPONEGORO OF UNIVERSITY': 'Diponegoro University',
#  'DIPONEGORO UNIVERSITY UNIVERSITAS DIPONEGORO': 'Moi University  Rongo University College',
#  'DIPONEGORO UNIVERSITY INDONESIA': 'Diponegoro University',
#  'DJUANDA BOGOR UNIVVERSITY': 'Djuanda University',
#  'DJUANDA UNIVERSITY': 'Djuanda University',
#  'DONG NAI UNIVERSITY': 'Dong Nai University',
#  'DOW UNIVERSITY OF HEALTH SCIENCES': 'Dow University of Health Sciences',
#  'DR SOETOMO UNIVERSITY': 'Dr Soetomo University',
#  'DRB HICOM UNIVERSITY OF AUTOMOTIVE MALAYSIA': 'Islamic University of Malaysia',
#  'DRIYARKARA SCHOOL OF PHILOSOPHY': 'Munich School of Philosophy',
#  'DUBLIN BUSINESS SCHOOL': 'Dublin Business School',
#  'DURHAM UNIVERSITY': 'Durham University',
#  'DUTA WACANA CHRISTIAN UNIVERSITY': 'Duta Wacana Christian University',
#  'DUY TAN UNIVERSITY': 'Duy Tan University',
#  'EASTERN INTERNATIONAL UNIVERSITY': 'Eastern International University',
#  'EASTERN MEDITERRANEAN UNIVERSITY TURKEY': 'Eastern Mediterranean University',
#  'EDINBURGH NAPIER': 'Edinburgh Napier University',
#  'EDUCATION UNIVERSITY OF INDONESIAN': 'Indonesia University of Education',
#  'EFARINA UNIVERSITY': 'Mariana University',
#  'EL RAHMA EDUCATION CENTRE': 'Higher Education Centre',
#  'ELANGOR INTERNATIONAL ISLAMIC UNIVERSITY COLLEGE': 'Selangor International Islamic University College',
#  'ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA': 'Technical Institute of Aeronautical Engineering',
#  'ELITE INTERNATIONAL COLLEGE': 'Ebenezer International Colleges',
#  'ELIZABETH INTERNATIONAL': 'DellArte International',
#  'EMBRYRIDDLE AERONAUTICAL UNIVERSITY': 'EmbryRiddle Aeronautical University',
#  'EMLYON BUSINESS SCHOOL': 'EM Lyon Business School',
#  'ERASMUS UNIVERSITY UNIVERSITAS GADJAH MADA': 'Durham University  Durham University',
#  'ERASMUS UNIVERSITY ROTTERDAM': 'Erasmus University Rotterdam',
#  'ERCIYES UNIVERSITY': 'Erciyes University',
#  'ERCIYES ÜNIVERSITESI TURKEY': 'Erciyes University',
#  'ESA UNGGUL JAKARTA UNIVERSITY': 'Esa Unggul University',
#  'ESC RENNES BUSINESS SCHOOL': 'ESC Rennes Business School',
#  'ESQ BUSINESS SCHOOL': 'ESA Business School',
#  'ESSEC BUSINESS SCHOOL': 'ESSEC Business School',
#  'EWHA WOMANS UNIVERSITY': 'Texas Womans University',
#  'FACULTY OF ANIMAL SCIENCE GADJAH MADA UNIVERSITY': 'University of Human Arts and Sciences',
#  'FACULTY OF ECONOMIC AND COMMUNICATION': 'Faculty of Communication',
#  'FACULTY OF ECONOMICS AND BUSINESS UNIVERSITAS GADJAH MADA': 'Hebei University of Economics and Business',
#  'FACULTY OF PSYCHOLOGY AIRLANGGA UNIVERSITY': 'Ilmenau University of Technology',
#  'FACULTY OF SOCIAL AND POLITIC SCIENCE': 'College of Political and Social Sciences',
#  'FACULTY OF TECHNOLOGY INFORMATION': 'Infórium Faculty of Technology',
#  'FAJAR UNIVERS': 'Fajar University',
#  'FAKULTAS HUKUM UNIVERSITAS SEBELAS MARET': 'Sebelas Maret University',
#  'FALCUTY OF LAW': 'Faculty of Jau',
#  'FAR EASTERN FEDERAL UNIVERSITY': 'The Far Eastern University',
#  'FAST NATIONAL INSTITUTE OF COMPUTER AND EMERGING SCIENCES': 'Galileo Institute of Computer Science and Engineering',
#  'FAST NATIONAL UNIVERSITY OF COMPUTER EMERGING SCIENCES': 'National University of Computer and Emerging Sciences',
#  'FATIMA JINNAH WOMEN UNIVERSITY': 'Fatima Jinnah Women University',
#  'FEDERAL UNIVERSITY OF TECHNOLOGY OWERRI': 'Federal University of Technology',
#  'FEDERAL URDU UNIVERSITY OF ART SCIENCE AND TECHNOLOGY': 'Yu Da University of Science and Technology',
#  'FEDERATION UNIVERSITY AUSTRALIA': 'Federation University Australia',
#  'FLINDERS UNIVERSITY SOUTH AUSTRALIA': 'University of South Australia',
#  'FLORIDA INTERNATIONAL UNIVERSITY': 'Florida International University',
#  'FOREGIN TRADE UNIVERSITY HA NOI VIET NAM': 'Foreign Trade University',
#  'FOREIGN TRADE UNIVERSITY': 'Foreign Trade University',
#  'FORMAN CHRISTIAN COLLEGE A CHARTERED UNIVERSITY': 'Ghana Christian University College',
#  'FOUNDATION UNIVERSITY': 'Foundation University',
#  'FOUNDATION UNIVERSITY ISLAMABAD': 'Navarra University Foundation',
#  'FOUNDATION UNIVERSITY RAWALPINDI CAMPUS': 'María Caño University Foundation',
#  'FPT UNIVERSITY': 'FTP University',
#  'FPT ARENA HCMC UNIVERSITY OF CULTURE': 'University of Agriculture',
#  'FPT POLY TECHNIC': 'Otago Polytechnic',
#  'FRANKFURT UNIVERSITY OF APPLIED SCIENCES': 'Frankfurt University of Applied Sciences',
#  'FRIEDRICH SCHILLER UNIVERSITY JENA GERMANY': 'Friedrich Schiller University Jena',
#  'FT UNIVERSITAS MUHAMMADIYAH JAKARTA': 'Muhammadiyah University of Jakarta',
#  'FTMS COLLEGE': 'Thomas College',
#  'FUDAN UNIVERSITY': 'Fudan University',
#  'GL BAJAJ INSTITUTE OF MANAGEMENT AND RESEARCH': 'SP Jain Institute of Management and Research',
#  'GADJAH MAD UNIVERSITY': 'Gajah Mada University',
#  'GADJAH MADA UNIVERSITY BRAWIJAYA UNIVERSITY': 'Durham University  Durham University',
#  'GADJAH MADA UNIVERSITY INDONESIA': 'AlAzhar University Indonesia',
#  'GAJAH MADA UNIVERSITY': 'Gajah Mada University',
#  'GAJAYANA MALANG UNIVERSITY': 'Gajayana University Malang',
#  'GALUH UNIVERSITY': 'Galuh University',
#  'GANESHA UNIVERSITY OF EDUCATION': 'Ganesha University of Education',
#  'GARUT UNIVERSITY': 'Garut University',
#  'GC UNIVERSITY FAISLABAD': 'The University of Faisalabad',
#  'GOVERNMENT COLLEGE UNIVERSITY FAISALABAD': 'Government College University',
#  'GDANSK UNIVERSITY OF TECHNOLOGY': 'Gdansk University of Technology',
#  'GENDERAL SOEDIRMAN UNIVERSITY': 'General Soedirman University',
#  'GENERAL ACHMAD YANI UNIVERSITY': 'Jenderal Achmad Yani University',
#  'GEOMATIKA UNIVERSITY COLLEGE': 'TATI University College',
#  'GEORGIA INSTITUTE OF TECHNOLOGY': 'Georgia Institute of Technology',
#  'GERMAN MALAYSIAN INSTITUTE': 'Mahatma Gandhi Institute',
#  'GHAZI UNIVERSITY D G KHAN': 'Aga Khan University',
#  'GHULAM ISHAQ KHAN INSTITUTE OF ENGINEERING AND TECHNOLOGY TOPI SAWABI': 'Ghulam Ishaq Khan Institute of Engineering Sciences and Technology',
#  'GICI BUSSINES SCHOOL': 'ICD Business School',
#  'GIFU UNIVERSITY JAPAN': 'Gifu University',
#  'GIK INSTITUTE OF ENGINEERING SCIENCES AND TECHNOLOGY': 'Indian Institute of Engineering Science and Technology',
#  'GOLDSMITHS UNIVERSITY OF LONDON': 'University of East London',
#  'GORONTALO STATE UNIVERSITY': 'Gorontalo State University',
#  'GOVT COLLEGE WOMEN UNIVERSITY OF FAISALABAD': 'Lahore College for Women University',
#  'GOVERNMENT COLLEGE UNIVERSITY LAHORE': 'Government College University',
#  'GOVERNMENT SADIQ COLLEGE WOMEN UNIVERSITYBAHAWALPUR': 'Government College University',
#  'GRAPHIC ERA HILL UNIVERSITY': 'Graphic Era Hill University',
#  'GREAT ZIMBABWE': 'Great Zimbabwe University',
#  'GREENWICH UNIVERSITY': 'Greenwich University',
#  'GUNADARMA UNIVERSITY': 'Gunadarma University',
#  'GUNMA UNIVERSITY JAPAN': 'Gunma University',
#  'HA NOI UNIVERSITY OF PUBLIC HEALTH': 'Hanoi University of Public Health',
#  'HALU OLEO UNIVERSITY': 'Haluoleo University',
#  'HAMDARD UNIVERSITY': 'Hamdard University',
#  'HAMKA UNIVERSITY': 'Thamar University',
#  'HAN UNIVERSITY OF APPLIED SCIENCES': 'HAN University of Applied Sciences',
#  'HANG TUAH UNIVERESITY': 'Hang Tuah University',
#  'HANOI FOREIGN TRADE UNIVERSITY': 'Foreign Trade University',
#  'HANOI LAW UNIVERSITY': 'Hanoi Law University',
#  'HARAPAN BANGSA BUSINESS SCHOOL': 'Barna Business School',
#  'HARAPAN BANGSA INSTITUTE OF TECHNOLOGY': 'Harapan Bangsa Institute of Technology',
#  'HARBIN INSTITUTE OF TECHNOLOGY': 'Harbin Institute of Technology',
#  'HARVARD UNIVERSITY': 'Harvard University',
#  'HASANIDDIN UNIVERSITY': 'Hasanuddin University',
#  'HASANUDDIN UNIVERSITY OF MAKASSAR': 'Islamic University of Makassar',
#  'HAZARA UNIVERSITY MANSEHRA': 'Haramaya University',
#  'HCM CITY UNIVERSITY OF TECHNOLOGY AND EDUCATION': 'Ho Chi Minh City University of Technology and Education',
#  'HCM VNU INTERNATIONAL UNIVERSITY': 'International University',
#  'HCMC OPEN UNIVERSITY': 'Open University',
#  'HELO UNIVERSITY': 'Elon University',
#  'HELP COLLEGE OF ARTS AND TECHNOLOGY': 'Isabela College of Arts and Technology',
#  'HELP UNIVERISTY': 'HELP University',
#  'HELSINKI METROPOLIA UNIVERSITY OF APPLIED SCIENCES': 'Metropolia University of Applied Sciences',
#  'HERIOT WATT UNIERSITY MALAYSIA': 'Himalayan University',
#  'HERIOTWATT UNIVERSITY': 'HeriotWatt University',
#  'HIGH SCHOOL': 'IFP School',
#  'HIGH SCHOOL OF INFORMATICS AND COMPUTER MANAGEMENT MIKROSKIL': 'Schoo of Informatics Management and Computer Sciences',
#  'HIMACHAL PRADESH UNIVERSITY INDIA': 'Himachal Pradesh University',
#  'HIROSHIMA UNIVERSITY': 'Hiroshima University',
#  'HITEC UNIVERSITY': 'HITEC University',
#  'HKBP NOMENSEN UNIVERSITY': 'Nommensen HKBP University',
#  'HO CHI MINH BACH KHOA UNIVERSITY': 'Ho Chi Minh City University of Law',
#  'HO CHI MINH CITY INTERNATIONAL UNIVERSITY': 'Industrial University of Ho Chi Minh City',
#  'HO CHI MINH CITY OPEN UNIVERSITY': 'Ho Chi Minh City Open University',
#  'HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY': 'Ho Chi Minh University of Technology',
#  'HO CHI MINH CITY UNIVERSITY OF ECONOMICS AND LAW': 'University of Economics Ho Chi Minh City',
#  'HO CHI MINH CITY UNIVERSITY OF FOOD INDUSTRY': 'Ho Chi Minh City University of Food Industry',
#  'HO CHI MINH CITY UNIVERSITY OF FOREIGN LANGUAGES AND INFORMATION TECHNOLOGY': 'Ho Chi Minh City University of Foreign Languages and Information Technology',
#  'HO CHI MINH CITY UNIVERSITY OF SCIENCE': 'Ho Chi Minh City Open University',
#  'HO CHI MINH UNIVERSITY OF MEDICINE AND PHARMACY': 'Ho Chi Minh City University of Medicine and Pharmacy',
#  'HOA SEN UNIVERSITY': 'Hoa Sen University',
#  'HOCHSCHULE MANNHEIM MANNHEIM UNIVERSITY OF APPLIED SCIENCES': 'Mannheim University of Applied Sciences',
#  'HOKKAIDO UNIVERSITY JAPAN': 'Hokkaido University',
#  'HONG KONG BAPTIST UNIVERSITY HONG KONG': 'Hong Kong Baptist University',
#  'HONGBANG INTERNATIONAL UNIVERSITY': 'Hongbang International University',
#  'HUAZHONG UNIVERSITY OF SCIENCE AND TECHNOLOGY': 'Huazhong University of Science and Technology',
#  'HUE UNIVERSITY': 'Hue University',
#  'HUE UNIVERSITY OF FOREIGN LANGUAGES': 'Dalian University of Foreign Languages',
#  'HUFIHO CHI MINH UNIVERSITY OF FOOD INDUSTRY': 'Ho Chi Minh City University of Food Industry',
#  'HUMBER COLLEGE': 'Humber College',
#  'HUNGARIAN UNIVERSITY OF AGRICULTURE AND LIFE SCIENCE MATE': 'Gorgan University of Agriculture and Natural Resources',
#  'HUTECH UNIVERSITY': 'Hechi University',
#  'ICET UNIVERSITY OF THE PUNJAB LAHORE': 'The University of Lahore',
#  'INDONESIA INTERNATIONAL INSTITUTE FOR LIFE SCIENCES': 'International Institute for Population Sciences',
#  'IACT COLLEGE': 'ICCT Colleges',
#  'UNIVERSITY IBA': 'Iba University',
#  'IBA UNIVERSITY PALEMBANG': 'Palembang University',
#  'IBBI UNIVERSITY': 'Ibb University',
#  'IBMT INTERNATIONAL UNIVERSITY': 'Akita International University',
#  'IBMT SCHOOL OF MANAGEMENT': 'School of Management',
#  'IBN KHALDUN BOGOR': 'Ibn Khaldun University   Bogor',
#  'IMPERIAL COLLEGE OF BUSINESS STUDIES': 'National Taipei College of Business',
#  'IESEG SCHOOL OF MANAGEMENT': 'IESEG School of Management',
#  'IFIM BUSINESS SCHOOL': 'School of Business',
#  'IIEE NED UNIVERSITY OF ENGINEERING AND TECHNOLOGY': 'NED University of Engineering and Technology',
#  'IILM COLLEGE OF ENGINEERING AND TECHNOLOGY': 'College of Engineering and Information Technology',
#  'INTERNATIONAL ISLAMIC UNIVERSITY MALAYSIA': 'International Islamic University Malaysia',
#  'ILMA UNIVERSITY': 'ILMA University',
#  'IMPERIAL COLLEGE LONDON': 'Imperial College London',
#  'IMSTITUT TEKNOLOGI SEPULUH NOPEMBER': 'Sepuluh November Institute of Technology',
#  'INABA BUSSINES SCHOOL': 'ESIBA Business School',
#  'INDEPENDENT UNIVERSITY BANGLADESH': 'Independent University of Angola',
#  'INDIAN INSTITUTE OF INFORMATION TECHNOLOGY': 'Indian Institute of Information Technology',
#  'INDIAN INSTITUTE OF MANAGEMENT': 'Indian Institute of Management',
#  'INDIANA UNIVERSITY BLOOMINGTON': 'Indiana University Bloomington',
#  'INDIANA UNIVERSITY PURDUE UNIVERSITY INDIANAPOLIS': 'Indiana UniversityPurdue University Indianapolis',
#  'INDO GLOBAL MANDIRI': 'Indo Global Mandiri University',
#  'INDONESIA BANKING SCHOOL': 'Indonesian School of Art   Bandung',
#  'INDONESIA COLLAGE OF ECONOMICS': 'Haikou College of Economics',
#  'INDONESIA COMPUTER UNIVERSITY': 'Indonesian Computer University',
#  'INDONESIA INSTITUTE OF EDUCATION': 'Federal Institute of Education',
#  'INDONESIA ISLAMIC UNIVERSITY': 'Islamic University of Indonesia',
#  'INDONESIA JENTERA SCHOOL OF LAW': 'Indonesian School of Management',
#  'INDONESIAN ADVENTIST UNIVERSITY': 'Adventist University of Indonesia',
#  'INDONESIAN CHRISTIAN UNIVERSITY PAULUS MAKASSAR': 'Indonesian Christian Maluku University',
#  'INDONESIAN COOPERATIVE MANAGEMENT INSTITUTE': 'Indonesian Institute of Cooperative  Management',
#  'INDONESIAN HIGH SCHOOL OF ECONOMICS': 'Higher School of Economics',
#  'INDUS UNIVERSITY GULSHAN CAMPUS KARACHI': 'LINK CAMPUS University',
#  'INDUSTRIAL UNIVERSITY OF HO CHI MINH CITY': 'Industrial University of Ho Chi Minh City',
#  'INFORMATICS BUSINESS INSTITUTE DARMAJAYA': 'Informatics and Business Institute Darmajaya',
#  'INFORMATION TECHNOLOGY UNIVERSITY LAHORE': 'Jaypee University of Information Technology',
#  'INFRASTRUCTURE UNIVERSITY KUALA LUMPUR': 'Infrastructure University Kuala Lumpur',
#  'UNIVERSITY METHODIST INDONESIA': 'Methodist University of Indonesia',
#  'INSA LYON': 'INSA  Lyon',
#  'INSEAD': 'INSEAD',
#  'INSEEC BUSINESS SCHOOL': 'INSEEC Business School',
#  'INSITITUT TEKNOLOGI HARAPAN BANGSA': 'Harapan Bangsa Institute of Technology',
#  'INSITITUT TEKNOLOGI PLN': 'Technological Institute of León',
#  'INSITUT SAINS DAN TEKNOLOGI NASIONAL': 'National Institute of Science and Technology',
#  'INSITUT TEKNOLOGI MEDAN': 'Medan Institute of Technology',
#  'INSITUT TEKNOLOGI NASIONAL BANDUNG': 'Bandung National Institute of Technology',
#  'INSITUTE COMMUNICATIONS AND BUSINESS LSPR JAKARTA': 'Institute of Communication and Business Studies',
#  'INSTIPER YOGYAKARTA': 'STIE YKPN Yogyakarta',
#  'INSTITU SENI INDONESIA PADANG PANJANG': 'Indonesian Institute of Art   Padang Panjang',
#  'INSTITU TEKNOLOGI SAINS BANDUNG': 'Bandung Institute of Technology',
#  'INSTITUSI TEKNIK': 'Khangai Institute',
#  'INSTITUT BISNIS MULTIMEDIA ASMI': 'Institute for Business and Multimedia',
#  'INSTITUT BISNIS NUSANTARA': 'Nusantara Business Institute',
#  'INSTITUT ILMU ADMINISTRASI DAN MANAJEMEN STIAMI': 'Institute of Administration and Management',
#  'INSTITUT ILMU KESEHATAN BHAKTI WIYATA KEDIRI': 'Bhakti Wiyata Kediri Institute of Medical Sciences',
#  'INSTITUT INDONESIA RAYA': 'Indian Law Institute',
#  'INSTITUT INFORMATIKA BISNIS DARMAJAYA': 'Informatics and Business Institute Darmajaya',
#  'INSTITUT MANAJEMEN KOPERASI INDONESIA': 'Indian Institute of Management',
#  'INSTITUT MANAJEMEN TELKOM': 'Institute of Management',
#  'INSTITUT PERBANAS': 'Pratt Institute',
#  'INSTITUT PERBANAS JAKARTA': 'ABFI Institute Perbanas Jakarta',
#  'INSTITUT PERTANIAN BOGOR IPB UNIVERSITY': 'Panafrican University Institute',
#  'INSTITUT PERTANIAN STIPER': 'Nan Tien Institute',
#  'INSTITUT PTIQ JAKARTA': 'Jakarta Arts Institute',
#  'INSTITUT SAINS TEKNOLOGI AKPRIND': 'Latin American Technological Institute',
#  'INSTITUT SAINS AND TECHNOLOGI NATIONAL': 'National Institute of Science and Technology',
#  'INSTITUT SCIENCE TECHNOLOGI YOGYAKARTA': 'AKPRIND Institute of Science and Technology  Yogyakarta',
#  'INSTITUT SENI INDONESIA SURAKARTA': 'Indonesian Institute of Art  Surakarta',
#  'INSTITUT STIAMI': 'Silay Institute',
#  'INSTITUT TAZKIA': 'KazakhChina Institute',
#  'INSTITUT TAZKIA SENTUL': 'Sapientia Institute',
#  'INSTITUT TECHNOLOGY OF PADANG': 'Padang Institute of Technology',
#  'INSTITUT TECNOLOGY NATIONAL': 'National Institute of Technology',
#  'INSTITUT TEKNOLOGI NASIONAL MALANG': 'Malang National Institute of Technology',
#  'INSTITUT TEKNOLOGI BANDUNG SCHOOL OF BUSINESS MANAGEMENT': 'Institute of Business and Management Sciences',
#  'INSTITUT TEKNOLOGI BUDI UTOMO': 'Budi Utomo Institute of Technology',
#  'INSTITUT TEKNOLOGI NASIONAL ITENAS': 'International Institute of Technology',
#  'INSTITUT TEKNOLOGI PLN JAKARTA': 'Technological Institute of Mazatlán',
#  'INSTITUT TEKNOLOGI SUMATERA': 'Southern Institute of Technology',
#  'INSTITUT TEKNOLOGI TELKOM': 'Tokyo Institute of Technology',
#  'INSTITUT TEKNOLOGIPLN': 'Institute of Technology',
#  'INSTITUTE BUSINESS AND TECHNOLOGY PELITA INDONESIA': 'Institute of Business and Technology',
#  'INSTITUTE OF BUSINESS ADMINISTRATION': 'Institute of Business Administration',
#  'INSTITUTE OF BUSINESS AND MANAGEMENT UET LAHORE': 'Institute of Management and Business',
#  'INSTITUTE OF CHARTERED ACCOUNTANTS OF INDIA': 'Institute of Chartered Accountants in Australia',
#  'INSTITUTE OF CHEMICAL SCIENCES BZU MULTAN': 'BP Koirala Institute of Health Sciences',
#  'INSTITUTE OF INDUSTRIAL ELECTRONICS ENGINEERING NEDUET': 'National Institute of Industrial Engineering',
#  'INSTITUTE OF MANAGEMENT SCIENCES BZU MULTAN': 'Institute of Science and Management',
#  'INSTITUTE OF QUALITY AND TECHNOLOGY MANAGEMENT UNIVERSITY OF THE PUNJAB LAHORE': 'The Eastern University of Management and Technology',
#  'INSTITUTE OF SCIENCE AND TECHNOLOGY AKPRIND YOGYAKARTA': 'AKPRIND Institute of Science and Technology  Yogyakarta',
#  'INSTITUTE OF SOUTHERN PUNJAB MULTAN': 'Institute of Southern Punjab',
#  'INSTITUTE OF SPACE TECHNOLOGY': 'Institute of Space Technology',
#  'INSTITUTE OF TAZKIA BOGOR': 'Syuniq Institute of Goris',
#  'INSTITUTE OF TEACHER TRAINING AND EDUCATION SILIWANGI': 'Institute of Teacher Training and Educational Science Wates',
#  'INSTITUTE OF TECHNOLOGY TELKOM': 'Tokyo Institute of Technology',
#  'INSTITUTE OF TOURISM BANDUNG': 'Institute of Business and Tourism',
#  'INSTITUTE SAHID OF TOURISM': 'Mexican Institute of Tourism Studies',
#  'INSTITUTE SAIN TECHNOLOGY NASIONAL JAKARTA': 'National Institute of Technology Karnataka',
#  'INSTITUTE TECHNOLOGY ADHI TAMA SURABAYA ITATS': 'Adhi Tama Institute of Technology Surabaya',
#  'INSTITUTE TECHNOLOGY AND BUSINESS ASIA MALANG': 'Institute of Business and Technology',
#  'INSTITUTE TECHNOLOGY HARAPAN BANGSA': 'Harapan Bangsa Institute of Technology',
#  'INSTITUTE TECHNOLOGY OF INDONESIA': 'Indonesian Institute of Technology',
#  'INSTITUTE TECHNOLOGY OF KALIMANTAN': 'Lanyang Institute of Technology',
#  'INSTITUTE TECHNOLOGY OF SUMATERA': 'Southern Institute of Technology',
#  'INSURANCE MANAGEMENT SCHOOL OF TRISAKTI': 'School of Advanced Management Studies',
#  'INTEC EDUCATION COLLEGE': 'College of Educational Sciences',
#  'INTEC EDUCATION COLLEGEUITM': 'College of Educational Sciences',
#  'INTERNATIONAL BUSINESS AND MANAGEMENT': 'International Management Institute',
#  'INTERNATIONAL CENTRE FOR EDUCATION IN ISLAMIC FINANCE': 'International Centre for Education in Islamic Finance',
#  'INTERNATIONAL CLASS TRISAKTI UNIVERSITY': 'International Black Sea University',
#  'INTERNATIONAL COLLEGE MANAGEMENT OF SYDNEY': 'International College of Management Sydney',
#  'INTERNATIONAL COLLEGE OF YAYASAN MELAKA': 'International College of Management Sydney',
#  'INTERNATIONAL ISLAMIC UNIVERSITY': 'International Islamic University',
#  'INTERNATIONAL ISLAMIC UNIVERSITY COLLEGE OF SELAGOR': 'Selangor International Islamic University College',
#  'INTERNATIONAL ISLAMIC UNIVERSITYISLAMABAD': 'International Islamic University',
#  'INTERNATIONAL MEDICAL UNIVERSITY': 'International Medical University',
#  'INTERNATIONAL SCHOOL OF VIET NAM NATIONAL UNIVERSITY IN HA NOI': 'University of Limoges  National School of Industrial Ceramics',
#  'INTERNATIONAL UNIVERISTY HO CHI MINH CITY': 'Industrial University of Ho Chi Minh City',
#  'INTERNATIONAL UNIVERSITI MALAYAWALES': 'International University of MalayaWales',
#  'INTERNATIONAL UNIVERSITY': 'International University',
#  'INTERNATIONAL UNIVERSITY COLLEGE OF TECHNOLOGY TWINTECH': 'International University College of Technology Twintech',
#  'INTERNATIONAL UNIVERSITY LIAISON INDONESIA': 'DIU Libertas International University',
#  'INTERNATIONAL UNIVERSITY OF CEMENT INDONESIA UISI': 'International University of Catalonia',
#  'INTI INTERNATIONAL UNIVERSITY': 'Inti International University',
#  'INTITUT TAZKIA': 'KazakhChina Institute',
#  'INTITUT TEKNOLOGI BANDUNG': 'Bandung Institute of Technology',
#  'INTITUT TEKNOLOGI NASIONAL BANDUNG': 'Bandung National Institute of Technology',
#  'INTITUT TEKNOLOGI PLN': 'Technological Institute of León',
#  'INTITUT TRANSPORTASI DAN LOGISTIK TRISAKTI': 'Institute of Transport and Logistics',
#  'INTITUTE OF ART INDONESIA DENPASAR': 'Indonesian Institute of Art  Denpasar',
#  'IOWA STATE UNIVERSITY': 'Iowa State University',
#  'INSTITUTE OF PUBLIC ADMINISTRATION': 'Institute of Public Administration',
#  'IPB VOCATIONAL SCHOOL': 'Higher Vocational School',
#  'IPE MANAGEMENT SCHOOL PARIS': 'ISC Paris School of Management',
#  'IPMI INTERNATIONAL BUSINESS SCHOOL': 'International Business School',
#  'IQ ACADEMY': 'IP Academy',
#  'IQRA UNIVERSITY': 'Iqra University',
#  'IQRA UNIVERSITY MAIN CAMPUS': 'LINK CAMPUS University',
#  'IRKUTSK NATIONAL RESEARCH TECHNICAL UNIVERSITY RUSSIA': 'Donetsk National Technical University',
#  'ISLAM 45 BEKASI UNIVERSITY': 'Bekasi 45 Islamic University',
#  'ISLAM KALIMANTAN MAB UNIVERSITY': 'Islamic University of Lamongan',
#  'ISLAMIA COLLEGE PESHAWAR': 'Marawi Islamic College',
#  'ISLAMIC BANDUNG UNIVERSITY': 'Islamic University of Bandung',
#  'ISLAMIC BATIC UNIVERSITY': 'Islamic Batik University',
#  'ISLAMIC SCIENCE UNIVERSITY OF MALAYSIA': 'Islamic Science University of Malaysia',
#  'ISLAMIC STATE OF SULTAN SYARIF KASIM UNIVERSITY': 'State Islamic University of Sultan Syarif Kasim Riau',
#  'ISLAMIC STATE UNIVERSITY ARRANIRY BANDA ACEH': 'State University of Islamic Studies ArRaniry',
#  'ISLAMIC STATE UNIVERSITY NORTH SUMATERA': 'Islamic University of North Sumatra',
#  'ISLAMIC STATE UNIVERSITY OF ALAUDDIN MAKASSAR': 'State Islamic University of Alauddin',
#  'ISLAMIC STATE UNIVERSITY OF RADEN FATAH': 'State Islamic University of Alauddin',
#  'ISLAMIC STATE UNIVERSITY OF SUNAN GUNUNG DJATI BANDUNG': 'State Islamic University of Alauddin',
#  'ISLAMIC UNIVERSITY OF INDONESIA UII YOGYAKARTA': 'Islamic University of Indonesia',
#  'ISLAMIC UNIVERSITY OF LAMONGAN': 'Islamic University of Lamongan',
#  'ISLAMIC UNIVERSITY OF NUSANTARA': 'Islamic University of Nusantara',
#  'ISLAMIC UNIVERSITY OF RADEN INTAN LAMPUNG': 'Islamic University of Lamongan',
#  'ISLAMIC UNIVERSITY OF RIAU': 'Islamic University of Riau',
#  'ISLAMIC UNIVERSITY OF SUNAN AMPEL SURABAYA': 'Sunan Giri Surabaya University',
#  'ISRA UNIVERSITY HYDERABAD': 'University of Hyderabad',
#  'ISTANBUL MEDENIYET UNIVERSITY': 'Istanbul Medeniyet University',
#  'ISTANBUL TECHNICAL UNIVERSITY': 'Istanbul Technical University',
#  'ITB BANDUNG INSTITUTE OF TECHNOLOGY': 'Bandung Institute of Technology',
#  'ITB INSTITUT TEKNOLOGI BANDUNG': 'Bandung Institute of Technology',
#  'ITB AAS INDONESIA SURAKARTA': 'Indonesian Institute of Art  Surakarta',
#  'ITS INSTITUT TEKNOLOGI SEPULUH NOPEMBER SURABAYA': 'Sepuluh November Institute of Technology',
#  'ITS SURABAYA INSTITUTE OF TECHNOLOGY': 'Saitama Institute of Technology',
#  'JAGANNATH UNIVERSITY': 'Jagannath University',
#  'JAHANGIRNAGAR UNIVERSITY': 'Jahangirnagar University',
#  'JAKARTA FISHERIES UNIVERSITY': 'Tamil Nadu Fisheries University',
#  'JAKARTA GLOBAL UNIVERSITY': 'Jakarta University',
#  'JAKARTA INSTITUTE OF ART': 'Jakarta Arts Institute',
#  'JAKARTA INTERNATIONAL COLLEGE': 'J  K International College',
#  'JAKARTA INTERNATIONAL HIGH SCHOOL': 'Flight School International',
#  'JAKARTA STATE ISLAMIC UNIVERSITY': 'Islamic University of Jakarta',
#  'JAKARTA STATE UNIVERAITY': 'State University of Jakarta',
#  'JAMBI UNIVERSITY': 'Jambi University',
#  'JAMES COOK UNIVERSITY': 'James Cook University',
#  'JAMK UNIVERSITY OF APPLIED SCIENCES': 'Jade University of Applied Sciences',
#  'JANABADRA UNIVERSITY': 'Janabadra University',
#  'JAWAHARLAL NEHRU TECHNOLOGICAL UNIVERSITY HYDERABAD': 'Jawaharlal Nehru Technological University',
#  'JAYABAYA UNIVERSITY': 'Jayabaya University',
#  'JEMBER OF UNIVERSITY': 'Jember University',
#  'JEMBER STATE POLYTECHNIC': 'Stella Maris Polytechnic',
#  'JESUS AND MARY COLLEGE UNIVERSITY OF DELHI': 'University of Cambridge  Jesus College',
#  'JIANGSU UNIVERSITY': 'Jiangsu University',
#  'JIANGXI NORMAL UNIVERSITY': 'Jiangxi Normal University',
#  'KAIMS INTERNATIONAL INSTITUTE MULTAN': 'Institute of International Relations',
#  'KALBIS INSTITUT': 'Kalbis Institute',
#  'KALIMANTAN INSTITUT OF TECHNOLOGY': 'Lanyang Institute of Technology',
#  'KANAZAWA UNIVERSITY': 'Kanazawa University',
#  'KANJURUHAN MALANG UNIVERSITY': 'Kanjuruhan University',
#  'KAPLAN BUSINESS SCHOOL AUSTRALIA': 'Kaplan Business School',
#  'KARACHI INSTITUTE OF ECONOMICS AND TECHNOLOGY': 'Karachi Institute of Economics and Technology',
#  'KARACHI SCHOOL FOR BUSINESS AND LEADERSHIP': 'Karachi School of Business and Leadership',
#  'KARACHI UNIVERSITY BUSINESS SCHOOL': 'University of the Pacific Business School',
#  'KARADENIZ TECHNICAL UNIVERSITY': 'Karadeniz Technical University',
#  'KARBALA UNIVERSITY': 'Karbala University',
#  'KARLSRUHE INSTITUTE OF TECHNOLOGY': 'Karlsruhe Institute of Technology',
#  'KASETSART UNIVERSITY': 'Kasetsart University',
#  'KATHOLIEKE UNIVERSITEIT LEUVEN': 'Catholic University of Leuven',
#  'KATOLIK PARAHYANGAN UNIVERSITY': 'Parahyangan Catholic University',
#  'KAZAN FEDERAL UNIVERSITY': 'Federal University of Paraná',
#  'KCA UNIVERSITY': 'KCA University',
#  'KDU COLLEGE': 'Keuka College',
#  'KDU PENANG UNIVERSITY COLLEGE': 'European University College',
#  'KEBANGSAAN UNIVERSITY': 'Kebangsaan University',
#  'KEDIRI ISLAMIC UNIVERSITY': 'Islamic University of Kadiri',
#  'KESATUAN BUSINESS AND INFORMATICS INSTITUTE': 'Informatics and Business Institute Darmajaya',
#  'KHAIRUN UNIVERSITY': 'Khairun University',
#  'KHAWAJA FAREED UNIVERSITY OF ENGINEERING AND INFORMATION TECHNOLOGY': 'Mehran University of Engineering and Technology Jamshoro',
#  'KHONKAEN UNIVERSITY': 'Konan University',
#  'KHWAJA FAREED UNIVERSITY': 'FreedHardeman University',
#  'KIEN GIANG UNIVERSITY': 'Tien Giang University',
#  'KING MONGKUTS INSTITUTE OF TECHNOLOGY NORTH BANGKOK': 'King Mongkuts Institute of Technology North Bangkok',
#  'KING MONGKUTS UNIVERSITY OF TECHNOLOGY THONBURI': 'King Mongkuts University of Technology Thonburi',
#  'KINGS COLLEGE LONDON': 'Kings College London',
#  'KINGSTON UNIVERSITY': 'Kingston University',
#  'KITKALAIGNARKARUNANIDHI INSTITUTE OF TECHNOLOGY': 'Kanagawa Institute of Technology',
#  'KLABAT UNIVERSITY': 'Klabat University',
#  'KOGI STATE UNIVERSITY': 'Kogi State University',
#  'KOLEJ UNIVERSITI POLY TECH MARA KUALA LUMPUR': 'Kuala Lumpur Metropolitan University College',
#  'KOOKMIN UNIVERSITY': 'Fooyin University',
#  'KOREA ADVANCED INSTITUTE OF SCIENCE AND TECHNOLOGY': 'Japan Advanced Institute of Science and Technology',
#  'KOREA NATIONAL UNIVERSITY OF TRANSPORTATION': 'National Transport University',
#  'KOREA UNIVERSITY': 'Kean University',
#  'KPJ HEALTHCARE UNIVERSITY COLLEGE': 'KPJ Healthcare University College',
#  'KRISNADWIPAYANA': 'Krisnadwipayana University',
#  'KRISTEN KRIDA WACANA UNIVERSITY': 'Krida Wacana Christian University',
#  'KTH ROYAL INSTITUTE OF TECHNOLOGY': 'Royal Institute of Technology',
#  'KUALA LUMPUR METROPOLITAN UNIVERSITY': 'Kuala Lumpur Metropolitan University College',
#  'KUBAN STATE TECHNOLOGICAL UNIVERSITY': 'Belarusian State Technological University',
#  'KUMOH NATIONAL INSTITUTE OF TECHNOLOGY': 'National Institute of Technology',
#  'KUNINGAN UNIVERSITY': 'Kuningan University',
#  'KUNSAN NATIONAL UNIVERSITY': 'National Ilan University',
#  'KURSK STATE MEDICAL UNIVERSITY': 'Lugansk State Medical University',
#  'KURUKSHETRA UNIVERSITY KURUKSHETRA': 'Kurukshetra University',
#  'KYOTO UNIVERSITY': 'Kyoto University',
#  'KYUNG HEE UNIVERSITY': 'Hung Kuang University',
#  'KYUNGSUNG UNIVERSITY': 'Kyushu University',
#  'KYUSHU UNIVERSITY': 'Kyushu University',
#  'LA TROBE UNIVERSITY': 'La Trobe University',
#  'LAB UNIVERSITY OF APPLIED SCIENCES': 'EBC University of Applied Sciences',
#  'LAGUNA STATE POLYTECHNIC UNIVERSITY': 'Laguna State Polytechnic University',
#  'LAHORE COLLEGE FOR WOMEN UNIVERSITY': 'Lahore College for Women University',
#  'LAHORE LEADS UNIVERSITY': 'Lakehead University',
#  'LAHORE SCHOOL OF ECONOMICS': 'Lahore School of Economics',
#  'LAMBUNG MANGKURAT UNIVERSITY': 'Lambung Mangkurat University',
#  'LAMONGAN ISLAMIC UNIVERSITY': 'Islamic University of Lamongan',
#  'LAMPUNG UNIVERSITY UNILA': 'Lampung University',
#  'LANCANG KUNING UNIVERSITY': 'Lancang Kuning University',
#  'LANCASTER UNIVERSITY': 'Lancaster University',
#  'LANCASTER UNIVERSITY MANAGEMENT SCHOOL': 'Management and Science University',
#  'LASALLE COLLEGE': 'Lasell College',
#  'LASALLE UNIVERSITY': 'La Salle University',
#  'LAW FACULTY OF JAMBI UNIVERSITY': 'University of Cumbria',
#  'LEIDEN UNIVERSITY': 'Leiden University',
#  'LEO CUSSEN CENTRE FOR LAW': 'Leo Cussen Centre For Law',
#  'LIA INSTITUTE OF FOREIGN LANGUAGES': 'Institute of Tourism and Foreign Languages',
#  'LIAONING UNIVERSITY CHINA': 'China Jiliang University',
#  'LIMKOKWING UNIVERSITY': 'Liaoning University',
#  'LIMKOKWING UNIVERSITY OF CREATIVE AND TECHNOLOGY': 'Limkokwing University of Creative Technology',
#  'LINCOLN UNIVERSITY': 'Lincoln University',
#  'LINGNAN UNIVERSITY': 'Lingnan University',
#  'LIVERPOOL JOHN MOORES UNIVERSITY': 'Liverpool John Moores University',
#  'LONDON SCHOOL OF PUBLIC RELATIONS JAKARTA': 'London School of Public Relations',
# ...
#  'MIDDLESEX UNIVERSITY': 'Middlesex University',
#  'MILITARY COLLEGE OF SIGNALSNUST': 'College of St Mary',
#  'MILITARY INSTITUTE OF SCIENCE AND TECHNOLOGY': 'Masdar Institute of Science and Technology',
#  'MING CHUAN UNIVERSITY': 'Ming Chuan University',
#  'MIP POLITECNICO DI MILANO': 'Politecnico di Milano',
#  'MIRPUR UNIVERSITY OF SCIENCE AND TECHNOLOGY AJK': 'Mirpur University of Science and Technology',
#  'MIT WORLD PEACE UNIVERSITY PUNE': 'New World University',
#  'MIZORAM UNIVERSITY': 'Mizoram University',
#  'MULTIMEDIA UNIVERSITY': 'Multimedia University',
#  'MNS UNIVERSITY OF ENGINEERING AND TECHNOLOGY MULTAN': 'Khulna University of Engineering and Technology',
#  'MODERN ACADEMY': 'Marnix Academy',
#  'MOESLIM UNIVERSITY OF INDONESIA': 'Muslim University of Indonesia',
#  'MOESTOPO UNIVERSITY': 'Boston University',
#  'MOHAMMAD ALI JINNAH UNIVERSITY': 'Mohammad Ali Jinnah University',
#  'MOHAMMAD HUSNI THAMRIN UNIVERSITY': 'Tahri Mohammed Béchar University',
#  'MOMMENSEN HKBP UNIVERSITY': 'Nommensen HKBP University',
#  'MONASH MALAYSIA UNIVERSITY': 'Open University Malaysia',
#  'MONASH UNIVERSITY MELBOURNE AU': 'University of Melbourne',
#  'MONASH UNIVERSITY AUSTRALIA': 'Torrens University Australia',
#  'MONASH UNIVERSITY CAULFIELD CAMPUS': 'Madonna University  Elele Campus',
#  'MOTIVASI INSANI VOCATIONAL HIGH SCHOOL': 'Oeconomicus Vocational Higher School',
#  'MSU COLLEGE': 'Miles College',
#  'MUHADI SETIABUDI UNIVERSITY': 'Istanbul Aydin University',
#  'MUHAMADIYAH SURAKARTA UNIVERSITY': 'Muhammadiyah University of Surakarta',
#  'MUHAMMAD NAWAZ SHARIF UNIVERSITY OF ENGINEERING TECHNOLOGY MULTAN': 'Khulna University of Engineering and Technology',
#  'MUHAMMADIYA UNIVERSITY OF YOGYAKARTA': 'Muhammadiyah University of Yogyakarta',
#  'MUHAMMADIYAH ACEH UNIVERSITY': 'Muhammadiyah University of Aceh',
#  'MUHAMMADIYAH CIREBON UNIVERSITY': 'Muhammadiyah University of Cirebon',
#  'MUHAMMADIYAH NORTH SUMATRA OF UNIVERSITY': 'Muhammadiyah University of North Sumatra',
#  'MUHAMMADIYAH PALEMBANG UNIVERSITY': 'Muhammadiyah University of Palembang',
#  'MUHAMMADIYAH PROF DR HAMKA UNIVERSITY': 'Muhammadiyah Prof Dr Hamka University',
#  'MUHAMMADIYAH SIDOARJO UNIVERSITY': 'Muhammadiyah University of Sidoarjo',
#  'MUHAMMADIYAH TANGERANG UNIVERSITY': 'Muhammadiyah University of Tangerang',
#  'MUHAMMADIYAH UNIVERSITY OF PURWOKERTO': 'Muhammadiyah University of Purwokerto',
#  'MUHAMMADIYAH UNIVERSITY OF SUKABUMI': 'Muhammadiyah University of Sukabumi',
#  'MUHAMMADIYAH UNIVERSITY OF SUMATERA UTARA': 'Muhammadiyah University of West Sumatra',
#  'MULIA UNIVERSITY BALIKPAPAN': 'Balikpapan University',
#  'MULTIMEDIA NUSANTARA UNIVERSITY': 'Nusantara Multimedia University',
#  'MULTIMEDIA UNIVERISITY': 'Multimedia University',
#  'MULTIMEDIA UNIVERSITYCYBERJAYA': 'Multimedia University',
#  'MURIA KUDUS UNIVERSITY': 'Muria Kudus University',
#  'MUSASHINO UNIVERSITY': 'Musashino University',
#  'MUSI CHARITAS CATHOLIC UNIVERSITY': 'Saint Thomas Catholic University',
#  'MUSLIM UNIVERSITY OF INDONESIA': 'Muslim University of Indonesia',
#  'MYONGJI UNIVERSITY': 'Tongji University',
#  'NED UNIVERSITY OF ENGINEERING TECHNOLOGY': 'NED University of Engineering and Technology',
#  'NANHUA UNIVERSITY TAIWAN': 'National Taiwan University',
#  'NANJING UNIVERSITY OF AERONAUTICS AND ASTRONAUTICS': 'Nanjing University of Aeronautics and Astronautics',
#  'NANJING UNIVERSITY OF INFORMATION SCIENCE AND TECHNOLOGY': 'Nanjing University of Information Science and Technology',
#  'NANJING XIAOZHUANG UNIVERSITY': 'Nanjing Xiaozhuang University',
#  'NANYANG BUSINESS SCHOOL': 'CASTAING Business School',
#  'NANYANG INSTITUTE OF TECHNOLOGY': 'Nanyang Institute of Technology',
#  'NANYANG POLYTECHNIC': 'Kaduna Polytechnic',
#  'NANYANG TECHNOLOGICAL UNIVERISTY': 'Nanyang Technological University',
#  'NAROTAMA UNIVERCITY': 'Narotama University',
#  'NAROTAMA UNIVERSITY SURABAYA': 'Surabaya State University',
#  'NASIONAL DEVELOPMENT UNIVERSITY OF VETERAN JAKARTA': 'Veteran National Development University of Jakarta',
#  'NASIONAL UNIVERSITY': 'National University',
#  'NATIONAL CENTRAL UNIVERSITY': 'National Central University',
#  'NATIONAL CHENG KUNG UNIVERSITY': 'National Cheng Kung University',
#  'NATIONAL CHENGCHI UNIVERSITY': 'National Chengchi University',
#  'NATIONAL CHIAO TUNG UNIVERSITY TAIWAN': 'National Chiao Tung University',
#  'NATIONAL CHIAYI UNIVERSITY': 'National Chiayi University',
#  'NATIONAL CHINYI UNIVERSITY OF TECHNOLOGY': 'National ChinYi University of Technology',
#  'NATIONAL CHUNG CHENG UNIVERSITY TAIWAN': 'National Chung Cheng University',
#  'NATIONAL COLLEGE OF BUSINESS ECONOMICS': 'College of Business Education',
#  'NATIONAL COLLEGE OF BUSINESS ADMINISTRATION AND ECONOMIC': 'National College of Business Administration and Economics',
#  'NATIONAL DEFENCE UNIVERSITY': 'National Defence University',
#  'NATIONAL DEFENCE UNIVERSITY OF MALAYSIA': 'National Defence University of Malaysia',
#  'NATIONAL DEVELOPMENT UNIVERSITY YOGYAKARTA': 'Veteran National Development University of Yogyakarta',
#  'NATIONAL DONG HWA UNIVERSITY': 'National Dong Hwa University',
#  'NATIONAL ECONOMIC UNIVERSITY': 'National Economics University',
#  'NATIONAL ECONOMICS UNIVERSITY HANOI VIETNAM': 'Vietnam National University  Hanoi',
#  'NATIONAL FORMOSA UNIVERSITY': 'National Formosa University',
#  'NATIONAL HOTEL INSTITUTE BANDUNG': 'Homi Bhabha National Institute',
#  'NATIONAL HOTEL SCHOOL JAKARTA': 'National Art School',
#  'NATIONAL INSTITUTE MALANG': 'Malang National Institute of Technology',
#  'NATIONAL INSTITUTE OF EDUCATION': 'National Institute of Education',
#  'NATIONAL INSTITUTE OF FOOD TECHNOLOGY ENTREPRENEURSHIP MANAGEMENT': 'National Institute of Food Technology Entrepreneurship and Management',
#  'NATIONAL INSTITUTE OF MALAYSIA': 'Malaviya National Institute of Technology',
#  'NATIONAL INSTITUTE OF SCIENCE AND TECHNOLOGY': 'National Institute of Science and Technology',
#  'NATIONAL MANAGEMENT DEGREE COLLEGE': 'College of Healthcare Management',
#  'NATIONAL QUEMOY UNIVERSITY': 'National Quemoy University',
#  'NATIONAL RESEARCH NUCLEAR UNIVERSITY': 'National University of Rosario',
#  'NATIONAL SUN YATSEN UNIVERSITY TAIWAN ROC': 'National Sun YatSen University',
#  'NATIONAL TECHNOLOGICAL UNIVERSITY': 'National Technological University',
#  'NATIONAL UNIVERCITY': 'National University',
#  'NATIONAL UNIVERSITY UNIVERSITAS NASIONAL': 'National University of Ireland  Uversity',
#  'NATIONAL UNIVERSITY JAKARTA': 'Jaipur National University',
#  'NATIONAL UNIVERSITY OF COMPUTER EMERGING SCIENCES': 'National University of Computer and Emerging Sciences',
#  'NATIONAL UNIVERSITY OF IRELAND AT KAPLAN SINGAPORE UCD': 'National University of Singapore',
#  'NATIONAL UNIVERSITY OF IRELAND UNIVERSITY COLLEGE DUBLIN': 'National University of Ireland  University College Dublin',
#  'NATIONAL UNIVERSITY OF MODERN LANAGUAGES RAWALPINDI': 'National University of Modern Languages',
#  'NATIONAL UNIVERSITY OF SCIENCES AND TECHNOLOGYISLAMABAD': 'National University of Sciences and Technology',
#  'NATIONAL UNIVERSITY OF SURABAYA': 'National University of Ucayali',
#  'NDUM NATIONAL DEFENSE UNIVERSITY MALAYSIA': 'National Defence University of Malaysia',
#  'NED UNIVERSITY': 'TED University',
#  'NEW MEXICO INSTITUTE OF MINING TECHNOLOGY': 'New Mexico Institute of Mining and Technology',
#  'NEW YORK UNIVERSITY': 'New York University',
#  'NEWCASTLE UNIVERSITY': 'Newcastle University',
#  'NEWCASTLE UNIVERSITY MEDICINE MALAYSIA': 'AlArab Medical University',
#  'NEXFORD UNIVERSITY': 'Nord University',
#  'NFC INSTITUTE OF ENGINEERING TECHNOLOGY MULTAN': 'NFC Institute of Engineering and Technology',
#  'NFCINSTITUTE OF ENGINEERING TECHNOLOGY MULTAN': 'Institute of Engineering and Technology',
#  'NGEE ANN POLYTECHNIC': 'Otago Polytechnic',
#  'NGUDI WALUYO UNIVERSITY': 'Hsing Wu University',
#  'NGURAH RAI UNIVERSITY': 'Ngurah Rai University',
#  'NGUYEN TAT THANH UNIVERSITY': 'Nguyen Tat Thanh University',
#  'NHI ACADEMY OF TOURISM BANDUNG': 'Kazakh Academy of Sport and Tourism',
#  'NIAGARA COLLEGE CANADA': 'Niagara College',
#  'NICOLAUS COPERNICUS UNIVERSITY': 'Nicolaus Copernicus University',
#  'NILAI UNIVERSITY': 'Nilai University',
#  'NINGBI UNIVERSITY': 'Ningbo University',
#  'NIRMA UNIVERSITY': 'Nirma University',
#  'NITRO BUSINESS AND FINANCE INSTITUTE MAKASSAR': 'Institute of Management and Business',
#  'NMIMS UNIVERSITY DEEMED TO BE UNIVERSITY': 'NMIMS University Deemed to be University',
#  'NOMMENSEN HKBP UNIVERCITY': 'Nommensen HKBP University',
#  'NONG LAM UNIVERSITY HO CHI MINH CITY': 'Nong Lam University  Ho Chi Minh City',
#  'NORTH MAHARASHTRA': 'North Maharashtra University',
#  'NORTH SOUTH UNIVERSITY': 'North South University',
#  'NORTH SUMATERA ISLAMIC UNIVERSITY': 'Islamic University of North Sumatra',
#  'NORTHEAST FORESTRY UNIVERSITY': 'Northeast Forestry University',
#  'NORTHEASTERN UNIVERSITY UNITED STATES': 'Northeastern State University',
#  'NORTHERN KENTUCKY UNIVERSITY': 'Northern Kentucky University',
#  'NORTHERN UNIVERSITY OF MALAYSIA': 'Northern University of Malaysia',
#  'NORWEGIAN UNIVERSITY OF SCIENCE AND TECHNOLOGY': 'Norwegian University of Science and Technology',
#  'NUSA CENDANA UNIVERSITY': 'University of Nusa Cendana',
#  'NUSA MANDIRI UNIVERSITY': 'Nusa Nipa University',
#  'NUST NATIONAL UNIVERSITY OF SCIENCES TECHNOLOGY BUSINESS SCHOOL': 'National University of Sciences and Technology',
#  'NUST BUSINESS SCHOOL': 'Putra Business School',
#  'OHIO STATE UNIVERSITY': 'Imo State University',
#  'OKLAHOMA CITY UNIVERSITY': 'Oklahoma City University',
#  'OKLAHOMA STATE UNIVERSITY': 'Oklahoma State University',
#  'OPEN UNIVERSITY': 'Open University',
#  'ORANGE COAST COLLEGE': 'East Coast College',
#  'OREGON STATE UNIVERSITY': 'Oregon State University',
#  'OSTWESTFALENLIPPE UNIVERSITY OF APPLIED SCIENCES': 'OstwestfalenLippe University of Applied Sciences',
#  'OXFORD BROOKES UNIVERSITY': 'Oxford Brookes University',
#  'OZYEGIN UNIVERSITY TURKEY': 'Foreign Trade University',
#  'P3B UNIVERSITAS NEGERI SURABAYA': 'Free University of Surabaya',
#  'PACE UNIVERSITY': 'Pace University',
#  'PADANG INSTITUTE OF TECHNOLOGY': 'Padang Institute of Technology',
#  'PADANG OF STATE UNIVERSITY': 'Padang State University',
#  'PADJADJARAN UNIVERSITY UNPAD': 'Padjadjaran University',
#  'PADJADJARAN UNIVERSITY BANDUNG': 'Padjadjaran University',
#  'PAFKARACHI INSTITUTE OF ECONOMICS AND TECHNOLOGY': 'Karachi Institute of Economics and Technology',
#  'PAKISTAN AIR FORCEKARACHI INSTITUTE OF ECONOMICS AND TECHNOLOGY': 'The Finance and Economics Institute of Tajikistan',
#  'PAKISTAN INSTITUTE OF ENGINEERING APPLIED SCIENCES PIEAS': 'Pakistan Institute of Engineering and Applied Sciences',
#  'PAKUAN UNIVERCITY': 'Pakuan University',
#  'PAKUAN UNIVERSITY BOGOR': 'Pakuan University',
#  'PALANGKA RAYA UNIVERSITY': 'Palangka Raya University',
#  'PALEMBANG MUHAMMADIYAH UNIVERSITY': 'Muhammadiyah University of Palembang',
#  'PALEMBANG POLYTECHNIC OF TOURISM': 'Polytechnic of Turin',
#  'PAMALANG UNIVERSITY': 'Pamulang University',
#  'PANCA BHAKTI UNIVERSITY': 'Panca Bhakti University',
#  'PANCA MARGA PROBOLINGGO UNIVERSITY': 'Panca Marga University',
#  'PANCASAKTI TEGAL UNIVERSITY': 'Pancasakti University of Tegal',
#  'PANCASILA UNIVERSITY': 'Pancasila University',
#  'PANDANARAN UNIVERSITY': 'Padjadjaran University',
#  'PANYAPIWAT INSTITUTE OF MANAGEMENT': 'Panyapiwat Institute of Management',
#  'PARAHYANGAN CATHOLIC UNIVERSITY': 'Parahyangan Catholic University',
#  'PARAHYANGAN CATHOLIC UNIVERSITY CIVIL ENGINEERING': 'Parahyangan Catholic University',
#  'PARIS GRADUATE SCHOOL OF MANAGEMENT': 'Graduate School of Management',
#  'PASUNDAN OF UNIVERSITY': 'Pasundan University',
#  'PASUNDAN UNIVERISTY': 'Pasundan University',
#  'PASUNDAN UNIVERSITY INDONESIA': 'Indonesian Pramita University',
#  'PATTIMURA UNIVERSITY': 'Pattimura University',
#  'PEKALONGAN UNIVERSITY': 'Pekalongan University',
#  'PEKING UNIVERSITY': 'Peking University',
#  'PELITA BANGSA UNIVERSITY': 'Bangka Belitung University',
#  'PELITA HARAPAN UNIVERSITY KARAWACI': 'Pelita Harapan University',
#  'PELITA NUSANTARA MEDAN': 'Dian Nusantara University',
#  'PEMBANGUNAN JAYA UNIVERSITY': 'Tunas Pembangunan University',
#  'PENN STATE UNIVERSITY': 'Kent State University',
#  'PERADABAN UNIVERSITY': 'Perdana University',
#  'PERBANAS INSITUTE': 'Pratt Institute',
#  'PERBANAS INSITUTE JAKARTA': 'ABFI Institute Perbanas Jakarta',
#  'PERKASA FLIGHT SCHOOL': 'Flight School International',
#  'PERSADA INDONESIA UNIVERSITY': 'Persada Indonesian YAI University',
#  'PERTAMINA UNIVERSITY': 'Perdana University',
#  'PETRA CHRISTIAN UNIVERISTY': 'Petra Christian University',
#  'PETRA CHRISTIAN UNIVERSITY SURABAYA': 'Petra Christian University',
#  'PETRA VOCATIONAL HIGH SCHOOL': 'Higher Vocational School',
#  'PETRONAS TECHNOLOGICAL UNIVERSITY': 'Petronas Technological University',
#  'PETROVIETNAM MANPOWER TRAINING COLLEGE': 'Police Officer Training College',
#  'PGRI ADIBUANA SURABAYA': 'Adi Buana PGRI University',
#  'PGRI BANYUWANGI UNIVERSITY': 'Banyuwangi PGRI University',
#  'PGRI UNIVERSITY OF INDONESIA': 'University of Prima Indonesia',
#  'PGRI UNIVERSITY OF YOGYAKARTA': 'Respati University of Yogyakarta',
#  'PLN INSTITUE OF TECHNOLOGY': 'Institute of Technology',
#  'PLN TECHNOLOGY INSTITUTE JAKARTA': 'Kitami Institute of Technology',
#  'PLYMOUTH UNIVERSITY': 'University of Plymouth',
#  'PMAS ARID AGRICULTURE UNIVERSITY': 'Assam Agricultural University',
#  'PODOMORO UNIVERSITY': 'Aomori University',
#  'POLITECHNIC LP3I': 'Auchi Polytechnic',
#  'POLITECHNIC OF MALANG': 'Polytechnic of Karlovac',
#  'POLITECHNIC OF SEKAYU': 'Polytechnic of Rijeka',
#  'POLITECHNIC OF SRIWIJAYA': 'Polytechnic of Rijeka',
#  'POLITECNICO DI MILANO': 'Politecnico di Milano',
#  'POLYTECHNIC': 'The Polytechnic',
#  'POLYTECHNIC ATI PADANG': 'Bolgatanga Polytechnic',
#  'POLYTECHNIC CALTEX RIAU': 'Polytechnic of Rijeka',
#  'POLYTECHNIC INSTITUTE OF NUCLEAR TECHNOLOGY': 'Institute of Technical Technology',
#  'POLYTECHNIC OF HEALTH DENPASAR': 'Polytechnic Faculty of Campinas',
#  'POLYTECHNIC OF JEMBER': 'Federal Polytechnic',
#  'POLYTECHNIC OF KEDIRI': 'Polytechnic of Karlovac',
#  'POLYTECHNIC OF LHOKSEUMAWE': 'Polytechnic of Karlovac',
#  'POLYTECHNIC OF POS INDONESIA': 'Polytechnic Institute of Tomar',
#  'POLYTECHNIC OF SEMARANG STATE': 'Polytechnic of Požega',
#  'POLYTECHNIC PIKSI GANESHA': 'Gaza Polytechnic Institute',
#  'POLYTECHNIC STATE OF INDRAMAYU': 'Camiguin Polytechnic State College',
#  'POLYTECHNIC STATE OF PONTIANAK': 'Polytechnic University of Tirana',
#  'POLYTECHNIC UNGKU OMAR': 'Polytechnic of Turin',
#  'POLYTHECNICS OF PADANG': 'Bolgatanga Polytechnic',
#  'PPM MANAJEMEN': 'Sup Management',
#  'PPM SCHOOL OF MANAGEMENT': 'School of Management',
#  'PRADITA UNIVERSITY': 'Pratap University',
#  'PRAGUE BUSINESS COLLEGE': 'Libertas Business College',
#  'PREMIER UNIVERSITY': 'Premier University',
#  'PRESDIENT UNIVERSITY': 'President University',
#  'PRESTON INSTITUTE OF MANAGEMENT SCIENCE AND TECHNOLOGY': 'Preston Institute of Management Sciences and Technology',
#  'PRESTON UNIVERSITY': 'Preston University',
#  'PRINCETON UNIVERSITY UNITED STATES': 'United States International University',
#  'PRIVATE UNIVERSITY': 'Private University',
#  'PROD DR MOESTOPO BERAGAMA UNIVERSITY': 'Prof Dr Moestopo University Religion',
#  'PROF DR HAMKA MUHAMMADIYAH UNIVERSITY': 'Muhammadiyah Prof Dr Hamka University',
#  'PROFESSIONAL MANAGEMENT COLLEGE INDONESIA': 'RRiF College of Financial Management',
#  'PUKYONG NATIONAL UNIVERSITY': 'National Penghu University',
#  'PUNJAB UNIVERSITY': 'Punjabi University',
#  'PUNJAB UNIVERSITY INSTITUTE OF ADMINISTRATIVE SCIENCES': 'German University of Administrative Sciences',
#  'PURDUE SCHOOL OF ENGINEERING IUPUI': 'ICAM School of Engineering',
#  'PURDUE UNIVERSITY': 'Purdue University',
#  'PUTERA BATAM UNIVERSITY': 'University of Putera Batam',
#  'PUTRA INDONESIA YPTK PADANG UNIVERSITY': 'Putra Indonesia YPTK University of Padang',
#  'PUTRA INTERNATIONAL COLLEGE': 'Zikura International College',
#  'QATAR UNIVERSITY': 'Qatar University',
#  'QUAID E AWAM UNIVERSITY OF ENGINEERING SCIENCE AND TECHNOLOGY NAWABSHAH': 'Kwame Nkrumah University of Science and Technology',
#  ...}

# %%
#Save dict to a file
dictionary = dedup_name_dict
  
try:
    geeky_file = open('/content/dedup_name_dict.txt', 'wt')
    geeky_file.write(str(dictionary))
    geeky_file.close()
  
except:
    print("Unable to write to file")

# %% [markdown]
# #Putting back with whole database with matched names

# %% [markdown]
# ##Putting it back into the whole database

# %%
#import the dict files
##########
# importing the module
import ast
  
# reading the data from the file
with open('/content/name_dict_deduplipy68-4726head1.txt') as f:
    data = f.read()
  
print("Data type before reconstruction : ", type(data))
      
# reconstructing the data as a dictionary
d_60 = ast.literal_eval(data)
  
print("Data type after reconstruction : ", type(d_60))
print(d_60)
# Out:
# Data type before reconstruction :  <class 'str'>
# Data type after reconstruction :  <class 'dict'>
# {'ANDALAS UNIVERSITY': 'Andalas University', 'ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA': 'Atma Jaya Catholic University of Indonesia', 'HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND EDUCATION': 'Ho Chi Minh City University of Technology and Education', 'JENDERAL SOEDIRMAN UNIVERSITY': 'General Soedirman University', 'MEDAN STATE UNIVERSITY': 'State University of Medan', 'NATIONAL INSTITUTE OF TECHNOLOGY BANDUNG': 'Bandung National Institute of Technology', 'PADJAJARAN UNIVERSITY': 'Padjadjaran University', 'SOLBRIDGE INTERNATIONAL SCHOOL OF BUSINESS': 'International School of Business', 'SURABAYA STATE OF UNIVERSITY': 'Surabaya State University', 'TRILOGI UNIVERSITY': 'Trilogi University', 'UNIVERSITY GADJAH MADA': 'Gajah Mada University', 'UNIVERSITY NUSA MANDIRI': 'Nusa Nipa University', 'UNIVERSITY OF INDONESIA': 'Indonesia University', 'UNIVERSITY OF NORTH SUMATRA': 'Islamic University of North Sumatra', 'YOGYAKARTA VETERAN NATIONAL DEVELOPMENT UNIVERSITY': 'Veteran National Development University of Yogyakarta', 'ANGEL KANČEV UNIVERSITY OF RUSE': 'Angel Kančev University of Ruse', 'BALTAZAR ADAM KRČELIĆ COLLEGE OF BUSINESS ADMINISTRATION': 'Baltazar Adam Krčelić College of Business Administration', 'CHERNORIZETS HRABAR FREE UNIVERSITY OF VARNA': 'Chernorizets Hrabar  Free University of Varna', 'DA TSENOV ACADEMY OF ECONOMICS SVISHTOV': 'DA Tsenov Academy of Economics  Svishtov', 'GEORGE BARIȚIU UNIVERSITY': 'George Barițiu University', 'KONSTANTIN PRESLAVSKI SHUMEN UNIVERSITY': 'Konstantin Preslavski Shumen University', 'KRUSTYO SARAFOV NATIONAL ACADEMY FOR THEATRE AND FILM ARTS': 'Krustyo Sarafov National Academy for Theatre and Film Arts', 'LA GRACE UNIVERSITY ADVANCED TECHNICIANS SCHOOL OF BENIN': 'La Grace University Advanced Technicians School of Benin', '17 AGUSTUS 1945 JAKARTA UNIVERSITY': '17 August 1945 University Jakarta', 'AACHEN UNIVERSITY OF APPLIED SCIENCE': 'Aachen University of Applied Sciences', 'ABBOTTABAD UNIVERSITY OF SCIENCE AND TECHNOLOGY': 'Abbottabad University of Science and Technology', 'ABDUL WALI KHAN UNIVERSITY MARDAN': 'Abdul Wali Khan University', 'ABE INTERNATIONAL BUSINESS COLLEGE': 'ABE International Business College', 'ABERYSTWYTH UNIVERSITY': 'Aberystwyth University', 'ABFI INSTITUTE PERBANAS': 'ABFI Institute Perbanas Jakarta', 'ABIA STATE UNIVERSITY': 'Abia State University', 'ACADEMY MARITIME CIREBON': 'Maine Maritime Academy', 'ACADEMY OF HUMANITIES AND TECHNOLOGY': 'Academy of Humanities and Technology', 'ACCRA TECHNICAL UNIVERSITY': 'Accra Technical University', 'ADHI TAMA INSTITUTE OF TECHNOLOGY': 'Adhi Tama Institute of Technology Surabaya', 'ADHI TAMA INSTITUTE OF TECHNOLOGY SURABAYA': 'Adhi Tama Institute of Technology Surabaya', 'ADI BUANA SURABAYA UNIVERSITY': 'Sunan Giri Surabaya University', 'ADISUTJIPTO COLLEGE OF TECHNOLOGY': 'Baguio College of Technology', 'ADVENTIST UNIVERSITY OF INDONESIA': 'Adventist University of Indonesia', 'ADVENTIST UNIVERSITY OF THE PHILIPPINES': 'Adventist University of the Philippines', 'AFRICA INTERNATIONAL UNIVERSITY': 'Africa International University', 'AGROCAMPUS WEST': 'Agrocampus West', 'AHMAD DAHLAN UNIVERSITY': 'Ahmad Dahlan University', 'AIMST UNIVERSITY': 'AIMST University', 'AIR UNIVERSITY': 'Air University', 'AIRLANGGA UNIVERSITY UNAIR': 'Airlangga University', 'AISYIYAH YOGYAKARTA UNIVERSITY': 'Yogyakarta State University', 'AKPRIND INSTITUTE OF SCIENCE TECHNOLOGY': 'SRM Institute of Science and Technology', 'AL AZHAR INDONESIA UNIVERSITY': 'AlAzhar University Indonesia', 'ALAUDDIN ISLAMIC STATE UNIVERSITY': 'State Islamic University of Alauddin', 'ALETHEIA UNIVERSITY CHINA': 'Aletheia University', 'ALIGARH MUSLIM UNIVERSITY': 'Aligarh Muslim University', 'AMA COMPUTER COLLEGE': 'ACTS Computer College', 'AMIKOM UNIVERSITY YOGYAKARTA': 'Cokroaminoto University  Yogyakarta', 'AMITY BUSINESS SCHOOL': 'BGFI Business School', 'ANGLIA RUSKIN UNIVERSITY': 'Anglia Ruskin University', 'ARID INSTITUTE OF MANAGEMENT SCIENCES LAHORE': 'Inst ...

# %%
#Map the dict to the whole unique list

data60=pd.DataFrame(deduplipydf["school_names"].map(d_60))
data60
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-2e7b2c8a8c6c> in <module>()
#       1 #Map the dict to the whole unique list
#       2
# ----> 3 data60=pd.DataFrame(deduplipydf["school_names"].map(d_60))
#       4 data60
#
# NameError: name 'd_60' is not defined

# %%
#Use this if not from file, straight from name_dict variable
data60=pd.DataFrame(deduplipydf["school_names"].map(name_dict))
data60
# Out:
#                                            school_names
# 0                                    Andalas University
# 1            Atma Jaya Catholic University of Indonesia
# 2                                                   NaN
# 3     Ho Chi Minh City University of Technology and ...
# 4                          General Soedirman University
# ...                                                 ...
# 9275                                                NaN
# 9276                                                NaN
# 9277                                                NaN
# 9278                                                NaN
# 9279                                    Toyo University
#
# [9280 rows x 1 columns]

# %%
#Combine together with uninames + dedup id + newname from unilist

compared_60 = pd.concat([deduplipydf, data60], axis=1, join='inner')
compared_60
# Out:
#                                            school_names  ...                                       school_names
# 0                                    ANDALAS UNIVERSITY  ...                                 Andalas University
# 1            ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA  ...         Atma Jaya Catholic University of Indonesia
# 2     BANDUNG POLYTECHNIC FOR MANUFACTURING POLMAN B...  ...                                                NaN
# 3     HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND ...  ...  Ho Chi Minh City University of Technology and ...
# 4                         JENDERAL SOEDIRMAN UNIVERSITY  ...                       General Soedirman University
# ...                                                 ...  ...                                                ...
# 9275                           ĐẠI HỌC BÁCH KHOA HÀ NỘI  ...                                                NaN
# 9276                                  ĐẠI HỌC CÔNG ĐOÀN  ...                                                NaN
# 9277                        ĐẠI HỌC TÀI CHÍNH MARKETING  ...                                                NaN
# 9278                         IMG SRCJAVASCRIPTALERTTEST  ...                                                NaN
# 9279                               東洋大学 TOYO UNIVERSITY  ...                                    Toyo University
#
# [9280 rows x 3 columns]

# %%
#To put the new names with the correct dedup_id

compared_60.columns = ['school_names', 'dedup_id', 'new_name']
compared_60=compared_60.drop(['school_names'], axis = 1)
compared_60.columns = ['dedup_id', 'school_names']

# %%
compared_60
# Out:
#       dedup_id                                       school_names
# 0            1                                 Andalas University
# 1            8         Atma Jaya Catholic University of Indonesia
# 2           46                                                NaN
# 3          101  Ho Chi Minh City University of Technology and ...
# 4          122                       General Soedirman University
# ...        ...                                                ...
# 9275      9272                                                NaN
# 9276      9273                                                NaN
# 9277      9274                                                NaN
# 9278      9275                                                NaN
# 9279      9276                                    Toyo University
#
# [9280 rows x 2 columns]

# %%
#Taking back the df before taking unique values 
#Added 1 more column to assign dedup ID into it

school_namedf_na.columns = ['school_names']
school_namedf_na['deduplication_id'] = 0

# %%
#To put dedup_id with whole list

df1 = school_namedf_na.set_index('school_names')
df2 = deduplipydf.set_index('school_names')
df1.update(df2)
df1.reset_index(inplace=True)

# %%
df1
# Out:
#                                             school_names  deduplication_id
# 0                                     ANDALAS UNIVERSITY               1.0
# 1             ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA               8.0
# 2      BANDUNG POLYTECHNIC FOR MANUFACTURING  POLMAN ...               0.0
# 3      HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND ...             101.0
# 4                          JENDERAL SOEDIRMAN UNIVERSITY             122.0
# ...                                                  ...               ...
# 59625                                  ĐẠI HỌC CÔNG ĐOÀN            9273.0
# 59626                          ĐẠI HỌC KINH TẾ  QUỐC DÂN               0.0
# 59627                        ĐẠI HỌC TÀI CHÍNH MARKETING            9274.0
# 59628                       \tIMG SRCJAVASCRIPTALERTTEST               0.0
# 59629                               東洋大学 TOYO UNIVERSITY            9276.0
#
# [59630 rows x 2 columns]

# %%
df1 = df1.astype({"deduplication_id": int})

# %%
#Drop those with dedup ID = 0, was cleaned out and not required for deduplipy

df1.drop(df1[df1['deduplication_id'] < 1].index, inplace = True)

# %%
df1
# Out:
#                                             school_names  deduplication_id
# 0                                     ANDALAS UNIVERSITY                 1
# 1             ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA                 8
# 3      HO CHI MINH CITY UNIVERSITY OF TECHNOLOGY AND ...               101
# 4                          JENDERAL SOEDIRMAN UNIVERSITY               122
# 5                      LEGAL PROFESSION QUALIFYING BOARD              7638
# ...                                                  ...               ...
# 59623                               ĐH CÔNG NGHIỆP TPHCM              9271
# 59624                           ĐẠI HỌC BÁCH KHOA HÀ NỘI              9272
# 59625                                  ĐẠI HỌC CÔNG ĐOÀN              9273
# 59627                        ĐẠI HỌC TÀI CHÍNH MARKETING              9274
# 59629                               東洋大学 TOYO UNIVERSITY              9276
#
# [38839 rows x 2 columns]

# %%
compared_60.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9280 entries, 0 to 9279
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dedup_id      9280 non-null   int64
#  1   school_names  3223 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 145.1+ KB

# %%
compared_60=compared_60.dropna()

# %%
#df1 = df1.set_index('Name')
#df2 = df2.set_index('Name')
#df1.update(df2)
#df1.reset_index(inplace=True)

df1 = df1.set_index('deduplication_id')
df2 = compared_60.set_index('dedup_id')
df1.update(df2)
df1.reset_index(inplace=True)

# %%
df1
# Out:
#        deduplication_id                                       school_names
# 0                     1                                 Andalas University
# 1                     8         Atma Jaya Catholic University of Indonesia
# 2                   101  Ho Chi Minh City University of Technology and ...
# 3                   122                       General Soedirman University
# 4                  7638                  LEGAL PROFESSION QUALIFYING BOARD
# ...                 ...                                                ...
# 38834              9271                               ĐH CÔNG NGHIỆP TPHCM
# 38835              9272                           ĐẠI HỌC BÁCH KHOA HÀ NỘI
# 38836              9273                                  ĐẠI HỌC CÔNG ĐOÀN
# 38837              9274                        ĐẠI HỌC TÀI CHÍNH MARKETING
# 38838              9276                                    Toyo University
#
# [38839 rows x 2 columns]

# %%
df1.to_csv("newuninames.csv")

# %% [markdown]
# ##Check new uni names

# %%
df1['school_names'].value_counts().head(30).plot(kind='bar',figsize=(15,10))

# %% [markdown]
# #Leftover code

# %% [markdown]
# ##Character count, accronyms for cleaning

# %%
unique_list['char_count'] = unique_list['school_name'].str.len()
unique_list

# %%
unique_list[unique_list.char_count < 5]

# %%
#AMIK = AMIK BINA SARANA INFORMATIKA
#BSI = UNIVERSITAS BINA SARANA INFORMATIKA
#FKIP = FKIP BAHASA INGGRIS
#FPT = FPT UNIVERSITY
#GCUF = GOVERNMENT COLLEGE UNIVERSITY FAISALABAD
#GIKI = GHULAM ISHAQ KHAN INSTITUTE
#I3L = 	INDONESIA INTERNATIONAL INSTITUTE FOR LIFE SCIENCES
#IAIN = INSTITUT AGAMA ISLAM NEGERI
#IBA = 	UNIVERSITY IBA
#IBBI = SEKOLAH TINGGI ILMU EKONOMI
#IBM = IBM ASMI
#ICBS = IMPERIAL COLLEGE OF BUSINESS STUDIES
#IIEE = IIEE NED UNIVERSITY OF ENGINEERING AND TECHNOLOGY
#IIUM = INTERNATIONAL ISLAMIC UNIVERSITY MALAYSIA 
#INTI = INTI INTERNATIONAL COLLEGE
#IPA = INSTITUTE OF PUBLIC ADMINISTRATION
#IPB = 	INSTITUT PERTANIAN BOGOR
#ITB = BANDUNG INSTITUTE OF TECHNOLOGHY
#ITNY = INSTITUT TEKNOLOGI NASIONAL YOGYAKARTA
#ITS = INSTITUT SEPULUH NOPEMBER
#IUMW = INTERNATIONAL UNIVERSITY OF MALAYAWALES
#KPTM = KOLEJ POLYTECH MARA
#LP31 = LP3I COLLEGE
#LSC = LONDON SCHOOL OF COMMERCE
#LSPR = LONDON SCHOOL OF PUBLIC RELATIONS
#MCHM = MALAYSIAN COLLEGE OF HOSPITALITY AND MANAGEMENT
#MMU = MULTIMEDIA UNIVERSITY
#MSU = MANAGEMENT SCIENCE UNIVERSITY
#NED = NED UNIVERSITY OF ENGINEERING AND TECHNOLOGY
#NTU = NANYANG TECHNOLOGICAL UNIVERSITY
#NUS = NATIONAL UNIVERSITY OF SINGAPORE
#NUST = NATIONAL UNIVERSITY OF SCIENCE AND TECHNOLOGY NUST
#PENS = ELECTRONIC ENGINEERING POLYTECHNIC INSTITUTE OF SURABAYA
#PVU = TRƯỜNG ĐẠI HỌC
#RMIT = ROYAL MELBOURNE INSTITUTE OF TECHNOLOGY
#SEGI = SEGI COLLEGE
#STIA = SEKOLAH TINGGI ILMU ADMINISTRASI
#STIE = SEKOLAH TINGGI ILMU EKONOMI
#SWUC = SOUTHWESTERN CHRISTIAN UNIVERSITY
#UBSI = UNIVERSITAS BINA SARANA INFORMATIKA
#UCSI = UCSI UNIVERISTY
#UEF = ĐẠI HỌC KINH TẾ QUỐC DÂN
#UEH = UNIVERSITY OF ECONOMICS HCMC
#UEL = UNIVERSITY OF EAST LONDON
#UGM = 	GADJAH MADA UNIVERSITY
#UIAM = UNIVERSITI ISLAM ANTARABANGSA MALAYSIA
#UII = UNIVERSITY ISLAM INDONESIA
#UITM = MARA UNIVERSITY OF TECHNOLOGY MALAYSIA
#UKI = 	UNIVERSITY KRISTEN INDONESIA
#UKM = NATIONAL UNIVERSITY OF MALAYSIA
#UM = UNIVERSITY OF MALAYA
#UMJ = UNIVERSITAS MUHAMMADIYAH JAKARTA
#UMM = UNIVERSITY OF MALAYA
#UMP = UNIVERSITY MALAYSIA PAHANG
#UMSU = UNIVERSITY MUHAMMADIYAH SUMATERA UTARA
#UMT = UNIVERSITI MALAYSIA TERENGGANU
#UMY = UNIVERSITY MUHAMMADIYAH YOGYAKARTA
#UNS = SEBELAS MARET UNIVERSITY
#UNSW = UNIVERSITY OF NEW SOUTH WALES
#UNY = UNIVERSITAS NEGERI YOGYAKARTA
#UOL = 	UNIVERSITY OF LONDON
#UPH = PELITA HARAPAN UNIVERSITY
#UPI = UNIVERSITY PENDIDIKAN INDONESIA
#UPM = UNIVERSITY PUTRA MALAYSIA
#UPNM = UNIVERSITI PERTAHANAN NASIONAL MALAYSIA
#USIM = UNIVERSITI SAINS ISLAM MALAYSIA
#USM = UNIVERSITI SAINS MALAYSIA
#USU = UNIVERSITY SUMATERA UTARA
#UTAR = UNIVERSITY TUNKU ABDUL RAHMAN
#UTEM = UNIVERSITI TEKNIKAL MALAYSIA MELAKA
#UTHM = UNIVERSITY TUN HUSSEIN ONN MALAYSIA
#UTM = UNIVERSITY TEKNOLOGI MALAYSIA
#UTP = UNIVERSITI TEKNOLOGI PETRONAS
#UUM = UNIVERSITY UTARA MALAYSIA
#YAI = AKADEMI AKUNTANSI YAI

# %% [markdown]
# ##Clustering using Sklearn

# %%
# !pip install leven
# Out:
# Collecting leven
#   Downloading leven-1.0.4.tar.gz (20 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from leven) (1.15.0)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 8.6 MB/s
# Building wheels for collected packages: leven
#   Building wheel for leven (setup.py) ... done
#   Created wheel for leven: filename=leven-1.0.4-cp37-cp37m-linux_x86_64.whl size=55507 sha256=f8b6aa88b9f42e643134c6d7ea17f93a3536d63bab8087be661ef00c76ee3ae2
#   Stored in directory: /root/.cache/pip/wheels/27/d5/b1/b36dd23f85aa662f19b11ef6069d5dc66643dfc1831d9f2bf5
# Successfully built leven
# Installing collected packages: nose, leven
# Successfully installed leven-1.0.4 nose-1.3.7

# %%
from leven import levenshtein       
import numpy as np
import sys
from sklearn.cluster import dbscan,DBSCAN
import sklearn

np.set_printoptions(threshold=sys.maxsize)

# %%
sklearn.__version__

# %%
cool = unique_list.values.tolist()

# %%
data = cool
def lev_metric(x, y):
    i, j = int(x[0]), int(y[0])     # extract indices
    return levenshtein(data[i], data[j])

X = np.arange(len(data)).reshape(-1, 1)
cluster=dbscan(X, metric=lev_metric, eps=5, min_samples=3)

# %%
levenshtein("abcd university", "university abcd")

# %%
cluster_list=list(cluster)

# %%
cluster_list[1]

# %%
cluster_df = pd.DataFrame(cluster_list)

# %%
cluster_df

# %%
cluster_df=cluster_df.transpose()

# %%
cluster_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9676 entries, 0 to 9675
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5004 non-null   float64
#  1   1       9676 non-null   float64
# dtypes: float64(2)
# memory usage: 151.3 KB

# %%
combined_df = pd.concat([unique_list, cluster_df], axis=1, join='inner')

# %%
combined_df.columns=['school_name', 'array1', 'array2']

# %%
combined_df.array2.value_counts()

# %%
combined_df.sort_values('array2') #eps 5, min 3
# Out:
#                                             school_name  array1  array2
# 9314                               東洋大学 TOYO UNIVERSITY     NaN    -1.0
# 3699  SEKOLAH TINGGI MANAJEMEN ILMU DAN KOMPUTER LOGIKA  7806.0    -1.0
# 3698  SEKOLAH TINGGI MANAJEMEN DAN ILMU KOMPUTER ROY...  7802.0    -1.0
# 3697  SEKOLAH TINGGI MANAJEMEN DAN ILMU KOMPUTER BUD...  7799.0    -1.0
# 3696         SEKOLAH TINGGI MANAJEMEN ASURANSI TRISAKTI  7798.0    -1.0
# ...                                                 ...     ...     ...
# 9187                                  VIGNAN UNIVERSITY     NaN   365.0
# 9183                     VIETNAM UNIVERSITY OF COMMERCE     NaN   365.0
# 9185                        VIETNAMESEGERMAN UNIVERSITY     NaN   365.0
# 9186                    VIETNAMESEGERMAN UNIVERSITY VGU     NaN   365.0
# 9188                   VIRGINA COMMONWEALTH INSTITUTION     NaN   365.0
#
# [9315 rows x 3 columns]

# %%
data = cool
def lev_metric(x, y):
    i, j = int(x[0]), int(y[0])     # extract indices
    return levenshtein(data[i], data[j])

X = np.arange(len(data)).reshape(-1, 1)
cluster=dbscan(X, metric=lev_metric, eps=6, min_samples=2)

# %%
cluster_list=list(cluster)
cluster_df = pd.DataFrame(cluster_list)
cluster_df=cluster_df.transpose()
combined_df2 = pd.concat([unique_list, cluster_df], axis=1, join='inner')
combined_df2.columns=['school_name', 'array1', 'array2']

# %%
combined_df2.sort_values('array2') #eps 6, min 2

# %% [markdown]
# ##Faster Clustering

# %%
# !pip install levenshtein
# Out:
# Collecting levenshtein
#   Downloading Levenshtein-0.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      |████████████████████████████████| 110 kB 5.7 MB/s
# Collecting rapidfuzz<1.9,>=1.8.2
#   Downloading rapidfuzz-1.8.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (854 kB)
#      |████████████████████████████████| 854 kB 11.5 MB/s
# Installing collected packages: rapidfuzz, levenshtein
# Successfully installed levenshtein-0.16.0 rapidfuzz-1.8.3

# %%
import numpy as np
import pandas as pd
import re
from sklearn.cluster import DBSCAN
from scipy.spatial.distance import pdist, squareform
from Levenshtein import distance

# %%
school_names = unique_list.to_numpy()

# %%
school_names=school_names.flatten()

# %%
def setdistance(l1, l2):
  return distance(l1[0], l2[0])

# %%
# %%time
distance_matrix = squareform(pdist(school_names.reshape(-1,1), metric=setdistance))
cls = DBSCAN(metric="precomputed", eps=3, min_samples=3)
cls.fit(distance_matrix)
label = pd.DataFrame({"name":school_names, "label":cls.labels_})
# Out:
# CPU times: user 1min 16s, sys: 153 ms, total: 1min 16s
# Wall time: 1min 16s

# %%
label.sort_values('label')
# Out:
#                                    name  label
# 4639                    STIE MUSI RAWAS     -1
# 5261  THE UNIVERSITY OF NEW SOUTH WALES     -1
# 5260        THE UNIVERSITY OF MELBOURNE     -1
# 5259    THE UNIVERSITY OF MANCHESTER UK     -1
# 5258       THE UNIVERSITY OF MANCHESTER     -1
# ...                                 ...    ...
# 9208               WIDYATAMA UNIVERSITY    378
# 9210                WIDYTAMA UNIVERSITY    378
# 9253         YOGYAKARTA SATE UNIVERSITY    379
# 9257       YOGYAKARTA STATES UNIVERSITY    379
# 9254        YOGYAKARTA STATE UNIVERSITY    379
#
# [9280 rows x 2 columns]

# %%
#label to look back on
#-1, 0, 3, 10, 11, [1, 13-17], [19,20], [22,23], 27, 42, 43, 48, 49, [73,76], [77,78], 
#81, 82, 86, 87, 88, 89, [90,91], 93, [103-109], [110-114,116-118], [121,122], 123,
#125, [127-138], [142,143], [145-150], [152,153], [154,160,162-169], 161, [170,171]
#[174,175], [176,177], [181-187], [192,193], [194,195], 197, 199, [205,206], 222, 224
#[291,292], 294, [298,299], 318, [321,322], 334, 335, 336,337, 338, 339, 341, 342,
#343, 344, 346, 347, 348, 353, 354, 355, 357, 358, 360, 361, 362, 365, 366, 369

#[1, 13-17] - ATMA JAYA CATHOLIC UNIVERSITY OF INDONESIA
#[19,20] - BANDUNG INSTITUTE OF TECHNOLOGHY
#[22,23] - STATE POLYTECHNIC
#[73,76] - SEPULUH NOVEMBER INSTITUTE OF TECHNOLOGY
#[77,78] - INTERNATIONAL ISLAMIC UNIVERSITY ISLAMABAD
#[90,91] - KOLEJ UNIVERSITY POLYTECH
#[103-109] - MUHAMMADIYAH UNIVERSITY
#[110-114,116-118] - NATIONAL UNIVERSITY OF SCIENCE AND TECHNOLOGY
#[121,122] - PERBANAS INSTITUTE
#[127-138] - STATE POLYTECHNIC
#[142,143] - QUAID E AWAM UNIVERSITY OF ENGINEERING SCIENCES AND TECHNOLOGY
#[145-150] - SEKOLAH TINGGI (remove maybe)
#[152,153] - SEPULUH NOVEMBER INSTITUTE OF TECHNOLOGY
#[154,160,162,169] - SMK/SMA (remove maybe)
#[170,171] - STATE ISLAMIC UNIVERSITY
#[174,175] - Sekolah Tinggi Bahasa (remove, just a language school)
#[176,177] - SEKOLAH TINGGI ILMU EKONOMI
#[181-187] - SEKOLAH TINGGI (remove maybe)
#[192,193] - TRISAKTI INSTITUTE OF TRANSPORTATION AND LOGISTICS
#[194,195] - TUNKU ABDUL RAHMAN UNIVERSITY COLLEGE
#[205,206] - MUHAMMADIYAH UNIVERSITY
#[291,292] - DEVELOPMENT UNIVERSITY OF PANCA BUDI
#[298,299] - PROF DR MOESTOPO UNIVERSITY
#[220,321,322] - MARA UNIVERSITY OF TECHNOLOGY MALAYSIA

# %% [markdown]
# ##Coding attempts

# %%
school_name_list = school_namedf_na.iloc[:,0].values.tolist()
#unique_list = ['UNIVERSITY OF' if i.startswith('UNIVER')]

school_name_list

# %%
z = []
cool = []
for x in school_name_list:
  z.append(x.split())

for anything in z:
  if len(anything) < 1:
    print(anything)

# %%
for i in range(len(z)):
  if len(z[i]) == 0:
    continue
  
  if z[i][0].endswith('ITAS'):
    cool.append(' '.join(['UNIVERSITY'] + z[i][1:]))
  else:
    cool.append(' '.join(z[i][0:]))
cool

# %%
school_name_list=pd.DataFrame(cool)
school_name_list

# %%
data = cool
def lev_metric(x, y):
    i, j = int(x[0]), int(y[0])     # extract indices
    return levenshtein(data[i], data[j])

X = np.arange(len(data)).reshape(-1, 1)
cluster=dbscan(X, metric=lev_metric, eps=6, min_samples=2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._ball_tree.BinaryTree.rdist()
#
# sklearn/neighbors/_dist_metrics.pyx in sklearn.neighbors._dist_metrics.DistanceMetric.rdist()
#
# sklearn/neighbors/_dist_metrics.pyx in sklearn.neighbors._dist_metrics.PyFuncDistance.dist()
#
# sklearn/neighbors/_dist_metrics.pyx in sklearn.neighbors._dist_metrics.PyFuncDistance._dist()
#
# <ipython-input-22-f2a3ac880cec> in lev_metric(x, y)
#       2 def lev_metric(x, y):
#       3     i, j = int(x[0]), int(y[0])     # extract indices
# ----> 4     return levenshtein(data[i], data[j])
#       5
#       6 X = np.arange(len(data)).reshape(-1, 1)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.neighbors._ball_tree.BinaryTree._query_radius_single'
# Traceback (most recent call last):
#   File "sklearn/neighbors/_binary_tree.pxi", line 1129, in sklearn.neighbors._ball_tree.BinaryTree.rdist
#   File "sklearn/neighbors/_dist_metrics.pyx", line 303, in sklearn.neighbors._dist_metrics.DistanceMetric.rdist
#   File "sklearn/neighbors/_dist_metrics.pyx", line 1128, in sklearn.neighbors._dist_metrics.PyFuncDistance.dist
#   File "sklearn/neighbors/_dist_metrics.pyx", line 1136, in sklearn.neighbors._dist_metrics.PyFuncDistance._dist
#   File "<ipython-input-22-f2a3ac880cec>", line 4, in lev_metric
# KeyboardInterrupt

# %%
cluster_list=list(cluster)
cluster_df = pd.DataFrame(cluster_list)
cluster_df=cluster_df.transpose()
combined_df3 = pd.concat([school_name_list, cluster_df], axis=1, join='inner')
combined_df3.columns=['school_name', 'array1', 'array2']
